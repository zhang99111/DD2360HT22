# %% [markdown]
# <a href="https://colab.research.google.com/github/zhang99111/DD2360HT22/blob/main/hw_3/hw3_ex3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd '/content/drive/MyDrive'
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive

# %%
# !nvcc -arch=sm_75 ./lab3_ex3.cu -o lab3_ex3

# %%
# !./lab3_ex3 131072
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# hostBins[2429] =  43
# CPU and GPU results are  equal.
# resultRef[2430] = 42
# hostBins[2430] =  42
# CPU and GPU results are  equal.
# resultRef[2431] = 33
# hostBins[2431] =  33
# CPU and GPU results are  equal.
# resultRef[2432] = 21
# hostBins[2432] =  21
# CPU and GPU results are  equal.
# resultRef[2433] = 36
# hostBins[2433] =  36
# CPU and GPU results are  equal.
# resultRef[2434] = 39
# hostBins[2434] =  39
# CPU and GPU results are  equal.
# resultRef[2435] = 38
# hostBins[2435] =  38
# CPU and GPU results are  equal.
# resultRef[2436] = 37
# hostBins[2436] =  37
# CPU and GPU results are  equal.
# resultRef[2437] = 31
# hostBins[2437] =  31
# CPU and GPU results are  equal.
# resultRef[2438] = 31
# hostBins[2438] =  31
# CPU and GPU results are  equal.
# resultRef[2439] = 25
# hostBins[2439] =  25
# CPU and GPU results are  equal.
# resultRef[2440] = 37
# hostBins[2440] =  37
# CPU and GPU results are  equal.
# resultRef[2441] = 25
# hostBins[2441] =  25
# CPU and GPU results are  equal.
# resultRef[2442] = 29
# hostBins[2442] =  29
# CPU and GPU results are  equal.
# resultRef[2443] = 43
# hostBins[2443] =  43
# CPU and GPU results are  equal.
# resultRef[2444] = 30
# hostBins[2444] =  30
# CPU and GPU results are  equal.
# resultRef[2445] = 37
# hostBins[2445] =  37
# CPU and GPU results are  equal.
# resultRef[2446] = 40
# hostBins[2446] =  40
# CPU and GPU results are  equal.
# resultRef[2447] = 40
# hostBins[2447] =  40
# CPU and GPU results are  equal.
# resultRef[2448] = 30
# hostBins[2448] =  30
# CPU and GPU results are  equal.
# resultRef[2449] = 40
# hostBins[2449] =  40
# CPU and GPU results are  equal.
# resultRef[2450] = 30
# hostBins[2450] =  30
# CPU and GPU results are  equal.
# resultRef[2451] = 34
# hostBins[2451] =  34
# CPU and GPU results are  equal.
# resultRef[2452] = 34
# hostBins[2452] =  34
# CPU and GPU results are  equal.
# resultRef[2453] = 37
# hostBins[2453] =  37
# CPU and GPU results are  equal.
# resultRef[2454] = 22
# hostBins[2454] =  22
# CPU and GPU results are  equal.
# resultRef[2455] = 32
# hostBins[2455] =  32
# CPU and GPU results are  equal.
# resultRef[2456] = 26
# hostBins[2456] =  26
# CPU and GPU results are  equal.
# resultRef[2457] = 28
# hostBins[2457] =  28
# CPU and GPU results are  equal.
# resultRef[2458] = 32
# hostBins[2458] =  32
# CPU and GPU results are  equal.
# resultRef[2459] = 42
# hostBins[2459] =  42
# CPU and GPU results are  equal.
# resultRef[2460] = 29
# hostBins[2460] =  29
# CPU and GPU results are  equal.
# resultRef[2461] = 30
# hostBins[2461] =  30
# CPU and GPU results are  equal.
# resultRef[2462] = 30
# hostBins[2462] =  30
# CPU and GPU results are  equal.
# resultRef[2463] = 41
# hostBins[2463] =  41
# CPU and GPU results are  equal.
# resultRef[2464] = 41
# hostBins[2464] =  41
# CPU and GPU results are  equal.
# resultRef[2465] = 36
# hostBins[2465] =  36
# CPU and GPU results are  equal.
# resultRef[2466] = 33
# hostBins[2466] =  33
# CPU and GPU results are  equal.
# resultRef[2467] = 32
# hostBins[2467] =  32
# CPU and GPU results are  equal.
# resultRef[2468] = 29
# hostBins[2468] =  29
# CPU and GPU results are  equal.
# resultRef[2469] = 42
# hostBins[2469] =  42
# CPU and GPU results are  equal.
# resultRef[2470] = 38
# hostBins[2470] =  38
# CPU and GPU results are  equal.
# resultRef[2471] = 28
# hostBins[2471] =  28
# CPU and GPU results are  equal.
# resultRef[2472] = 32
# hostBins[2472] =  32
# CPU and GPU results are  equal.
# resultRef[2473] = 33
# hostBins[2473] =  33
# CPU and GPU results are  equal.
# resultRef[2474] = 27
# hostBins[2474] =  27
# CPU and GPU results are  equal.
# resultRef[2475] = 34
# hostBins[2475] =  34
# CPU and GPU results are  equal.
# resultRef[2476] = 17
# hostBins[2476] =  17
# CPU and GPU results are  equal.
# resultRef[2477] = 33
# hostBins[2477] =  33
# CPU and GPU results are  equal.
# resultRef[2478] = 29
# hostBins[2478] =  29
# CPU and GPU results are  equal.
# resultRef[2479] = 31
# hostBins[2479] =  31
# CPU and GPU results are  equal.
# resultRef[2480] = 30
# hostBins[2480] =  30
# CPU and GPU results are  equal.
# resultRef[2481] = 32
# hostBins[2481] =  32
# CPU and GPU results are  equal.
# resultRef[2482] = 27
# hostBins[2482] =  27
# CPU and GPU results are  equal.
# resultRef[2483] = 29
# hostBins[2483] =  29
# CPU and GPU results are  equal.
# resultRef[2484] = 38
# hostBins[2484] =  38
# CPU and GPU results are  equal.
# resultRef[2485] = 35
# hostBins[2485] =  35
# CPU and GPU results are  equal.
# resultRef[2486] = 31
# hostBins[2486] =  31
# CPU and GPU results are  equal.
# resultRef[2487] = 30
# hostBins[2487] =  30
# CPU and GPU results are  equal.
# resultRef[2488] = 29
# hostBins[2488] =  29
# CPU and GPU results are  equal.
# resultRef[2489] = 28
# hostBins[2489] =  28
# CPU and GPU results are  equal.
# resultRef[2490] = 35
# hostBins[2490] =  35
# CPU and GPU results are  equal.
# resultRef[2491] = 28
# hostBins[2491] =  28
# CPU and GPU results are  equal.
# resultRef[2492] = 24
# hostBins[2492] =  24
# CPU and GPU results are  equal.
# resultRef[2493] = 34
# hostBins[2493] =  34
# CPU and GPU results are  equal.
# resultRef[2494] = 18
# hostBins[2494] =  18
# CPU and GPU results are  equal.
# resultRef[2495] = 20
# hostBins[2495] =  20
# CPU and GPU results are  equal.
# resultRef[2496] = 27
# hostBins[2496] =  27
# CPU and GPU results are  equal.
# resultRef[2497] = 23
# hostBins[2497] =  23
# CPU and GPU results are  equal.
# resultRef[2498] = 30
# hostBins[2498] =  30
# CPU and GPU results are  equal.
# resultRef[2499] = 32
# hostBins[2499] =  32
# CPU and GPU results are  equal.
# resultRef[2500] = 25
# hostBins[2500] =  25
# CPU and GPU results are  equal.
# resultRef[2501] = 35
# hostBins[2501] =  35
# CPU and GPU results are  equal.
# resultRef[2502] = 23
# hostBins[2502] =  23
# CPU and GPU results are  equal.
# resultRef[2503] = 43
# hostBins[2503] =  43
# CPU and GPU results are  equal.
# resultRef[2504] = 43
# hostBins[2504] =  43
# CPU and GPU results are  equal.
# resultRef[2505] = 38
# hostBins[2505] =  38
# CPU and GPU results are  equal.
# resultRef[2506] = 35
# hostBins[2506] =  35
# CPU and GPU results are  equal.
# resultRef[2507] = 31
# hostBins[2507] =  31
# CPU and GPU results are  equal.
# resultRef[2508] = 29
# hostBins[2508] =  29
# CPU and GPU results are  equal.
# resultRef[2509] = 38
# hostBins[2509] =  38
# CPU and GPU results are  equal.
# resultRef[2510] = 28
# hostBins[2510] =  28
# CPU and GPU results are  equal.
# resultRef[2511] = 27
# hostBins[2511] =  27
# CPU and GPU results are  equal.
# resultRef[2512] = 37
# hostBins[2512] =  37
# CPU and GPU results are  equal.
# resultRef[2513] = 40
# hostBins[2513] =  40
# CPU and GPU results are  equal.
# resultRef[2514] = 50
# hostBins[2514] =  50
# CPU and GPU results are  equal.
# resultRef[2515] = 45
# hostBins[2515] =  45
# CPU and GPU results are  equal.
# resultRef[2516] = 21
# hostBins[2516] =  21
# CPU and GPU results are  equal.
# resultRef[2517] = 28
# hostBins[2517] =  28
# CPU and GPU results are  equal.
# resultRef[2518] = 29
# hostBins[2518] =  29
# CPU and GPU results are  equal.
# resultRef[2519] = 24
# hostBins[2519] =  24
# CPU and GPU results are  equal.
# resultRef[2520] = 33
# hostBins[2520] =  33
# CPU and GPU results are  equal.
# resultRef[2521] = 30
# hostBins[2521] =  30
# CPU and GPU results are  equal.
# resultRef[2522] = 34
# hostBins[2522] =  34
# CPU and GPU results are  equal.
# resultRef[2523] = 36
# hostBins[2523] =  36
# CPU and GPU results are  equal.
# resultRef[2524] = 34
# hostBins[2524] =  34
# CPU and GPU results are  equal.
# resultRef[2525] = 35
# hostBins[2525] =  35
# CPU and GPU results are  equal.
# resultRef[2526] = 36
# hostBins[2526] =  36
# CPU and GPU results are  equal.
# resultRef[2527] = 22
# hostBins[2527] =  22
# CPU and GPU results are  equal.
# resultRef[2528] = 34
# hostBins[2528] =  34
# CPU and GPU results are  equal.
# resultRef[2529] = 26
# hostBins[2529] =  26
# CPU and GPU results are  equal.
# resultRef[2530] = 32
# hostBins[2530] =  32
# CPU and GPU results are  equal.
# resultRef[2531] = 27
# hostBins[2531] =  27
# CPU and GPU results are  equal.
# resultRef[2532] = 39
# hostBins[2532] =  39
# CPU and GPU results are  equal.
# resultRef[2533] = 39
# hostBins[2533] =  39
# CPU and GPU results are  equal.
# resultRef[2534] = 47
# hostBins[2534] =  47
# CPU and GPU results are  equal.
# resultRef[2535] = 36
# hostBins[2535] =  36
# CPU and GPU results are  equal.
# resultRef[2536] = 26
# hostBins[2536] =  26
# CPU and GPU results are  equal.
# resultRef[2537] = 40
# hostBins[2537] =  40
# CPU and GPU results are  equal.
# resultRef[2538] = 40
# hostBins[2538] =  40
# CPU and GPU results are  equal.
# resultRef[2539] = 35
# hostBins[2539] =  35
# CPU and GPU results are  equal.
# resultRef[2540] = 29
# hostBins[2540] =  29
# CPU and GPU results are  equal.
# resultRef[2541] = 30
# hostBins[2541] =  30
# CPU and GPU results are  equal.
# resultRef[2542] = 28
# hostBins[2542] =  28
# CPU and GPU results are  equal.
# resultRef[2543] = 42
# hostBins[2543] =  42
# CPU and GPU results are  equal.
# resultRef[2544] = 37
# hostBins[2544] =  37
# CPU and GPU results are  equal.
# resultRef[2545] = 34
# hostBins[2545] =  34
# CPU and GPU results are  equal.
# resultRef[2546] = 33
# hostBins[2546] =  33
# CPU and GPU results are  equal.
# resultRef[2547] = 25
# hostBins[2547] =  25
# CPU and GPU results are  equal.
# resultRef[2548] = 38
# hostBins[2548] =  38
# CPU and GPU results are  equal.
# resultRef[2549] = 36
# hostBins[2549] =  36
# CPU and GPU results are  equal.
# resultRef[2550] = 36
# hostBins[2550] =  36
# CPU and GPU results are  equal.
# resultRef[2551] = 26
# hostBins[2551] =  26
# CPU and GPU results are  equal.
# resultRef[2552] = 35
# hostBins[2552] =  35
# CPU and GPU results are  equal.
# resultRef[2553] = 24
# hostBins[2553] =  24
# CPU and GPU results are  equal.
# resultRef[2554] = 28
# hostBins[2554] =  28
# CPU and GPU results are  equal.
# resultRef[2555] = 27
# hostBins[2555] =  27
# CPU and GPU results are  equal.
# resultRef[2556] = 27
# hostBins[2556] =  27
# CPU and GPU results are  equal.
# resultRef[2557] = 30
# hostBins[2557] =  30
# CPU and GPU results are  equal.
# resultRef[2558] = 37
# hostBins[2558] =  37
# CPU and GPU results are  equal.
# resultRef[2559] = 31
# hostBins[2559] =  31
# CPU and GPU results are  equal.
# resultRef[2560] = 35
# hostBins[2560] =  35
# CPU and GPU results are  equal.
# resultRef[2561] = 41
# hostBins[2561] =  41
# CPU and GPU results are  equal.
# resultRef[2562] = 35
# hostBins[2562] =  35
# CPU and GPU results are  equal.
# resultRef[2563] = 35
# hostBins[2563] =  35
# CPU and GPU results are  equal.
# resultRef[2564] = 29
# hostBins[2564] =  29
# CPU and GPU results are  equal.
# resultRef[2565] = 26
# hostBins[2565] =  26
# CPU and GPU results are  equal.
# resultRef[2566] = 40
# hostBins[2566] =  40
# CPU and GPU results are  equal.
# resultRef[2567] = 39
# hostBins[2567] =  39
# CPU and GPU results are  equal.
# resultRef[2568] = 34
# hostBins[2568] =  34
# CPU and GPU results are  equal.
# resultRef[2569] = 32
# hostBins[2569] =  32
# CPU and GPU results are  equal.
# resultRef[2570] = 34
# hostBins[2570] =  34
# CPU and GPU results are  equal.
# resultRef[2571] = 28
# hostBins[2571] =  28
# CPU and GPU results are  equal.
# resultRef[2572] = 32
# hostBins[2572] =  32
# CPU and GPU results are  equal.
# resultRef[2573] = 22
# hostBins[2573] =  22
# CPU and GPU results are  equal.
# resultRef[2574] = 50
# hostBins[2574] =  50
# CPU and GPU results are  equal.
# resultRef[2575] = 40
# hostBins[2575] =  40
# CPU and GPU results are  equal.
# resultRef[2576] = 24
# hostBins[2576] =  24
# CPU and GPU results are  equal.
# resultRef[2577] = 33
# hostBins[2577] =  33
# CPU and GPU results are  equal.
# resultRef[2578] = 29
# hostBins[2578] =  29
# CPU and GPU results are  equal.
# resultRef[2579] = 27
# hostBins[2579] =  27
# CPU and GPU results are  equal.
# resultRef[2580] = 36
# hostBins[2580] =  36
# CPU and GPU results are  equal.
# resultRef[2581] = 31
# hostBins[2581] =  31
# CPU and GPU results are  equal.
# resultRef[2582] = 35
# hostBins[2582] =  35
# CPU and GPU results are  equal.
# resultRef[2583] = 30
# hostBins[2583] =  30
# CPU and GPU results are  equal.
# resultRef[2584] = 25
# hostBins[2584] =  25
# CPU and GPU results are  equal.
# resultRef[2585] = 36
# hostBins[2585] =  36
# CPU and GPU results are  equal.
# resultRef[2586] = 25
# hostBins[2586] =  25
# CPU and GPU results are  equal.
# resultRef[2587] = 26
# hostBins[2587] =  26
# CPU and GPU results are  equal.
# resultRef[2588] = 26
# hostBins[2588] =  26
# CPU and GPU results are  equal.
# resultRef[2589] = 23
# hostBins[2589] =  23
# CPU and GPU results are  equal.
# resultRef[2590] = 27
# hostBins[2590] =  27
# CPU and GPU results are  equal.
# resultRef[2591] = 30
# hostBins[2591] =  30
# CPU and GPU results are  equal.
# resultRef[2592] = 36
# hostBins[2592] =  36
# CPU and GPU results are  equal.
# resultRef[2593] = 25
# hostBins[2593] =  25
# CPU and GPU results are  equal.
# resultRef[2594] = 30
# hostBins[2594] =  30
# CPU and GPU results are  equal.
# resultRef[2595] = 39
# hostBins[2595] =  39
# CPU and GPU results are  equal.
# resultRef[2596] = 32
# hostBins[2596] =  32
# CPU and GPU results are  equal.
# resultRef[2597] = 31
# hostBins[2597] =  31
# CPU and GPU results are  equal.
# resultRef[2598] = 24
# hostBins[2598] =  24
# CPU and GPU results are  equal.
# resultRef[2599] = 38
# hostBins[2599] =  38
# CPU and GPU results are  equal.
# resultRef[2600] = 28
# hostBins[2600] =  28
# CPU and GPU results are  equal.
# resultRef[2601] = 42
# hostBins[2601] =  42
# CPU and GPU results are  equal.
# resultRef[2602] = 27
# hostBins[2602] =  27
# CPU and GPU results are  equal.
# resultRef[2603] = 25
# hostBins[2603] =  25
# CPU and GPU results are  equal.
# resultRef[2604] = 28
# hostBins[2604] =  28
# CPU and GPU results are  equal.
# resultRef[2605] = 30
# hostBins[2605] =  30
# CPU and GPU results are  equal.
# resultRef[2606] = 32
# hostBins[2606] =  32
# CPU and GPU results are  equal.
# resultRef[2607] = 34
# hostBins[2607] =  34
# CPU and GPU results are  equal.
# resultRef[2608] = 26
# hostBins[2608] =  26
# CPU and GPU results are  equal.
# resultRef[2609] = 34
# hostBins[2609] =  34
# CPU and GPU results are  equal.
# resultRef[2610] = 37
# hostBins[2610] =  37
# CPU and GPU results are  equal.
# resultRef[2611] = 28
# hostBins[2611] =  28
# CPU and GPU results are  equal.
# resultRef[2612] = 38
# hostBins[2612] =  38
# CPU and GPU results are  equal.
# resultRef[2613] = 19
# hostBins[2613] =  19
# CPU and GPU results are  equal.
# resultRef[2614] = 28
# hostBins[2614] =  28
# CPU and GPU results are  equal.
# resultRef[2615] = 44
# hostBins[2615] =  44
# CPU and GPU results are  equal.
# resultRef[2616] = 32
# hostBins[2616] =  32
# CPU and GPU results are  equal.
# resultRef[2617] = 35
# hostBins[2617] =  35
# CPU and GPU results are  equal.
# resultRef[2618] = 20
# hostBins[2618] =  20
# CPU and GPU results are  equal.
# resultRef[2619] = 28
# hostBins[2619] =  28
# CPU and GPU results are  equal.
# resultRef[2620] = 36
# hostBins[2620] =  36
# CPU and GPU results are  equal.
# resultRef[2621] = 36
# hostBins[2621] =  36
# CPU and GPU results are  equal.
# resultRef[2622] = 38
# hostBins[2622] =  38
# CPU and GPU results are  equal.
# resultRef[2623] = 34
# hostBins[2623] =  34
# CPU and GPU results are  equal.
# resultRef[2624] = 30
# hostBins[2624] =  30
# CPU and GPU results are  equal.
# resultRef[2625] = 30
# hostBins[2625] =  30
# CPU and GPU results are  equal.
# resultRef[2626] = 43
# hostBins[2626] =  43
# CPU and GPU results are  equal.
# resultRef[2627] = 30
# hostBins[2627] =  30
# CPU and GPU results are  equal.
# resultRef[2628] = 35
# hostBins[2628] =  35
# CPU and GPU results are  equal.
# resultRef[2629] = 35
# hostBins[2629] =  35
# CPU and GPU results are  equal.
# resultRef[2630] = 23
# hostBins[2630] =  23
# CPU and GPU results are  equal.
# resultRef[2631] = 37
# hostBins[2631] =  37
# CPU and GPU results are  equal.
# resultRef[2632] = 33
# hostBins[2632] =  33
# CPU and GPU results are  equal.
# resultRef[2633] = 33
# hostBins[2633] =  33
# CPU and GPU results are  equal.
# resultRef[2634] = 24
# hostBins[2634] =  24
# CPU and GPU results are  equal.
# resultRef[2635] = 38
# hostBins[2635] =  38
# CPU and GPU results are  equal.
# resultRef[2636] = 31
# hostBins[2636] =  31
# CPU and GPU results are  equal.
# resultRef[2637] = 32
# hostBins[2637] =  32
# CPU and GPU results are  equal.
# resultRef[2638] = 37
# hostBins[2638] =  37
# CPU and GPU results are  equal.
# resultRef[2639] = 35
# hostBins[2639] =  35
# CPU and GPU results are  equal.
# resultRef[2640] = 28
# hostBins[2640] =  28
# CPU and GPU results are  equal.
# resultRef[2641] = 34
# hostBins[2641] =  34
# CPU and GPU results are  equal.
# resultRef[2642] = 30
# hostBins[2642] =  30
# CPU and GPU results are  equal.
# resultRef[2643] = 39
# hostBins[2643] =  39
# CPU and GPU results are  equal.
# resultRef[2644] = 28
# hostBins[2644] =  28
# CPU and GPU results are  equal.
# resultRef[2645] = 33
# hostBins[2645] =  33
# CPU and GPU results are  equal.
# resultRef[2646] = 37
# hostBins[2646] =  37
# CPU and GPU results are  equal.
# resultRef[2647] = 30
# hostBins[2647] =  30
# CPU and GPU results are  equal.
# resultRef[2648] = 39
# hostBins[2648] =  39
# CPU and GPU results are  equal.
# resultRef[2649] = 32
# hostBins[2649] =  32
# CPU and GPU results are  equal.
# resultRef[2650] = 31
# hostBins[2650] =  31
# CPU and GPU results are  equal.
# resultRef[2651] = 28
# hostBins[2651] =  28
# CPU and GPU results are  equal.
# resultRef[2652] = 30
# hostBins[2652] =  30
# CPU and GPU results are  equal.
# resultRef[2653] = 44
# hostBins[2653] =  44
# CPU and GPU results are  equal.
# resultRef[2654] = 35
# hostBins[2654] =  35
# CPU and GPU results are  equal.
# resultRef[2655] = 32
# hostBins[2655] =  32
# CPU and GPU results are  equal.
# resultRef[2656] = 38
# hostBins[2656] =  38
# CPU and GPU results are  equal.
# resultRef[2657] = 39
# hostBins[2657] =  39
# CPU and GPU results are  equal.
# resultRef[2658] = 43
# hostBins[2658] =  43
# CPU and GPU results are  equal.
# resultRef[2659] = 30
# hostBins[2659] =  30
# CPU and GPU results are  equal.
# resultRef[2660] = 27
# hostBins[2660] =  27
# CPU and GPU results are  equal.
# resultRef[2661] = 47
# hostBins[2661] =  47
# CPU and GPU results are  equal.
# resultRef[2662] = 35
# hostBins[2662] =  35
# CPU and GPU results are  equal.
# resultRef[2663] = 20
# hostBins[2663] =  20
# CPU and GPU results are  equal.
# resultRef[2664] = 28
# hostBins[2664] =  28
# CPU and GPU results are  equal.
# resultRef[2665] = 26
# hostBins[2665] =  26
# CPU and GPU results are  equal.
# resultRef[2666] = 26
# hostBins[2666] =  26
# CPU and GPU results are  equal.
# resultRef[2667] = 29
# hostBins[2667] =  29
# CPU and GPU results are  equal.
# resultRef[2668] = 35
# hostBins[2668] =  35
# CPU and GPU results are  equal.
# resultRef[2669] = 26
# hostBins[2669] =  26
# CPU and GPU results are  equal.
# resultRef[2670] = 33
# hostBins[2670] =  33
# CPU and GPU results are  equal.
# resultRef[2671] = 32
# hostBins[2671] =  32
# CPU and GPU results are  equal.
# resultRef[2672] = 28
# hostBins[2672] =  28
# CPU and GPU results are  equal.
# resultRef[2673] = 29
# hostBins[2673] =  29
# CPU and GPU results are  equal.
# resultRef[2674] = 37
# hostBins[2674] =  37
# CPU and GPU results are  equal.
# resultRef[2675] = 28
# hostBins[2675] =  28
# CPU and GPU results are  equal.
# resultRef[2676] = 24
# hostBins[2676] =  24
# CPU and GPU results are  equal.
# resultRef[2677] = 20
# hostBins[2677] =  20
# CPU and GPU results are  equal.
# resultRef[2678] = 25
# hostBins[2678] =  25
# CPU and GPU results are  equal.
# resultRef[2679] = 27
# hostBins[2679] =  27
# CPU and GPU results are  equal.
# resultRef[2680] = 42
# hostBins[2680] =  42
# CPU and GPU results are  equal.
# resultRef[2681] = 29
# hostBins[2681] =  29
# CPU and GPU results are  equal.
# resultRef[2682] = 34
# hostBins[2682] =  34
# CPU and GPU results are  equal.
# resultRef[2683] = 25
# hostBins[2683] =  25
# CPU and GPU results are  equal.
# resultRef[2684] = 20
# hostBins[2684] =  20
# CPU and GPU results are  equal.
# resultRef[2685] = 35
# hostBins[2685] =  35
# CPU and GPU results are  equal.
# resultRef[2686] = 39
# hostBins[2686] =  39
# CPU and GPU results are  equal.
# resultRef[2687] = 28
# hostBins[2687] =  28
# CPU and GPU results are  equal.
# resultRef[2688] = 30
# hostBins[2688] =  30
# CPU and GPU results are  equal.
# resultRef[2689] = 32
# hostBins[2689] =  32
# CPU and GPU results are  equal.
# resultRef[2690] = 30
# hostBins[2690] =  30
# CPU and GPU results are  equal.
# resultRef[2691] = 38
# hostBins[2691] =  38
# CPU and GPU results are  equal.
# resultRef[2692] = 30
# hostBins[2692] =  30
# CPU and GPU results are  equal.
# resultRef[2693] = 24
# hostBins[2693] =  24
# CPU and GPU results are  equal.
# resultRef[2694] = 38
# hostBins[2694] =  38
# CPU and GPU results are  equal.
# resultRef[2695] = 26
# hostBins[2695] =  26
# CPU and GPU results are  equal.
# resultRef[2696] = 43
# hostBins[2696] =  43
# CPU and GPU results are  equal.
# resultRef[2697] = 31
# hostBins[2697] =  31
# CPU and GPU results are  equal.
# resultRef[2698] = 33
# hostBins[2698] =  33
# CPU and GPU results are  equal.
# resultRef[2699] = 40
# hostBins[2699] =  40
# CPU and GPU results are  equal.
# resultRef[2700] = 31
# hostBins[2700] =  31
# CPU and GPU results are  equal.
# resultRef[2701] = 29
# hostBins[2701] =  29
# CPU and GPU results are  equal.
# resultRef[2702] = 42
# hostBins[2702] =  42
# CPU and GPU results are  equal.
# resultRef[2703] = 40
# hostBins[2703] =  40
# CPU and GPU results are  equal.
# resultRef[2704] = 29
# hostBins[2704] =  29
# CPU and GPU results are  equal.
# resultRef[2705] = 44
# hostBins[2705] =  44
# CPU and GPU results are  equal.
# resultRef[2706] = 28
# hostBins[2706] =  28
# CPU and GPU results are  equal.
# resultRef[2707] = 33
# hostBins[2707] =  33
# CPU and GPU results are  equal.
# resultRef[2708] = 20
# hostBins[2708] =  20
# CPU and GPU results are  equal.
# resultRef[2709] = 28
# hostBins[2709] =  28
# CPU and GPU results are  equal.
# resultRef[2710] = 36
# hostBins[2710] =  36
# CPU and GPU results are  equal.
# resultRef[2711] = 39
# hostBins[2711] =  39
# CPU and GPU results are  equal.
# resultRef[2712] = 27
# hostBins[2712] =  27
# CPU and GPU results are  equal.
# resultRef[2713] = 30
# hostBins[2713] =  30
# CPU and GPU results are  equal.
# resultRef[2714] = 25
# hostBins[2714] =  25
# CPU and GPU results are  equal.
# resultRef[2715] = 34
# hostBins[2715] =  34
# CPU and GPU results are  equal.
# resultRef[2716] = 29
# hostBins[2716] =  29
# CPU and GPU results are  equal.
# resultRef[2717] = 30
# hostBins[2717] =  30
# CPU and GPU results are  equal.
# resultRef[2718] = 35
# hostBins[2718] =  35
# CPU and GPU results are  equal.
# resultRef[2719] = 33
# hostBins[2719] =  33
# CPU and GPU results are  equal.
# resultRef[2720] = 35
# hostBins[2720] =  35
# CPU and GPU results are  equal.
# resultRef[2721] = 36
# hostBins[2721] =  36
# CPU and GPU results are  equal.
# resultRef[2722] = 33
# hostBins[2722] =  33
# CPU and GPU results are  equal.
# resultRef[2723] = 34
# hostBins[2723] =  34
# CPU and GPU results are  equal.
# resultRef[2724] = 30
# hostBins[2724] =  30
# CPU and GPU results are  equal.
# resultRef[2725] = 30
# hostBins[2725] =  30
# CPU and GPU results are  equal.
# resultRef[2726] = 31
# hostBins[2726] =  31
# CPU and GPU results are  equal.
# resultRef[2727] = 28
# hostBins[2727] =  28
# CPU and GPU results are  equal.
# resultRef[2728] = 36
# hostBins[2728] =  36
# CPU and GPU results are  equal.
# resultRef[2729] = 20
# hostBins[2729] =  20
# CPU and GPU results are  equal.
# resultRef[2730] = 35
# hostBins[2730] =  35
# CPU and GPU results are  equal.
# resultRef[2731] = 39
# hostBins[2731] =  39
# CPU and GPU results are  equal.
# resultRef[2732] = 27
# hostBins[2732] =  27
# CPU and GPU results are  equal.
# resultRef[2733] = 27
# hostBins[2733] =  27
# CPU and GPU results are  equal.
# resultRef[2734] = 36
# hostBins[2734] =  36
# CPU and GPU results are  equal.
# resultRef[2735] = 33
# hostBins[2735] =  33
# CPU and GPU results are  equal.
# resultRef[2736] = 34
# hostBins[2736] =  34
# CPU and GPU results are  equal.
# resultRef[2737] = 26
# hostBins[2737] =  26
# CPU and GPU results are  equal.
# resultRef[2738] = 35
# hostBins[2738] =  35
# CPU and GPU results are  equal.
# resultRef[2739] = 33
# hostBins[2739] =  33
# CPU and GPU results are  equal.
# resultRef[2740] = 34
# hostBins[2740] =  34
# CPU and GPU results are  equal.
# resultRef[2741] = 30
# hostBins[2741] =  30
# CPU and GPU results are  equal.
# resultRef[2742] = 29
# hostBins[2742] =  29
# CPU and GPU results are  equal.
# resultRef[2743] = 31
# hostBins[2743] =  31
# CPU and GPU results are  equal.
# resultRef[2744] = 35
# hostBins[2744] =  35
# CPU and GPU results are  equal.
# resultRef[2745] = 30
# hostBins[2745] =  30
# CPU and GPU results are  equal.
# resultRef[2746] = 36
# hostBins[2746] =  36
# CPU and GPU results are  equal.
# resultRef[2747] = 28
# hostBins[2747] =  28
# CPU and GPU results are  equal.
# resultRef[2748] = 38
# hostBins[2748] =  38
# CPU and GPU results are  equal.
# resultRef[2749] = 33
# hostBins[2749] =  33
# CPU and GPU results are  equal.
# resultRef[2750] = 31
# hostBins[2750] =  31
# CPU and GPU results are  equal.
# resultRef[2751] = 29
# hostBins[2751] =  29
# CPU and GPU results are  equal.
# resultRef[2752] = 31
# hostBins[2752] =  31
# CPU and GPU results are  equal.
# resultRef[2753] = 40
# hostBins[2753] =  40
# CPU and GPU results are  equal.
# resultRef[2754] = 19
# hostBins[2754] =  19
# CPU and GPU results are  equal.
# resultRef[2755] = 30
# hostBins[2755] =  30
# CPU and GPU results are  equal.
# resultRef[2756] = 34
# hostBins[2756] =  34
# CPU and GPU results are  equal.
# resultRef[2757] = 31
# hostBins[2757] =  31
# CPU and GPU results are  equal.
# resultRef[2758] = 30
# hostBins[2758] =  30
# CPU and GPU results are  equal.
# resultRef[2759] = 32
# hostBins[2759] =  32
# CPU and GPU results are  equal.
# resultRef[2760] = 29
# hostBins[2760] =  29
# CPU and GPU results are  equal.
# resultRef[2761] = 33
# hostBins[2761] =  33
# CPU and GPU results are  equal.
# resultRef[2762] = 36
# hostBins[2762] =  36
# CPU and GPU results are  equal.
# resultRef[2763] = 24
# hostBins[2763] =  24
# CPU and GPU results are  equal.
# resultRef[2764] = 35
# hostBins[2764] =  35
# CPU and GPU results are  equal.
# resultRef[2765] = 36
# hostBins[2765] =  36
# CPU and GPU results are  equal.
# resultRef[2766] = 41
# hostBins[2766] =  41
# CPU and GPU results are  equal.
# resultRef[2767] = 26
# hostBins[2767] =  26
# CPU and GPU results are  equal.
# resultRef[2768] = 42
# hostBins[2768] =  42
# CPU and GPU results are  equal.
# resultRef[2769] = 24
# hostBins[2769] =  24
# CPU and GPU results are  equal.
# resultRef[2770] = 30
# hostBins[2770] =  30
# CPU and GPU results are  equal.
# resultRef[2771] = 35
# hostBins[2771] =  35
# CPU and GPU results are  equal.
# resultRef[2772] = 26
# hostBins[2772] =  26
# CPU and GPU results are  equal.
# resultRef[2773] = 26
# hostBins[2773] =  26
# CPU and GPU results are  equal.
# resultRef[2774] = 30
# hostBins[2774] =  30
# CPU and GPU results are  equal.
# resultRef[2775] = 38
# hostBins[2775] =  38
# CPU and GPU results are  equal.
# resultRef[2776] = 40
# hostBins[2776] =  40
# CPU and GPU results are  equal.
# resultRef[2777] = 28
# hostBins[2777] =  28
# CPU and GPU results are  equal.
# resultRef[2778] = 30
# hostBins[2778] =  30
# CPU and GPU results are  equal.
# resultRef[2779] = 33
# hostBins[2779] =  33
# CPU and GPU results are  equal.
# resultRef[2780] = 22
# hostBins[2780] =  22
# CPU and GPU results are  equal.
# resultRef[2781] = 25
# hostBins[2781] =  25
# CPU and GPU results are  equal.
# resultRef[2782] = 28
# hostBins[2782] =  28
# CPU and GPU results are  equal.
# resultRef[2783] = 44
# hostBins[2783] =  44
# CPU and GPU results are  equal.
# resultRef[2784] = 36
# hostBins[2784] =  36
# CPU and GPU results are  equal.
# resultRef[2785] = 26
# hostBins[2785] =  26
# CPU and GPU results are  equal.
# resultRef[2786] = 28
# hostBins[2786] =  28
# CPU and GPU results are  equal.
# resultRef[2787] = 29
# hostBins[2787] =  29
# CPU and GPU results are  equal.
# resultRef[2788] = 23
# hostBins[2788] =  23
# CPU and GPU results are  equal.
# resultRef[2789] = 25
# hostBins[2789] =  25
# CPU and GPU results are  equal.
# resultRef[2790] = 30
# hostBins[2790] =  30
# CPU and GPU results are  equal.
# resultRef[2791] = 31
# hostBins[2791] =  31
# CPU and GPU results are  equal.
# resultRef[2792] = 31
# hostBins[2792] =  31
# CPU and GPU results are  equal.
# resultRef[2793] = 25
# hostBins[2793] =  25
# CPU and GPU results are  equal.
# resultRef[2794] = 35
# hostBins[2794] =  35
# CPU and GPU results are  equal.
# resultRef[2795] = 33
# hostBins[2795] =  33
# CPU and GPU results are  equal.
# resultRef[2796] = 38
# hostBins[2796] =  38
# CPU and GPU results are  equal.
# resultRef[2797] = 36
# hostBins[2797] =  36
# CPU and GPU results are  equal.
# resultRef[2798] = 26
# hostBins[2798] =  26
# CPU and GPU results are  equal.
# resultRef[2799] = 21
# hostBins[2799] =  21
# CPU and GPU results are  equal.
# resultRef[2800] = 26
# hostBins[2800] =  26
# CPU and GPU results are  equal.
# resultRef[2801] = 27
# hostBins[2801] =  27
# CPU and GPU results are  equal.
# resultRef[2802] = 37
# hostBins[2802] =  37
# CPU and GPU results are  equal.
# resultRef[2803] = 25
# hostBins[2803] =  25
# CPU and GPU results are  equal.
# resultRef[2804] = 32
# hostBins[2804] =  32
# CPU and GPU results are  equal.
# resultRef[2805] = 41
# hostBins[2805] =  41
# CPU and GPU results are  equal.
# resultRef[2806] = 36
# hostBins[2806] =  36
# CPU and GPU results are  equal.
# resultRef[2807] = 39
# hostBins[2807] =  39
# CPU and GPU results are  equal.
# resultRef[2808] = 31
# hostBins[2808] =  31
# CPU and GPU results are  equal.
# resultRef[2809] = 33
# hostBins[2809] =  33
# CPU and GPU results are  equal.
# resultRef[2810] = 30
# hostBins[2810] =  30
# CPU and GPU results are  equal.
# resultRef[2811] = 26
# hostBins[2811] =  26
# CPU and GPU results are  equal.
# resultRef[2812] = 33
# hostBins[2812] =  33
# CPU and GPU results are  equal.
# resultRef[2813] = 30
# hostBins[2813] =  30
# CPU and GPU results are  equal.
# resultRef[2814] = 29
# hostBins[2814] =  29
# CPU and GPU results are  equal.
# resultRef[2815] = 22
# hostBins[2815] =  22
# CPU and GPU results are  equal.
# resultRef[2816] = 36
# hostBins[2816] =  36
# CPU and GPU results are  equal.
# resultRef[2817] = 45
# hostBins[2817] =  45
# CPU and GPU results are  equal.
# resultRef[2818] = 30
# hostBins[2818] =  30
# CPU and GPU results are  equal.
# resultRef[2819] = 28
# hostBins[2819] =  28
# CPU and GPU results are  equal.
# resultRef[2820] = 45
# hostBins[2820] =  45
# CPU and GPU results are  equal.
# resultRef[2821] = 30
# hostBins[2821] =  30
# CPU and GPU results are  equal.
# resultRef[2822] = 28
# hostBins[2822] =  28
# CPU and GPU results are  equal.
# resultRef[2823] = 30
# hostBins[2823] =  30
# CPU and GPU results are  equal.
# resultRef[2824] = 37
# hostBins[2824] =  37
# CPU and GPU results are  equal.
# resultRef[2825] = 30
# hostBins[2825] =  30
# CPU and GPU results are  equal.
# resultRef[2826] = 31
# hostBins[2826] =  31
# CPU and GPU results are  equal.
# resultRef[2827] = 30
# hostBins[2827] =  30
# CPU and GPU results are  equal.
# resultRef[2828] = 33
# hostBins[2828] =  33
# CPU and GPU results are  equal.
# resultRef[2829] = 26
# hostBins[2829] =  26
# CPU and GPU results are  equal.
# resultRef[2830] = 32
# hostBins[2830] =  32
# CPU and GPU results are  equal.
# resultRef[2831] = 37
# hostBins[2831] =  37
# CPU and GPU results are  equal.
# resultRef[2832] = 32
# hostBins[2832] =  32
# CPU and GPU results are  equal.
# resultRef[2833] = 27
# hostBins[2833] =  27
# CPU and GPU results are  equal.
# resultRef[2834] = 35
# hostBins[2834] =  35
# CPU and GPU results are  equal.
# resultRef[2835] = 22
# hostBins[2835] =  22
# CPU and GPU results are  equal.
# resultRef[2836] = 39
# hostBins[2836] =  39
# CPU and GPU results are  equal.
# resultRef[2837] = 30
# hostBins[2837] =  30
# CPU and GPU results are  equal.
# resultRef[2838] = 31
# hostBins[2838] =  31
# CPU and GPU results are  equal.
# resultRef[2839] = 34
# hostBins[2839] =  34
# CPU and GPU results are  equal.
# resultRef[2840] = 34
# hostBins[2840] =  34
# CPU and GPU results are  equal.
# resultRef[2841] = 18
# hostBins[2841] =  18
# CPU and GPU results are  equal.
# resultRef[2842] = 29
# hostBins[2842] =  29
# CPU and GPU results are  equal.
# resultRef[2843] = 38
# hostBins[2843] =  38
# CPU and GPU results are  equal.
# resultRef[2844] = 29
# hostBins[2844] =  29
# CPU and GPU results are  equal.
# resultRef[2845] = 40
# hostBins[2845] =  40
# CPU and GPU results are  equal.
# resultRef[2846] = 29
# hostBins[2846] =  29
# CPU and GPU results are  equal.
# resultRef[2847] = 35
# hostBins[2847] =  35
# CPU and GPU results are  equal.
# resultRef[2848] = 23
# hostBins[2848] =  23
# CPU and GPU results are  equal.
# resultRef[2849] = 32
# hostBins[2849] =  32
# CPU and GPU results are  equal.
# resultRef[2850] = 35
# hostBins[2850] =  35
# CPU and GPU results are  equal.
# resultRef[2851] = 32
# hostBins[2851] =  32
# CPU and GPU results are  equal.
# resultRef[2852] = 35
# hostBins[2852] =  35
# CPU and GPU results are  equal.
# resultRef[2853] = 45
# hostBins[2853] =  45
# CPU and GPU results are  equal.
# resultRef[2854] = 36
# hostBins[2854] =  36
# CPU and GPU results are  equal.
# resultRef[2855] = 36
# hostBins[2855] =  36
# CPU and GPU results are  equal.
# resultRef[2856] = 36
# hostBins[2856] =  36
# CPU and GPU results are  equal.
# resultRef[2857] = 40
# hostBins[2857] =  40
# CPU and GPU results are  equal.
# resultRef[2858] = 32
# hostBins[2858] =  32
# CPU and GPU results are  equal.
# resultRef[2859] = 29
# hostBins[2859] =  29
# CPU and GPU results are  equal.
# resultRef[2860] = 33
# hostBins[2860] =  33
# CPU and GPU results are  equal.
# resultRef[2861] = 27
# hostBins[2861] =  27
# CPU and GPU results are  equal.
# resultRef[2862] = 30
# hostBins[2862] =  30
# CPU and GPU results are  equal.
# resultRef[2863] = 30
# hostBins[2863] =  30
# CPU and GPU results are  equal.
# resultRef[2864] = 28
# hostBins[2864] =  28
# CPU and GPU results are  equal.
# resultRef[2865] = 39
# hostBins[2865] =  39
# CPU and GPU results are  equal.
# resultRef[2866] = 37
# hostBins[2866] =  37
# CPU and GPU results are  equal.
# resultRef[2867] = 37
# hostBins[2867] =  37
# CPU and GPU results are  equal.
# resultRef[2868] = 27
# hostBins[2868] =  27
# CPU and GPU results are  equal.
# resultRef[2869] = 36
# hostBins[2869] =  36
# CPU and GPU results are  equal.
# resultRef[2870] = 33
# hostBins[2870] =  33
# CPU and GPU results are  equal.
# resultRef[2871] = 32
# hostBins[2871] =  32
# CPU and GPU results are  equal.
# resultRef[2872] = 31
# hostBins[2872] =  31
# CPU and GPU results are  equal.
# resultRef[2873] = 31
# hostBins[2873] =  31
# CPU and GPU results are  equal.
# resultRef[2874] = 35
# hostBins[2874] =  35
# CPU and GPU results are  equal.
# resultRef[2875] = 32
# hostBins[2875] =  32
# CPU and GPU results are  equal.
# resultRef[2876] = 28
# hostBins[2876] =  28
# CPU and GPU results are  equal.
# resultRef[2877] = 31
# hostBins[2877] =  31
# CPU and GPU results are  equal.
# resultRef[2878] = 30
# hostBins[2878] =  30
# CPU and GPU results are  equal.
# resultRef[2879] = 22
# hostBins[2879] =  22
# CPU and GPU results are  equal.
# resultRef[2880] = 38
# hostBins[2880] =  38
# CPU and GPU results are  equal.
# resultRef[2881] = 37
# hostBins[2881] =  37
# CPU and GPU results are  equal.
# resultRef[2882] = 36
# hostBins[2882] =  36
# CPU and GPU results are  equal.
# resultRef[2883] = 43
# hostBins[2883] =  43
# CPU and GPU results are  equal.
# resultRef[2884] = 34
# hostBins[2884] =  34
# CPU and GPU results are  equal.
# resultRef[2885] = 28
# hostBins[2885] =  28
# CPU and GPU results are  equal.
# resultRef[2886] = 28
# hostBins[2886] =  28
# CPU and GPU results are  equal.
# resultRef[2887] = 28
# hostBins[2887] =  28
# CPU and GPU results are  equal.
# resultRef[2888] = 29
# hostBins[2888] =  29
# CPU and GPU results are  equal.
# resultRef[2889] = 31
# hostBins[2889] =  31
# CPU and GPU results are  equal.
# resultRef[2890] = 29
# hostBins[2890] =  29
# CPU and GPU results are  equal.
# resultRef[2891] = 29
# hostBins[2891] =  29
# CPU and GPU results are  equal.
# resultRef[2892] = 29
# hostBins[2892] =  29
# CPU and GPU results are  equal.
# resultRef[2893] = 29
# hostBins[2893] =  29
# CPU and GPU results are  equal.
# resultRef[2894] = 30
# hostBins[2894] =  30
# CPU and GPU results are  equal.
# resultRef[2895] = 33
# hostBins[2895] =  33
# CPU and GPU results are  equal.
# resultRef[2896] = 39
# hostBins[2896] =  39
# CPU and GPU results are  equal.
# resultRef[2897] = 46
# hostBins[2897] =  46
# CPU and GPU results are  equal.
# resultRef[2898] = 27
# hostBins[2898] =  27
# CPU and GPU results are  equal.
# resultRef[2899] = 34
# hostBins[2899] =  34
# CPU and GPU results are  equal.
# resultRef[2900] = 27
# hostBins[2900] =  27
# CPU and GPU results are  equal.
# resultRef[2901] = 26
# hostBins[2901] =  26
# CPU and GPU results are  equal.
# resultRef[2902] = 22
# hostBins[2902] =  22
# CPU and GPU results are  equal.
# resultRef[2903] = 40
# hostBins[2903] =  40
# CPU and GPU results are  equal.
# resultRef[2904] = 34
# hostBins[2904] =  34
# CPU and GPU results are  equal.
# resultRef[2905] = 36
# hostBins[2905] =  36
# CPU and GPU results are  equal.
# resultRef[2906] = 35
# hostBins[2906] =  35
# CPU and GPU results are  equal.
# resultRef[2907] = 30
# hostBins[2907] =  30
# CPU and GPU results are  equal.
# resultRef[2908] = 35
# hostBins[2908] =  35
# CPU and GPU results are  equal.
# resultRef[2909] = 21
# hostBins[2909] =  21
# CPU and GPU results are  equal.
# resultRef[2910] = 31
# hostBins[2910] =  31
# CPU and GPU results are  equal.
# resultRef[2911] = 32
# hostBins[2911] =  32
# CPU and GPU results are  equal.
# resultRef[2912] = 23
# hostBins[2912] =  23
# CPU and GPU results are  equal.
# resultRef[2913] = 30
# hostBins[2913] =  30
# CPU and GPU results are  equal.
# resultRef[2914] = 21
# hostBins[2914] =  21
# CPU and GPU results are  equal.
# resultRef[2915] = 29
# hostBins[2915] =  29
# CPU and GPU results are  equal.
# resultRef[2916] = 34
# hostBins[2916] =  34
# CPU and GPU results are  equal.
# resultRef[2917] = 33
# hostBins[2917] =  33
# CPU and GPU results are  equal.
# resultRef[2918] = 31
# hostBins[2918] =  31
# CPU and GPU results are  equal.
# resultRef[2919] = 33
# hostBins[2919] =  33
# CPU and GPU results are  equal.
# resultRef[2920] = 29
# hostBins[2920] =  29
# CPU and GPU results are  equal.
# resultRef[2921] = 30
# hostBins[2921] =  30
# CPU and GPU results are  equal.
# resultRef[2922] = 35
# hostBins[2922] =  35
# CPU and GPU results are  equal.
# resultRef[2923] = 32
# hostBins[2923] =  32
# CPU and GPU results are  equal.
# resultRef[2924] = 33
# hostBins[2924] =  33
# CPU and GPU results are  equal.
# resultRef[2925] = 28
# hostBins[2925] =  28
# CPU and GPU results are  equal.
# resultRef[2926] = 27
# hostBins[2926] =  27
# CPU and GPU results are  equal.
# resultRef[2927] = 33
# hostBins[2927] =  33
# CPU and GPU results are  equal.
# resultRef[2928] = 21
# hostBins[2928] =  21
# CPU and GPU results are  equal.
# resultRef[2929] = 23
# hostBins[2929] =  23
# CPU and GPU results are  equal.
# resultRef[2930] = 29
# hostBins[2930] =  29
# CPU and GPU results are  equal.
# resultRef[2931] = 24
# hostBins[2931] =  24
# CPU and GPU results are  equal.
# resultRef[2932] = 42
# hostBins[2932] =  42
# CPU and GPU results are  equal.
# resultRef[2933] = 27
# hostBins[2933] =  27
# CPU and GPU results are  equal.
# resultRef[2934] = 23
# hostBins[2934] =  23
# CPU and GPU results are  equal.
# resultRef[2935] = 28
# hostBins[2935] =  28
# CPU and GPU results are  equal.
# resultRef[2936] = 26
# hostBins[2936] =  26
# CPU and GPU results are  equal.
# resultRef[2937] = 37
# hostBins[2937] =  37
# CPU and GPU results are  equal.
# resultRef[2938] = 29
# hostBins[2938] =  29
# CPU and GPU results are  equal.
# resultRef[2939] = 32
# hostBins[2939] =  32
# CPU and GPU results are  equal.
# resultRef[2940] = 25
# hostBins[2940] =  25
# CPU and GPU results are  equal.
# resultRef[2941] = 37
# hostBins[2941] =  37
# CPU and GPU results are  equal.
# resultRef[2942] = 35
# hostBins[2942] =  35
# CPU and GPU results are  equal.
# resultRef[2943] = 42
# hostBins[2943] =  42
# CPU and GPU results are  equal.
# resultRef[2944] = 28
# hostBins[2944] =  28
# CPU and GPU results are  equal.
# resultRef[2945] = 35
# hostBins[2945] =  35
# CPU and GPU results are  equal.
# resultRef[2946] = 42
# hostBins[2946] =  42
# CPU and GPU results are  equal.
# resultRef[2947] = 29
# hostBins[2947] =  29
# CPU and GPU results are  equal.
# resultRef[2948] = 27
# hostBins[2948] =  27
# CPU and GPU results are  equal.
# resultRef[2949] = 45
# hostBins[2949] =  45
# CPU and GPU results are  equal.
# resultRef[2950] = 28
# hostBins[2950] =  28
# CPU and GPU results are  equal.
# resultRef[2951] = 35
# hostBins[2951] =  35
# CPU and GPU results are  equal.
# resultRef[2952] = 48
# hostBins[2952] =  48
# CPU and GPU results are  equal.
# resultRef[2953] = 39
# hostBins[2953] =  39
# CPU and GPU results are  equal.
# resultRef[2954] = 38
# hostBins[2954] =  38
# CPU and GPU results are  equal.
# resultRef[2955] = 32
# hostBins[2955] =  32
# CPU and GPU results are  equal.
# resultRef[2956] = 34
# hostBins[2956] =  34
# CPU and GPU results are  equal.
# resultRef[2957] = 35
# hostBins[2957] =  35
# CPU and GPU results are  equal.
# resultRef[2958] = 33
# hostBins[2958] =  33
# CPU and GPU results are  equal.
# resultRef[2959] = 34
# hostBins[2959] =  34
# CPU and GPU results are  equal.
# resultRef[2960] = 35
# hostBins[2960] =  35
# CPU and GPU results are  equal.
# resultRef[2961] = 24
# hostBins[2961] =  24
# CPU and GPU results are  equal.
# resultRef[2962] = 31
# hostBins[2962] =  31
# CPU and GPU results are  equal.
# resultRef[2963] = 35
# hostBins[2963] =  35
# CPU and GPU results are  equal.
# resultRef[2964] = 25
# hostBins[2964] =  25
# CPU and GPU results are  equal.
# resultRef[2965] = 47
# hostBins[2965] =  47
# CPU and GPU results are  equal.
# resultRef[2966] = 38
# hostBins[2966] =  38
# CPU and GPU results are  equal.
# resultRef[2967] = 40
# hostBins[2967] =  40
# CPU and GPU results are  equal.
# resultRef[2968] = 31
# hostBins[2968] =  31
# CPU and GPU results are  equal.
# resultRef[2969] = 28
# hostBins[2969] =  28
# CPU and GPU results are  equal.
# resultRef[2970] = 35
# hostBins[2970] =  35
# CPU and GPU results are  equal.
# resultRef[2971] = 29
# hostBins[2971] =  29
# CPU and GPU results are  equal.
# resultRef[2972] = 26
# hostBins[2972] =  26
# CPU and GPU results are  equal.
# resultRef[2973] = 40
# hostBins[2973] =  40
# CPU and GPU results are  equal.
# resultRef[2974] = 22
# hostBins[2974] =  22
# CPU and GPU results are  equal.
# resultRef[2975] = 31
# hostBins[2975] =  31
# CPU and GPU results are  equal.
# resultRef[2976] = 25
# hostBins[2976] =  25
# CPU and GPU results are  equal.
# resultRef[2977] = 27
# hostBins[2977] =  27
# CPU and GPU results are  equal.
# resultRef[2978] = 32
# hostBins[2978] =  32
# CPU and GPU results are  equal.
# resultRef[2979] = 23
# hostBins[2979] =  23
# CPU and GPU results are  equal.
# resultRef[2980] = 27
# hostBins[2980] =  27
# CPU and GPU results are  equal.
# resultRef[2981] = 33
# hostBins[2981] =  33
# CPU and GPU results are  equal.
# resultRef[2982] = 30
# hostBins[2982] =  30
# CPU and GPU results are  equal.
# resultRef[2983] = 32
# hostBins[2983] =  32
# CPU and GPU results are  equal.
# resultRef[2984] = 29
# hostBins[2984] =  29
# CPU and GPU results are  equal.
# resultRef[2985] = 30
# hostBins[2985] =  30
# CPU and GPU results are  equal.
# resultRef[2986] = 36
# hostBins[2986] =  36
# CPU and GPU results are  equal.
# resultRef[2987] = 27
# hostBins[2987] =  27
# CPU and GPU results are  equal.
# resultRef[2988] = 33
# hostBins[2988] =  33
# CPU and GPU results are  equal.
# resultRef[2989] = 25
# hostBins[2989] =  25
# CPU and GPU results are  equal.
# resultRef[2990] = 29
# hostBins[2990] =  29
# CPU and GPU results are  equal.
# resultRef[2991] = 46
# hostBins[2991] =  46
# CPU and GPU results are  equal.
# resultRef[2992] = 30
# hostBins[2992] =  30
# CPU and GPU results are  equal.
# resultRef[2993] = 28
# hostBins[2993] =  28
# CPU and GPU results are  equal.
# resultRef[2994] = 32
# hostBins[2994] =  32
# CPU and GPU results are  equal.
# resultRef[2995] = 32
# hostBins[2995] =  32
# CPU and GPU results are  equal.
# resultRef[2996] = 28
# hostBins[2996] =  28
# CPU and GPU results are  equal.
# resultRef[2997] = 27
# hostBins[2997] =  27
# CPU and GPU results are  equal.
# resultRef[2998] = 38
# hostBins[2998] =  38
# CPU and GPU results are  equal.
# resultRef[2999] = 34
# hostBins[2999] =  34
# CPU and GPU results are  equal.
# resultRef[3000] = 26
# hostBins[3000] =  26
# CPU and GPU results are  equal.
# resultRef[3001] = 27
# hostBins[3001] =  27
# CPU and GPU results are  equal.
# resultRef[3002] = 33
# hostBins[3002] =  33
# CPU and GPU results are  equal.
# resultRef[3003] = 37
# hostBins[3003] =  37
# CPU and GPU results are  equal.
# resultRef[3004] = 32
# hostBins[3004] =  32
# CPU and GPU results are  equal.
# resultRef[3005] = 31
# hostBins[3005] =  31
# CPU and GPU results are  equal.
# resultRef[3006] = 32
# hostBins[3006] =  32
# CPU and GPU results are  equal.
# resultRef[3007] = 32
# hostBins[3007] =  32
# CPU and GPU results are  equal.
# resultRef[3008] = 31
# hostBins[3008] =  31
# CPU and GPU results are  equal.
# resultRef[3009] = 41
# hostBins[3009] =  41
# CPU and GPU results are  equal.
# resultRef[3010] = 22
# hostBins[3010] =  22
# CPU and GPU results are  equal.
# resultRef[3011] = 37
# hostBins[3011] =  37
# CPU and GPU results are  equal.
# resultRef[3012] = 26
# hostBins[3012] =  26
# CPU and GPU results are  equal.
# resultRef[3013] = 38
# hostBins[3013] =  38
# CPU and GPU results are  equal.
# resultRef[3014] = 33
# hostBins[3014] =  33
# CPU and GPU results are  equal.
# resultRef[3015] = 31
# hostBins[3015] =  31
# CPU and GPU results are  equal.
# resultRef[3016] = 32
# hostBins[3016] =  32
# CPU and GPU results are  equal.
# resultRef[3017] = 34
# hostBins[3017] =  34
# CPU and GPU results are  equal.
# resultRef[3018] = 32
# hostBins[3018] =  32
# CPU and GPU results are  equal.
# resultRef[3019] = 35
# hostBins[3019] =  35
# CPU and GPU results are  equal.
# resultRef[3020] = 28
# hostBins[3020] =  28
# CPU and GPU results are  equal.
# resultRef[3021] = 30
# hostBins[3021] =  30
# CPU and GPU results are  equal.
# resultRef[3022] = 35
# hostBins[3022] =  35
# CPU and GPU results are  equal.
# resultRef[3023] = 34
# hostBins[3023] =  34
# CPU and GPU results are  equal.
# resultRef[3024] = 37
# hostBins[3024] =  37
# CPU and GPU results are  equal.
# resultRef[3025] = 37
# hostBins[3025] =  37
# CPU and GPU results are  equal.
# resultRef[3026] = 36
# hostBins[3026] =  36
# CPU and GPU results are  equal.
# resultRef[3027] = 30
# hostBins[3027] =  30
# CPU and GPU results are  equal.
# resultRef[3028] = 41
# hostBins[3028] =  41
# CPU and GPU results are  equal.
# resultRef[3029] = 39
# hostBins[3029] =  39
# CPU and GPU results are  equal.
# resultRef[3030] = 29
# hostBins[3030] =  29
# CPU and GPU results are  equal.
# resultRef[3031] = 25
# hostBins[3031] =  25
# CPU and GPU results are  equal.
# resultRef[3032] = 34
# hostBins[3032] =  34
# CPU and GPU results are  equal.
# resultRef[3033] = 36
# hostBins[3033] =  36
# CPU and GPU results are  equal.
# resultRef[3034] = 30
# hostBins[3034] =  30
# CPU and GPU results are  equal.
# resultRef[3035] = 26
# hostBins[3035] =  26
# CPU and GPU results are  equal.
# resultRef[3036] = 31
# hostBins[3036] =  31
# CPU and GPU results are  equal.
# resultRef[3037] = 27
# hostBins[3037] =  27
# CPU and GPU results are  equal.
# resultRef[3038] = 34
# hostBins[3038] =  34
# CPU and GPU results are  equal.
# resultRef[3039] = 36
# hostBins[3039] =  36
# CPU and GPU results are  equal.
# resultRef[3040] = 30
# hostBins[3040] =  30
# CPU and GPU results are  equal.
# resultRef[3041] = 33
# hostBins[3041] =  33
# CPU and GPU results are  equal.
# resultRef[3042] = 26
# hostBins[3042] =  26
# CPU and GPU results are  equal.
# resultRef[3043] = 33
# hostBins[3043] =  33
# CPU and GPU results are  equal.
# resultRef[3044] = 26
# hostBins[3044] =  26
# CPU and GPU results are  equal.
# resultRef[3045] = 29
# hostBins[3045] =  29
# CPU and GPU results are  equal.
# resultRef[3046] = 30
# hostBins[3046] =  30
# CPU and GPU results are  equal.
# resultRef[3047] = 36
# hostBins[3047] =  36
# CPU and GPU results are  equal.
# resultRef[3048] = 33
# hostBins[3048] =  33
# CPU and GPU results are  equal.
# resultRef[3049] = 32
# hostBins[3049] =  32
# CPU and GPU results are  equal.
# resultRef[3050] = 45
# hostBins[3050] =  45
# CPU and GPU results are  equal.
# resultRef[3051] = 42
# hostBins[3051] =  42
# CPU and GPU results are  equal.
# resultRef[3052] = 16
# hostBins[3052] =  16
# CPU and GPU results are  equal.
# resultRef[3053] = 27
# hostBins[3053] =  27
# CPU and GPU results are  equal.
# resultRef[3054] = 37
# hostBins[3054] =  37
# CPU and GPU results are  equal.
# resultRef[3055] = 27
# hostBins[3055] =  27
# CPU and GPU results are  equal.
# resultRef[3056] = 42
# hostBins[3056] =  42
# CPU and GPU results are  equal.
# resultRef[3057] = 43
# hostBins[3057] =  43
# CPU and GPU results are  equal.
# resultRef[3058] = 24
# hostBins[3058] =  24
# CPU and GPU results are  equal.
# resultRef[3059] = 32
# hostBins[3059] =  32
# CPU and GPU results are  equal.
# resultRef[3060] = 38
# hostBins[3060] =  38
# CPU and GPU results are  equal.
# resultRef[3061] = 16
# hostBins[3061] =  16
# CPU and GPU results are  equal.
# resultRef[3062] = 35
# hostBins[3062] =  35
# CPU and GPU results are  equal.
# resultRef[3063] = 28
# hostBins[3063] =  28
# CPU and GPU results are  equal.
# resultRef[3064] = 25
# hostBins[3064] =  25
# CPU and GPU results are  equal.
# resultRef[3065] = 27
# hostBins[3065] =  27
# CPU and GPU results are  equal.
# resultRef[3066] = 26
# hostBins[3066] =  26
# CPU and GPU results are  equal.
# resultRef[3067] = 29
# hostBins[3067] =  29
# CPU and GPU results are  equal.
# resultRef[3068] = 37
# hostBins[3068] =  37
# CPU and GPU results are  equal.
# resultRef[3069] = 39
# hostBins[3069] =  39
# CPU and GPU results are  equal.
# resultRef[3070] = 33
# hostBins[3070] =  33
# CPU and GPU results are  equal.
# resultRef[3071] = 30
# hostBins[3071] =  30
# CPU and GPU results are  equal.
# resultRef[3072] = 37
# hostBins[3072] =  37
# CPU and GPU results are  equal.
# resultRef[3073] = 24
# hostBins[3073] =  24
# CPU and GPU results are  equal.
# resultRef[3074] = 39
# hostBins[3074] =  39
# CPU and GPU results are  equal.
# resultRef[3075] = 34
# hostBins[3075] =  34
# CPU and GPU results are  equal.
# resultRef[3076] = 34
# hostBins[3076] =  34
# CPU and GPU results are  equal.
# resultRef[3077] = 26
# hostBins[3077] =  26
# ...
# resultRef[3880] = 30
# hostBins[3880] =  30
# CPU and GPU results are  equal.
# resultRef[3881] = 28
# hostBins[3881] =  28
# CPU and GPU results are  equal.
# resultRef[3882] = 37
# hostBins[3882] =  37
# CPU and GPU results are  equal.
# resultRef[3883] = 32
# hostBins[3883] =  32
# CPU and GPU results are  equal.
# resultRef[3884] = 27
# hostBins[3884] =  27
# CPU and GPU results are  equal.
# resultRef[3885] = 33
# hostBins[3885] =  33
# CPU and GPU results are  equal.
# resultRef[3886] = 35
# hostBins[3886] =  35
# CPU and GPU results are  equal.
# resultRef[3887] = 29
# hostBins[3887] =  29
# CPU and GPU results are  equal.
# resultRef[3888] = 27
# hostBins[3888] =  27
# CPU and GPU results are  equal.
# resultRef[3889] = 34
# hostBins[3889] =  34
# CPU and GPU results are  equal.
# resultRef[3890] = 32
# hostBins[3890] =  32
# CPU and GPU results are  equal.
# resultRef[3891] = 23
# hostBins[3891] =  23
# CPU and GPU results are  equal.
# resultRef[3892] = 35
# hostBins[3892] =  35
# CPU and GPU results are  equal.
# resultRef[3893] = 27
# hostBins[3893] =  27
# CPU and GPU results are  equal.
# resultRef[3894] = 35
# hostBins[3894] =  35
# CPU and GPU results are  equal.
# resultRef[3895] = 24
# hostBins[3895] =  24
# CPU and GPU results are  equal.
# resultRef[3896] = 35
# hostBins[3896] =  35
# CPU and GPU results are  equal.
# resultRef[3897] = 21
# hostBins[3897] =  21
# CPU and GPU results are  equal.
# resultRef[3898] = 22
# hostBins[3898] =  22
# CPU and GPU results are  equal.
# resultRef[3899] = 26
# hostBins[3899] =  26
# CPU and GPU results are  equal.
# resultRef[3900] = 24
# hostBins[3900] =  24
# CPU and GPU results are  equal.
# resultRef[3901] = 31
# hostBins[3901] =  31
# CPU and GPU results are  equal.
# resultRef[3902] = 36
# hostBins[3902] =  36
# CPU and GPU results are  equal.
# resultRef[3903] = 34
# hostBins[3903] =  34
# CPU and GPU results are  equal.
# resultRef[3904] = 30
# hostBins[3904] =  30
# CPU and GPU results are  equal.
# resultRef[3905] = 29
# hostBins[3905] =  29
# CPU and GPU results are  equal.
# resultRef[3906] = 29
# hostBins[3906] =  29
# CPU and GPU results are  equal.
# resultRef[3907] = 30
# hostBins[3907] =  30
# CPU and GPU results are  equal.
# resultRef[3908] = 33
# hostBins[3908] =  33
# CPU and GPU results are  equal.
# resultRef[3909] = 39
# hostBins[3909] =  39
# CPU and GPU results are  equal.
# resultRef[3910] = 26
# hostBins[3910] =  26
# CPU and GPU results are  equal.
# resultRef[3911] = 33
# hostBins[3911] =  33
# CPU and GPU results are  equal.
# resultRef[3912] = 32
# hostBins[3912] =  32
# CPU and GPU results are  equal.
# resultRef[3913] = 23
# hostBins[3913] =  23
# CPU and GPU results are  equal.
# resultRef[3914] = 36
# hostBins[3914] =  36
# CPU and GPU results are  equal.
# resultRef[3915] = 27
# hostBins[3915] =  27
# CPU and GPU results are  equal.
# resultRef[3916] = 26
# hostBins[3916] =  26
# CPU and GPU results are  equal.
# resultRef[3917] = 24
# hostBins[3917] =  24
# CPU and GPU results are  equal.
# resultRef[3918] = 32
# hostBins[3918] =  32
# CPU and GPU results are  equal.
# resultRef[3919] = 33
# hostBins[3919] =  33
# CPU and GPU results are  equal.
# resultRef[3920] = 37
# hostBins[3920] =  37
# CPU and GPU results are  equal.
# resultRef[3921] = 32
# hostBins[3921] =  32
# CPU and GPU results are  equal.
# resultRef[3922] = 35
# hostBins[3922] =  35
# CPU and GPU results are  equal.
# resultRef[3923] = 35
# hostBins[3923] =  35
# CPU and GPU results are  equal.
# resultRef[3924] = 29
# hostBins[3924] =  29
# CPU and GPU results are  equal.
# resultRef[3925] = 31
# hostBins[3925] =  31
# CPU and GPU results are  equal.
# resultRef[3926] = 35
# hostBins[3926] =  35
# CPU and GPU results are  equal.
# resultRef[3927] = 25
# hostBins[3927] =  25
# CPU and GPU results are  equal.
# resultRef[3928] = 32
# hostBins[3928] =  32
# CPU and GPU results are  equal.
# resultRef[3929] = 43
# hostBins[3929] =  43
# CPU and GPU results are  equal.
# resultRef[3930] = 33
# hostBins[3930] =  33
# CPU and GPU results are  equal.
# resultRef[3931] = 44
# hostBins[3931] =  44
# CPU and GPU results are  equal.
# resultRef[3932] = 31
# hostBins[3932] =  31
# CPU and GPU results are  equal.
# resultRef[3933] = 30
# hostBins[3933] =  30
# CPU and GPU results are  equal.
# resultRef[3934] = 27
# hostBins[3934] =  27
# CPU and GPU results are  equal.
# resultRef[3935] = 35
# hostBins[3935] =  35
# CPU and GPU results are  equal.
# resultRef[3936] = 27
# hostBins[3936] =  27
# CPU and GPU results are  equal.
# resultRef[3937] = 35
# hostBins[3937] =  35
# CPU and GPU results are  equal.
# resultRef[3938] = 29
# hostBins[3938] =  29
# CPU and GPU results are  equal.
# resultRef[3939] = 32
# hostBins[3939] =  32
# CPU and GPU results are  equal.
# resultRef[3940] = 36
# hostBins[3940] =  36
# CPU and GPU results are  equal.
# resultRef[3941] = 35
# hostBins[3941] =  35
# CPU and GPU results are  equal.
# resultRef[3942] = 35
# hostBins[3942] =  35
# CPU and GPU results are  equal.
# resultRef[3943] = 33
# hostBins[3943] =  33
# CPU and GPU results are  equal.
# resultRef[3944] = 41
# hostBins[3944] =  41
# CPU and GPU results are  equal.
# resultRef[3945] = 31
# hostBins[3945] =  31
# CPU and GPU results are  equal.
# resultRef[3946] = 35
# hostBins[3946] =  35
# CPU and GPU results are  equal.
# resultRef[3947] = 30
# hostBins[3947] =  30
# CPU and GPU results are  equal.
# resultRef[3948] = 24
# hostBins[3948] =  24
# CPU and GPU results are  equal.
# resultRef[3949] = 40
# hostBins[3949] =  40
# CPU and GPU results are  equal.
# resultRef[3950] = 27
# hostBins[3950] =  27
# CPU and GPU results are  equal.
# resultRef[3951] = 34
# hostBins[3951] =  34
# CPU and GPU results are  equal.
# resultRef[3952] = 24
# hostBins[3952] =  24
# CPU and GPU results are  equal.
# resultRef[3953] = 25
# hostBins[3953] =  25
# CPU and GPU results are  equal.
# resultRef[3954] = 34
# hostBins[3954] =  34
# CPU and GPU results are  equal.
# resultRef[3955] = 29
# hostBins[3955] =  29
# CPU and GPU results are  equal.
# resultRef[3956] = 32
# hostBins[3956] =  32
# CPU and GPU results are  equal.
# resultRef[3957] = 28
# hostBins[3957] =  28
# CPU and GPU results are  equal.
# resultRef[3958] = 34
# hostBins[3958] =  34
# CPU and GPU results are  equal.
# resultRef[3959] = 45
# hostBins[3959] =  45
# CPU and GPU results are  equal.
# resultRef[3960] = 31
# hostBins[3960] =  31
# CPU and GPU results are  equal.
# resultRef[3961] = 32
# hostBins[3961] =  32
# CPU and GPU results are  equal.
# resultRef[3962] = 35
# hostBins[3962] =  35
# CPU and GPU results are  equal.
# resultRef[3963] = 26
# hostBins[3963] =  26
# CPU and GPU results are  equal.
# resultRef[3964] = 42
# hostBins[3964] =  42
# CPU and GPU results are  equal.
# resultRef[3965] = 29
# hostBins[3965] =  29
# CPU and GPU results are  equal.
# resultRef[3966] = 28
# hostBins[3966] =  28
# CPU and GPU results are  equal.
# resultRef[3967] = 33
# hostBins[3967] =  33
# CPU and GPU results are  equal.
# resultRef[3968] = 41
# hostBins[3968] =  41
# CPU and GPU results are  equal.
# resultRef[3969] = 25
# hostBins[3969] =  25
# CPU and GPU results are  equal.
# resultRef[3970] = 25
# hostBins[3970] =  25
# CPU and GPU results are  equal.
# resultRef[3971] = 32
# hostBins[3971] =  32
# CPU and GPU results are  equal.
# resultRef[3972] = 29
# hostBins[3972] =  29
# CPU and GPU results are  equal.
# resultRef[3973] = 25
# hostBins[3973] =  25
# CPU and GPU results are  equal.
# resultRef[3974] = 24
# hostBins[3974] =  24
# CPU and GPU results are  equal.
# resultRef[3975] = 35
# hostBins[3975] =  35
# CPU and GPU results are  equal.
# resultRef[3976] = 27
# hostBins[3976] =  27
# CPU and GPU results are  equal.
# resultRef[3977] = 25
# hostBins[3977] =  25
# CPU and GPU results are  equal.
# resultRef[3978] = 41
# hostBins[3978] =  41
# CPU and GPU results are  equal.
# resultRef[3979] = 23
# hostBins[3979] =  23
# CPU and GPU results are  equal.
# resultRef[3980] = 40
# hostBins[3980] =  40
# CPU and GPU results are  equal.
# resultRef[3981] = 37
# hostBins[3981] =  37
# CPU and GPU results are  equal.
# resultRef[3982] = 29
# hostBins[3982] =  29
# CPU and GPU results are  equal.
# resultRef[3983] = 29
# hostBins[3983] =  29
# CPU and GPU results are  equal.
# resultRef[3984] = 36
# hostBins[3984] =  36
# CPU and GPU results are  equal.
# resultRef[3985] = 26
# hostBins[3985] =  26
# CPU and GPU results are  equal.
# resultRef[3986] = 27
# hostBins[3986] =  27
# CPU and GPU results are  equal.
# resultRef[3987] = 33
# hostBins[3987] =  33
# CPU and GPU results are  equal.
# resultRef[3988] = 33
# hostBins[3988] =  33
# CPU and GPU results are  equal.
# resultRef[3989] = 31
# hostBins[3989] =  31
# CPU and GPU results are  equal.
# resultRef[3990] = 39
# hostBins[3990] =  39
# CPU and GPU results are  equal.
# resultRef[3991] = 24
# hostBins[3991] =  24
# CPU and GPU results are  equal.
# resultRef[3992] = 34
# hostBins[3992] =  34
# CPU and GPU results are  equal.
# resultRef[3993] = 32
# hostBins[3993] =  32
# CPU and GPU results are  equal.
# resultRef[3994] = 30
# hostBins[3994] =  30
# CPU and GPU results are  equal.
# resultRef[3995] = 22
# hostBins[3995] =  22
# CPU and GPU results are  equal.
# resultRef[3996] = 35
# hostBins[3996] =  35
# CPU and GPU results are  equal.
# resultRef[3997] = 31
# hostBins[3997] =  31
# CPU and GPU results are  equal.
# resultRef[3998] = 30
# hostBins[3998] =  30
# CPU and GPU results are  equal.
# resultRef[3999] = 29
# hostBins[3999] =  29
# CPU and GPU results are  equal.
# resultRef[4000] = 34
# hostBins[4000] =  34
# CPU and GPU results are  equal.
# resultRef[4001] = 33
# hostBins[4001] =  33
# CPU and GPU results are  equal.
# resultRef[4002] = 30
# hostBins[4002] =  30
# CPU and GPU results are  equal.
# resultRef[4003] = 27
# hostBins[4003] =  27
# CPU and GPU results are  equal.
# resultRef[4004] = 29
# hostBins[4004] =  29
# CPU and GPU results are  equal.
# resultRef[4005] = 26
# hostBins[4005] =  26
# CPU and GPU results are  equal.
# resultRef[4006] = 37
# hostBins[4006] =  37
# CPU and GPU results are  equal.
# resultRef[4007] = 30
# hostBins[4007] =  30
# CPU and GPU results are  equal.
# resultRef[4008] = 30
# hostBins[4008] =  30
# CPU and GPU results are  equal.
# resultRef[4009] = 36
# hostBins[4009] =  36
# CPU and GPU results are  equal.
# resultRef[4010] = 37
# hostBins[4010] =  37
# CPU and GPU results are  equal.
# resultRef[4011] = 29
# hostBins[4011] =  29
# CPU and GPU results are  equal.
# resultRef[4012] = 23
# hostBins[4012] =  23
# CPU and GPU results are  equal.
# resultRef[4013] = 46
# hostBins[4013] =  46
# CPU and GPU results are  equal.
# resultRef[4014] = 26
# hostBins[4014] =  26
# CPU and GPU results are  equal.
# resultRef[4015] = 30
# hostBins[4015] =  30
# CPU and GPU results are  equal.
# resultRef[4016] = 36
# hostBins[4016] =  36
# CPU and GPU results are  equal.
# resultRef[4017] = 35
# hostBins[4017] =  35
# CPU and GPU results are  equal.
# resultRef[4018] = 29
# hostBins[4018] =  29
# CPU and GPU results are  equal.
# resultRef[4019] = 23
# hostBins[4019] =  23
# CPU and GPU results are  equal.
# resultRef[4020] = 33
# hostBins[4020] =  33
# CPU and GPU results are  equal.
# resultRef[4021] = 33
# hostBins[4021] =  33
# CPU and GPU results are  equal.
# resultRef[4022] = 42
# hostBins[4022] =  42
# CPU and GPU results are  equal.
# resultRef[4023] = 28
# hostBins[4023] =  28
# CPU and GPU results are  equal.
# resultRef[4024] = 27
# hostBins[4024] =  27
# CPU and GPU results are  equal.
# resultRef[4025] = 33
# hostBins[4025] =  33
# CPU and GPU results are  equal.
# resultRef[4026] = 32
# hostBins[4026] =  32
# CPU and GPU results are  equal.
# resultRef[4027] = 37
# hostBins[4027] =  37
# CPU and GPU results are  equal.
# resultRef[4028] = 26
# hostBins[4028] =  26
# CPU and GPU results are  equal.
# resultRef[4029] = 25
# hostBins[4029] =  25
# CPU and GPU results are  equal.
# resultRef[4030] = 41
# hostBins[4030] =  41
# CPU and GPU results are  equal.
# resultRef[4031] = 31
# hostBins[4031] =  31
# CPU and GPU results are  equal.
# resultRef[4032] = 32
# hostBins[4032] =  32
# CPU and GPU results are  equal.
# resultRef[4033] = 39
# hostBins[4033] =  39
# CPU and GPU results are  equal.
# resultRef[4034] = 38
# hostBins[4034] =  38
# CPU and GPU results are  equal.
# resultRef[4035] = 23
# hostBins[4035] =  23
# CPU and GPU results are  equal.
# resultRef[4036] = 36
# hostBins[4036] =  36
# CPU and GPU results are  equal.
# resultRef[4037] = 40
# hostBins[4037] =  40
# CPU and GPU results are  equal.
# resultRef[4038] = 41
# hostBins[4038] =  41
# CPU and GPU results are  equal.
# resultRef[4039] = 32
# hostBins[4039] =  32
# CPU and GPU results are  equal.
# resultRef[4040] = 28
# hostBins[4040] =  28
# CPU and GPU results are  equal.
# resultRef[4041] = 30
# hostBins[4041] =  30
# CPU and GPU results are  equal.
# resultRef[4042] = 32
# hostBins[4042] =  32
# CPU and GPU results are  equal.
# resultRef[4043] = 31
# hostBins[4043] =  31
# CPU and GPU results are  equal.
# resultRef[4044] = 33
# hostBins[4044] =  33
# CPU and GPU results are  equal.
# resultRef[4045] = 28
# hostBins[4045] =  28
# CPU and GPU results are  equal.
# resultRef[4046] = 27
# hostBins[4046] =  27
# CPU and GPU results are  equal.
# resultRef[4047] = 28
# hostBins[4047] =  28
# CPU and GPU results are  equal.
# resultRef[4048] = 41
# hostBins[4048] =  41
# CPU and GPU results are  equal.
# resultRef[4049] = 30
# hostBins[4049] =  30
# CPU and GPU results are  equal.
# resultRef[4050] = 31
# hostBins[4050] =  31
# CPU and GPU results are  equal.
# resultRef[4051] = 41
# hostBins[4051] =  41
# CPU and GPU results are  equal.
# resultRef[4052] = 36
# hostBins[4052] =  36
# CPU and GPU results are  equal.
# resultRef[4053] = 38
# hostBins[4053] =  38
# CPU and GPU results are  equal.
# resultRef[4054] = 27
# hostBins[4054] =  27
# CPU and GPU results are  equal.
# resultRef[4055] = 30
# hostBins[4055] =  30
# CPU and GPU results are  equal.
# resultRef[4056] = 25
# hostBins[4056] =  25
# CPU and GPU results are  equal.
# resultRef[4057] = 43
# hostBins[4057] =  43
# CPU and GPU results are  equal.
# resultRef[4058] = 36
# hostBins[4058] =  36
# CPU and GPU results are  equal.
# resultRef[4059] = 33
# hostBins[4059] =  33
# CPU and GPU results are  equal.
# resultRef[4060] = 39
# hostBins[4060] =  39
# CPU and GPU results are  equal.
# resultRef[4061] = 29
# hostBins[4061] =  29
# CPU and GPU results are  equal.
# resultRef[4062] = 16
# hostBins[4062] =  16
# CPU and GPU results are  equal.
# resultRef[4063] = 33
# hostBins[4063] =  33
# CPU and GPU results are  equal.
# resultRef[4064] = 34
# hostBins[4064] =  34
# CPU and GPU results are  equal.
# resultRef[4065] = 40
# hostBins[4065] =  40
# CPU and GPU results are  equal.
# resultRef[4066] = 30
# hostBins[4066] =  30
# CPU and GPU results are  equal.
# resultRef[4067] = 34
# hostBins[4067] =  34
# CPU and GPU results are  equal.
# resultRef[4068] = 40
# hostBins[4068] =  40
# CPU and GPU results are  equal.
# resultRef[4069] = 35
# hostBins[4069] =  35
# CPU and GPU results are  equal.
# resultRef[4070] = 33
# hostBins[4070] =  33
# CPU and GPU results are  equal.
# resultRef[4071] = 39
# hostBins[4071] =  39
# CPU and GPU results are  equal.
# resultRef[4072] = 28
# hostBins[4072] =  28
# CPU and GPU results are  equal.
# resultRef[4073] = 31
# hostBins[4073] =  31
# CPU and GPU results are  equal.
# resultRef[4074] = 30
# hostBins[4074] =  30
# CPU and GPU results are  equal.
# resultRef[4075] = 36
# hostBins[4075] =  36
# CPU and GPU results are  equal.
# resultRef[4076] = 39
# hostBins[4076] =  39
# CPU and GPU results are  equal.
# resultRef[4077] = 27
# hostBins[4077] =  27
# CPU and GPU results are  equal.
# resultRef[4078] = 27
# hostBins[4078] =  27
# CPU and GPU results are  equal.
# resultRef[4079] = 42
# hostBins[4079] =  42
# CPU and GPU results are  equal.
# resultRef[4080] = 26
# hostBins[4080] =  26
# CPU and GPU results are  equal.
# resultRef[4081] = 33
# hostBins[4081] =  33
# CPU and GPU results are  equal.
# resultRef[4082] = 22
# hostBins[4082] =  22
# CPU and GPU results are  equal.
# resultRef[4083] = 32
# hostBins[4083] =  32
# CPU and GPU results are  equal.
# resultRef[4084] = 33
# hostBins[4084] =  33
# CPU and GPU results are  equal.
# resultRef[4085] = 34
# hostBins[4085] =  34
# CPU and GPU results are  equal.
# resultRef[4086] = 35
# hostBins[4086] =  35
# CPU and GPU results are  equal.
# resultRef[4087] = 28
# hostBins[4087] =  28
# CPU and GPU results are  equal.
# resultRef[4088] = 35
# hostBins[4088] =  35
# CPU and GPU results are  equal.
# resultRef[4089] = 33
# hostBins[4089] =  33
# CPU and GPU results are  equal.
# resultRef[4090] = 33
# hostBins[4090] =  33
# CPU and GPU results are  equal.
# resultRef[4091] = 38
# hostBins[4091] =  38
# CPU and GPU results are  equal.
# resultRef[4092] = 35
# hostBins[4092] =  35
# CPU and GPU results are  equal.
# resultRef[4093] = 35
# hostBins[4093] =  35
# CPU and GPU results are  equal.
# resultRef[4094] = 28
# hostBins[4094] =  28
# CPU and GPU results are  equal.
# resultRef[4095] = 0
# hostBins[4095] =  0
# CPU and GPU results are  equal.

# %%
# !nvprof ./lab3_ex3 131072
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# resultRef[2436] = 37
# hostBins[2436] =  37
# CPU and GPU results are  equal.
# resultRef[2437] = 31
# hostBins[2437] =  31
# CPU and GPU results are  equal.
# resultRef[2438] = 31
# hostBins[2438] =  31
# CPU and GPU results are  equal.
# resultRef[2439] = 25
# hostBins[2439] =  25
# CPU and GPU results are  equal.
# resultRef[2440] = 37
# hostBins[2440] =  37
# CPU and GPU results are  equal.
# resultRef[2441] = 25
# hostBins[2441] =  25
# CPU and GPU results are  equal.
# resultRef[2442] = 29
# hostBins[2442] =  29
# CPU and GPU results are  equal.
# resultRef[2443] = 43
# hostBins[2443] =  43
# CPU and GPU results are  equal.
# resultRef[2444] = 30
# hostBins[2444] =  30
# CPU and GPU results are  equal.
# resultRef[2445] = 37
# hostBins[2445] =  37
# CPU and GPU results are  equal.
# resultRef[2446] = 40
# hostBins[2446] =  40
# CPU and GPU results are  equal.
# resultRef[2447] = 40
# hostBins[2447] =  40
# CPU and GPU results are  equal.
# resultRef[2448] = 30
# hostBins[2448] =  30
# CPU and GPU results are  equal.
# resultRef[2449] = 40
# hostBins[2449] =  40
# CPU and GPU results are  equal.
# resultRef[2450] = 30
# hostBins[2450] =  30
# CPU and GPU results are  equal.
# resultRef[2451] = 34
# hostBins[2451] =  34
# CPU and GPU results are  equal.
# resultRef[2452] = 34
# hostBins[2452] =  34
# CPU and GPU results are  equal.
# resultRef[2453] = 37
# hostBins[2453] =  37
# CPU and GPU results are  equal.
# resultRef[2454] = 22
# hostBins[2454] =  22
# CPU and GPU results are  equal.
# resultRef[2455] = 32
# hostBins[2455] =  32
# CPU and GPU results are  equal.
# resultRef[2456] = 26
# hostBins[2456] =  26
# CPU and GPU results are  equal.
# resultRef[2457] = 28
# hostBins[2457] =  28
# CPU and GPU results are  equal.
# resultRef[2458] = 32
# hostBins[2458] =  32
# CPU and GPU results are  equal.
# resultRef[2459] = 42
# hostBins[2459] =  42
# CPU and GPU results are  equal.
# resultRef[2460] = 29
# hostBins[2460] =  29
# CPU and GPU results are  equal.
# resultRef[2461] = 30
# hostBins[2461] =  30
# CPU and GPU results are  equal.
# resultRef[2462] = 30
# hostBins[2462] =  30
# CPU and GPU results are  equal.
# resultRef[2463] = 41
# hostBins[2463] =  41
# CPU and GPU results are  equal.
# resultRef[2464] = 41
# hostBins[2464] =  41
# CPU and GPU results are  equal.
# resultRef[2465] = 36
# hostBins[2465] =  36
# CPU and GPU results are  equal.
# resultRef[2466] = 33
# hostBins[2466] =  33
# CPU and GPU results are  equal.
# resultRef[2467] = 32
# hostBins[2467] =  32
# CPU and GPU results are  equal.
# resultRef[2468] = 29
# hostBins[2468] =  29
# CPU and GPU results are  equal.
# resultRef[2469] = 42
# hostBins[2469] =  42
# CPU and GPU results are  equal.
# resultRef[2470] = 38
# hostBins[2470] =  38
# CPU and GPU results are  equal.
# resultRef[2471] = 28
# hostBins[2471] =  28
# CPU and GPU results are  equal.
# resultRef[2472] = 32
# hostBins[2472] =  32
# CPU and GPU results are  equal.
# resultRef[2473] = 33
# hostBins[2473] =  33
# CPU and GPU results are  equal.
# resultRef[2474] = 27
# hostBins[2474] =  27
# CPU and GPU results are  equal.
# resultRef[2475] = 34
# hostBins[2475] =  34
# CPU and GPU results are  equal.
# resultRef[2476] = 17
# hostBins[2476] =  17
# CPU and GPU results are  equal.
# resultRef[2477] = 33
# hostBins[2477] =  33
# CPU and GPU results are  equal.
# resultRef[2478] = 29
# hostBins[2478] =  29
# CPU and GPU results are  equal.
# resultRef[2479] = 31
# hostBins[2479] =  31
# CPU and GPU results are  equal.
# resultRef[2480] = 30
# hostBins[2480] =  30
# CPU and GPU results are  equal.
# resultRef[2481] = 32
# hostBins[2481] =  32
# CPU and GPU results are  equal.
# resultRef[2482] = 27
# hostBins[2482] =  27
# CPU and GPU results are  equal.
# resultRef[2483] = 29
# hostBins[2483] =  29
# CPU and GPU results are  equal.
# resultRef[2484] = 38
# hostBins[2484] =  38
# CPU and GPU results are  equal.
# resultRef[2485] = 35
# hostBins[2485] =  35
# CPU and GPU results are  equal.
# resultRef[2486] = 31
# hostBins[2486] =  31
# CPU and GPU results are  equal.
# resultRef[2487] = 30
# hostBins[2487] =  30
# CPU and GPU results are  equal.
# resultRef[2488] = 29
# hostBins[2488] =  29
# CPU and GPU results are  equal.
# resultRef[2489] = 28
# hostBins[2489] =  28
# CPU and GPU results are  equal.
# resultRef[2490] = 35
# hostBins[2490] =  35
# CPU and GPU results are  equal.
# resultRef[2491] = 28
# hostBins[2491] =  28
# CPU and GPU results are  equal.
# resultRef[2492] = 24
# hostBins[2492] =  24
# CPU and GPU results are  equal.
# resultRef[2493] = 34
# hostBins[2493] =  34
# CPU and GPU results are  equal.
# resultRef[2494] = 18
# hostBins[2494] =  18
# CPU and GPU results are  equal.
# resultRef[2495] = 20
# hostBins[2495] =  20
# CPU and GPU results are  equal.
# resultRef[2496] = 27
# hostBins[2496] =  27
# CPU and GPU results are  equal.
# resultRef[2497] = 23
# hostBins[2497] =  23
# CPU and GPU results are  equal.
# resultRef[2498] = 30
# hostBins[2498] =  30
# CPU and GPU results are  equal.
# resultRef[2499] = 32
# hostBins[2499] =  32
# CPU and GPU results are  equal.
# resultRef[2500] = 25
# hostBins[2500] =  25
# CPU and GPU results are  equal.
# resultRef[2501] = 35
# hostBins[2501] =  35
# CPU and GPU results are  equal.
# resultRef[2502] = 23
# hostBins[2502] =  23
# CPU and GPU results are  equal.
# resultRef[2503] = 43
# hostBins[2503] =  43
# CPU and GPU results are  equal.
# resultRef[2504] = 43
# hostBins[2504] =  43
# CPU and GPU results are  equal.
# resultRef[2505] = 38
# hostBins[2505] =  38
# CPU and GPU results are  equal.
# resultRef[2506] = 35
# hostBins[2506] =  35
# CPU and GPU results are  equal.
# resultRef[2507] = 31
# hostBins[2507] =  31
# CPU and GPU results are  equal.
# resultRef[2508] = 29
# hostBins[2508] =  29
# CPU and GPU results are  equal.
# resultRef[2509] = 38
# hostBins[2509] =  38
# CPU and GPU results are  equal.
# resultRef[2510] = 28
# hostBins[2510] =  28
# CPU and GPU results are  equal.
# resultRef[2511] = 27
# hostBins[2511] =  27
# CPU and GPU results are  equal.
# resultRef[2512] = 37
# hostBins[2512] =  37
# CPU and GPU results are  equal.
# resultRef[2513] = 40
# hostBins[2513] =  40
# CPU and GPU results are  equal.
# resultRef[2514] = 50
# hostBins[2514] =  50
# CPU and GPU results are  equal.
# resultRef[2515] = 45
# hostBins[2515] =  45
# CPU and GPU results are  equal.
# resultRef[2516] = 21
# hostBins[2516] =  21
# CPU and GPU results are  equal.
# resultRef[2517] = 28
# hostBins[2517] =  28
# CPU and GPU results are  equal.
# resultRef[2518] = 29
# hostBins[2518] =  29
# CPU and GPU results are  equal.
# resultRef[2519] = 24
# hostBins[2519] =  24
# CPU and GPU results are  equal.
# resultRef[2520] = 33
# hostBins[2520] =  33
# CPU and GPU results are  equal.
# resultRef[2521] = 30
# hostBins[2521] =  30
# CPU and GPU results are  equal.
# resultRef[2522] = 34
# hostBins[2522] =  34
# CPU and GPU results are  equal.
# resultRef[2523] = 36
# hostBins[2523] =  36
# CPU and GPU results are  equal.
# resultRef[2524] = 34
# hostBins[2524] =  34
# CPU and GPU results are  equal.
# resultRef[2525] = 35
# hostBins[2525] =  35
# CPU and GPU results are  equal.
# resultRef[2526] = 36
# hostBins[2526] =  36
# CPU and GPU results are  equal.
# resultRef[2527] = 22
# hostBins[2527] =  22
# CPU and GPU results are  equal.
# resultRef[2528] = 34
# hostBins[2528] =  34
# CPU and GPU results are  equal.
# resultRef[2529] = 26
# hostBins[2529] =  26
# CPU and GPU results are  equal.
# resultRef[2530] = 32
# hostBins[2530] =  32
# CPU and GPU results are  equal.
# resultRef[2531] = 27
# hostBins[2531] =  27
# CPU and GPU results are  equal.
# resultRef[2532] = 39
# hostBins[2532] =  39
# CPU and GPU results are  equal.
# resultRef[2533] = 39
# hostBins[2533] =  39
# CPU and GPU results are  equal.
# resultRef[2534] = 47
# hostBins[2534] =  47
# CPU and GPU results are  equal.
# resultRef[2535] = 36
# hostBins[2535] =  36
# CPU and GPU results are  equal.
# resultRef[2536] = 26
# hostBins[2536] =  26
# CPU and GPU results are  equal.
# resultRef[2537] = 40
# hostBins[2537] =  40
# CPU and GPU results are  equal.
# resultRef[2538] = 40
# hostBins[2538] =  40
# CPU and GPU results are  equal.
# resultRef[2539] = 35
# hostBins[2539] =  35
# CPU and GPU results are  equal.
# resultRef[2540] = 29
# hostBins[2540] =  29
# CPU and GPU results are  equal.
# resultRef[2541] = 30
# hostBins[2541] =  30
# CPU and GPU results are  equal.
# resultRef[2542] = 28
# hostBins[2542] =  28
# CPU and GPU results are  equal.
# resultRef[2543] = 42
# hostBins[2543] =  42
# CPU and GPU results are  equal.
# resultRef[2544] = 37
# hostBins[2544] =  37
# CPU and GPU results are  equal.
# resultRef[2545] = 34
# hostBins[2545] =  34
# CPU and GPU results are  equal.
# resultRef[2546] = 33
# hostBins[2546] =  33
# CPU and GPU results are  equal.
# resultRef[2547] = 25
# hostBins[2547] =  25
# CPU and GPU results are  equal.
# resultRef[2548] = 38
# hostBins[2548] =  38
# CPU and GPU results are  equal.
# resultRef[2549] = 36
# hostBins[2549] =  36
# CPU and GPU results are  equal.
# resultRef[2550] = 36
# hostBins[2550] =  36
# CPU and GPU results are  equal.
# resultRef[2551] = 26
# hostBins[2551] =  26
# CPU and GPU results are  equal.
# resultRef[2552] = 35
# hostBins[2552] =  35
# CPU and GPU results are  equal.
# resultRef[2553] = 24
# hostBins[2553] =  24
# CPU and GPU results are  equal.
# resultRef[2554] = 28
# hostBins[2554] =  28
# CPU and GPU results are  equal.
# resultRef[2555] = 27
# hostBins[2555] =  27
# CPU and GPU results are  equal.
# resultRef[2556] = 27
# hostBins[2556] =  27
# CPU and GPU results are  equal.
# resultRef[2557] = 30
# hostBins[2557] =  30
# CPU and GPU results are  equal.
# resultRef[2558] = 37
# hostBins[2558] =  37
# CPU and GPU results are  equal.
# resultRef[2559] = 31
# hostBins[2559] =  31
# CPU and GPU results are  equal.
# resultRef[2560] = 35
# hostBins[2560] =  35
# CPU and GPU results are  equal.
# resultRef[2561] = 41
# hostBins[2561] =  41
# CPU and GPU results are  equal.
# resultRef[2562] = 35
# hostBins[2562] =  35
# CPU and GPU results are  equal.
# resultRef[2563] = 35
# hostBins[2563] =  35
# CPU and GPU results are  equal.
# resultRef[2564] = 29
# hostBins[2564] =  29
# CPU and GPU results are  equal.
# resultRef[2565] = 26
# hostBins[2565] =  26
# CPU and GPU results are  equal.
# resultRef[2566] = 40
# hostBins[2566] =  40
# CPU and GPU results are  equal.
# resultRef[2567] = 39
# hostBins[2567] =  39
# CPU and GPU results are  equal.
# resultRef[2568] = 34
# hostBins[2568] =  34
# CPU and GPU results are  equal.
# resultRef[2569] = 32
# hostBins[2569] =  32
# CPU and GPU results are  equal.
# resultRef[2570] = 34
# hostBins[2570] =  34
# CPU and GPU results are  equal.
# resultRef[2571] = 28
# hostBins[2571] =  28
# CPU and GPU results are  equal.
# resultRef[2572] = 32
# hostBins[2572] =  32
# CPU and GPU results are  equal.
# resultRef[2573] = 22
# hostBins[2573] =  22
# CPU and GPU results are  equal.
# resultRef[2574] = 50
# hostBins[2574] =  50
# CPU and GPU results are  equal.
# resultRef[2575] = 40
# hostBins[2575] =  40
# CPU and GPU results are  equal.
# resultRef[2576] = 24
# hostBins[2576] =  24
# CPU and GPU results are  equal.
# resultRef[2577] = 33
# hostBins[2577] =  33
# CPU and GPU results are  equal.
# resultRef[2578] = 29
# hostBins[2578] =  29
# CPU and GPU results are  equal.
# resultRef[2579] = 27
# hostBins[2579] =  27
# CPU and GPU results are  equal.
# resultRef[2580] = 36
# hostBins[2580] =  36
# CPU and GPU results are  equal.
# resultRef[2581] = 31
# hostBins[2581] =  31
# CPU and GPU results are  equal.
# resultRef[2582] = 35
# hostBins[2582] =  35
# CPU and GPU results are  equal.
# resultRef[2583] = 30
# hostBins[2583] =  30
# CPU and GPU results are  equal.
# resultRef[2584] = 25
# hostBins[2584] =  25
# CPU and GPU results are  equal.
# resultRef[2585] = 36
# hostBins[2585] =  36
# CPU and GPU results are  equal.
# resultRef[2586] = 25
# hostBins[2586] =  25
# CPU and GPU results are  equal.
# resultRef[2587] = 26
# hostBins[2587] =  26
# CPU and GPU results are  equal.
# resultRef[2588] = 26
# hostBins[2588] =  26
# CPU and GPU results are  equal.
# resultRef[2589] = 23
# hostBins[2589] =  23
# CPU and GPU results are  equal.
# resultRef[2590] = 27
# hostBins[2590] =  27
# CPU and GPU results are  equal.
# resultRef[2591] = 30
# hostBins[2591] =  30
# CPU and GPU results are  equal.
# resultRef[2592] = 36
# hostBins[2592] =  36
# CPU and GPU results are  equal.
# resultRef[2593] = 25
# hostBins[2593] =  25
# CPU and GPU results are  equal.
# resultRef[2594] = 30
# hostBins[2594] =  30
# CPU and GPU results are  equal.
# resultRef[2595] = 39
# hostBins[2595] =  39
# CPU and GPU results are  equal.
# resultRef[2596] = 32
# hostBins[2596] =  32
# CPU and GPU results are  equal.
# resultRef[2597] = 31
# hostBins[2597] =  31
# CPU and GPU results are  equal.
# resultRef[2598] = 24
# hostBins[2598] =  24
# CPU and GPU results are  equal.
# resultRef[2599] = 38
# hostBins[2599] =  38
# CPU and GPU results are  equal.
# resultRef[2600] = 28
# hostBins[2600] =  28
# CPU and GPU results are  equal.
# resultRef[2601] = 42
# hostBins[2601] =  42
# CPU and GPU results are  equal.
# resultRef[2602] = 27
# hostBins[2602] =  27
# CPU and GPU results are  equal.
# resultRef[2603] = 25
# hostBins[2603] =  25
# CPU and GPU results are  equal.
# resultRef[2604] = 28
# hostBins[2604] =  28
# CPU and GPU results are  equal.
# resultRef[2605] = 30
# hostBins[2605] =  30
# CPU and GPU results are  equal.
# resultRef[2606] = 32
# hostBins[2606] =  32
# CPU and GPU results are  equal.
# resultRef[2607] = 34
# hostBins[2607] =  34
# CPU and GPU results are  equal.
# resultRef[2608] = 26
# hostBins[2608] =  26
# CPU and GPU results are  equal.
# resultRef[2609] = 34
# hostBins[2609] =  34
# CPU and GPU results are  equal.
# resultRef[2610] = 37
# hostBins[2610] =  37
# CPU and GPU results are  equal.
# resultRef[2611] = 28
# hostBins[2611] =  28
# CPU and GPU results are  equal.
# resultRef[2612] = 38
# hostBins[2612] =  38
# CPU and GPU results are  equal.
# resultRef[2613] = 19
# hostBins[2613] =  19
# CPU and GPU results are  equal.
# resultRef[2614] = 28
# hostBins[2614] =  28
# CPU and GPU results are  equal.
# resultRef[2615] = 44
# hostBins[2615] =  44
# CPU and GPU results are  equal.
# resultRef[2616] = 32
# hostBins[2616] =  32
# CPU and GPU results are  equal.
# resultRef[2617] = 35
# hostBins[2617] =  35
# CPU and GPU results are  equal.
# resultRef[2618] = 20
# hostBins[2618] =  20
# CPU and GPU results are  equal.
# resultRef[2619] = 28
# hostBins[2619] =  28
# CPU and GPU results are  equal.
# resultRef[2620] = 36
# hostBins[2620] =  36
# CPU and GPU results are  equal.
# resultRef[2621] = 36
# hostBins[2621] =  36
# CPU and GPU results are  equal.
# resultRef[2622] = 38
# hostBins[2622] =  38
# CPU and GPU results are  equal.
# resultRef[2623] = 34
# hostBins[2623] =  34
# CPU and GPU results are  equal.
# resultRef[2624] = 30
# hostBins[2624] =  30
# CPU and GPU results are  equal.
# resultRef[2625] = 30
# hostBins[2625] =  30
# CPU and GPU results are  equal.
# resultRef[2626] = 43
# hostBins[2626] =  43
# CPU and GPU results are  equal.
# resultRef[2627] = 30
# hostBins[2627] =  30
# CPU and GPU results are  equal.
# resultRef[2628] = 35
# hostBins[2628] =  35
# CPU and GPU results are  equal.
# resultRef[2629] = 35
# hostBins[2629] =  35
# CPU and GPU results are  equal.
# resultRef[2630] = 23
# hostBins[2630] =  23
# CPU and GPU results are  equal.
# resultRef[2631] = 37
# hostBins[2631] =  37
# CPU and GPU results are  equal.
# resultRef[2632] = 33
# hostBins[2632] =  33
# CPU and GPU results are  equal.
# resultRef[2633] = 33
# hostBins[2633] =  33
# CPU and GPU results are  equal.
# resultRef[2634] = 24
# hostBins[2634] =  24
# CPU and GPU results are  equal.
# resultRef[2635] = 38
# hostBins[2635] =  38
# CPU and GPU results are  equal.
# resultRef[2636] = 31
# hostBins[2636] =  31
# CPU and GPU results are  equal.
# resultRef[2637] = 32
# hostBins[2637] =  32
# CPU and GPU results are  equal.
# resultRef[2638] = 37
# hostBins[2638] =  37
# CPU and GPU results are  equal.
# resultRef[2639] = 35
# hostBins[2639] =  35
# CPU and GPU results are  equal.
# resultRef[2640] = 28
# hostBins[2640] =  28
# CPU and GPU results are  equal.
# resultRef[2641] = 34
# hostBins[2641] =  34
# CPU and GPU results are  equal.
# resultRef[2642] = 30
# hostBins[2642] =  30
# CPU and GPU results are  equal.
# resultRef[2643] = 39
# hostBins[2643] =  39
# CPU and GPU results are  equal.
# resultRef[2644] = 28
# hostBins[2644] =  28
# CPU and GPU results are  equal.
# resultRef[2645] = 33
# hostBins[2645] =  33
# CPU and GPU results are  equal.
# resultRef[2646] = 37
# hostBins[2646] =  37
# CPU and GPU results are  equal.
# resultRef[2647] = 30
# hostBins[2647] =  30
# CPU and GPU results are  equal.
# resultRef[2648] = 39
# hostBins[2648] =  39
# CPU and GPU results are  equal.
# resultRef[2649] = 32
# hostBins[2649] =  32
# CPU and GPU results are  equal.
# resultRef[2650] = 31
# hostBins[2650] =  31
# CPU and GPU results are  equal.
# resultRef[2651] = 28
# hostBins[2651] =  28
# CPU and GPU results are  equal.
# resultRef[2652] = 30
# hostBins[2652] =  30
# CPU and GPU results are  equal.
# resultRef[2653] = 44
# hostBins[2653] =  44
# CPU and GPU results are  equal.
# resultRef[2654] = 35
# hostBins[2654] =  35
# CPU and GPU results are  equal.
# resultRef[2655] = 32
# hostBins[2655] =  32
# CPU and GPU results are  equal.
# resultRef[2656] = 38
# hostBins[2656] =  38
# CPU and GPU results are  equal.
# resultRef[2657] = 39
# hostBins[2657] =  39
# CPU and GPU results are  equal.
# resultRef[2658] = 43
# hostBins[2658] =  43
# CPU and GPU results are  equal.
# resultRef[2659] = 30
# hostBins[2659] =  30
# CPU and GPU results are  equal.
# resultRef[2660] = 27
# hostBins[2660] =  27
# CPU and GPU results are  equal.
# resultRef[2661] = 47
# hostBins[2661] =  47
# CPU and GPU results are  equal.
# resultRef[2662] = 35
# hostBins[2662] =  35
# CPU and GPU results are  equal.
# resultRef[2663] = 20
# hostBins[2663] =  20
# CPU and GPU results are  equal.
# resultRef[2664] = 28
# hostBins[2664] =  28
# CPU and GPU results are  equal.
# resultRef[2665] = 26
# hostBins[2665] =  26
# CPU and GPU results are  equal.
# resultRef[2666] = 26
# hostBins[2666] =  26
# CPU and GPU results are  equal.
# resultRef[2667] = 29
# hostBins[2667] =  29
# CPU and GPU results are  equal.
# resultRef[2668] = 35
# hostBins[2668] =  35
# CPU and GPU results are  equal.
# resultRef[2669] = 26
# hostBins[2669] =  26
# CPU and GPU results are  equal.
# resultRef[2670] = 33
# hostBins[2670] =  33
# CPU and GPU results are  equal.
# resultRef[2671] = 32
# hostBins[2671] =  32
# CPU and GPU results are  equal.
# resultRef[2672] = 28
# hostBins[2672] =  28
# CPU and GPU results are  equal.
# resultRef[2673] = 29
# hostBins[2673] =  29
# CPU and GPU results are  equal.
# resultRef[2674] = 37
# hostBins[2674] =  37
# CPU and GPU results are  equal.
# resultRef[2675] = 28
# hostBins[2675] =  28
# CPU and GPU results are  equal.
# resultRef[2676] = 24
# hostBins[2676] =  24
# CPU and GPU results are  equal.
# resultRef[2677] = 20
# hostBins[2677] =  20
# CPU and GPU results are  equal.
# resultRef[2678] = 25
# hostBins[2678] =  25
# CPU and GPU results are  equal.
# resultRef[2679] = 27
# hostBins[2679] =  27
# CPU and GPU results are  equal.
# resultRef[2680] = 42
# hostBins[2680] =  42
# CPU and GPU results are  equal.
# resultRef[2681] = 29
# hostBins[2681] =  29
# CPU and GPU results are  equal.
# resultRef[2682] = 34
# hostBins[2682] =  34
# CPU and GPU results are  equal.
# resultRef[2683] = 25
# hostBins[2683] =  25
# CPU and GPU results are  equal.
# resultRef[2684] = 20
# hostBins[2684] =  20
# CPU and GPU results are  equal.
# resultRef[2685] = 35
# hostBins[2685] =  35
# CPU and GPU results are  equal.
# resultRef[2686] = 39
# hostBins[2686] =  39
# CPU and GPU results are  equal.
# resultRef[2687] = 28
# hostBins[2687] =  28
# CPU and GPU results are  equal.
# resultRef[2688] = 30
# hostBins[2688] =  30
# CPU and GPU results are  equal.
# resultRef[2689] = 32
# hostBins[2689] =  32
# CPU and GPU results are  equal.
# resultRef[2690] = 30
# hostBins[2690] =  30
# CPU and GPU results are  equal.
# resultRef[2691] = 38
# hostBins[2691] =  38
# CPU and GPU results are  equal.
# resultRef[2692] = 30
# hostBins[2692] =  30
# CPU and GPU results are  equal.
# resultRef[2693] = 24
# hostBins[2693] =  24
# CPU and GPU results are  equal.
# resultRef[2694] = 38
# hostBins[2694] =  38
# CPU and GPU results are  equal.
# resultRef[2695] = 26
# hostBins[2695] =  26
# CPU and GPU results are  equal.
# resultRef[2696] = 43
# hostBins[2696] =  43
# CPU and GPU results are  equal.
# resultRef[2697] = 31
# hostBins[2697] =  31
# CPU and GPU results are  equal.
# resultRef[2698] = 33
# hostBins[2698] =  33
# CPU and GPU results are  equal.
# resultRef[2699] = 40
# hostBins[2699] =  40
# CPU and GPU results are  equal.
# resultRef[2700] = 31
# hostBins[2700] =  31
# CPU and GPU results are  equal.
# resultRef[2701] = 29
# hostBins[2701] =  29
# CPU and GPU results are  equal.
# resultRef[2702] = 42
# hostBins[2702] =  42
# CPU and GPU results are  equal.
# resultRef[2703] = 40
# hostBins[2703] =  40
# CPU and GPU results are  equal.
# resultRef[2704] = 29
# hostBins[2704] =  29
# CPU and GPU results are  equal.
# resultRef[2705] = 44
# hostBins[2705] =  44
# CPU and GPU results are  equal.
# resultRef[2706] = 28
# hostBins[2706] =  28
# CPU and GPU results are  equal.
# resultRef[2707] = 33
# hostBins[2707] =  33
# CPU and GPU results are  equal.
# resultRef[2708] = 20
# hostBins[2708] =  20
# CPU and GPU results are  equal.
# resultRef[2709] = 28
# hostBins[2709] =  28
# CPU and GPU results are  equal.
# resultRef[2710] = 36
# hostBins[2710] =  36
# CPU and GPU results are  equal.
# resultRef[2711] = 39
# hostBins[2711] =  39
# CPU and GPU results are  equal.
# resultRef[2712] = 27
# hostBins[2712] =  27
# CPU and GPU results are  equal.
# resultRef[2713] = 30
# hostBins[2713] =  30
# CPU and GPU results are  equal.
# resultRef[2714] = 25
# hostBins[2714] =  25
# CPU and GPU results are  equal.
# resultRef[2715] = 34
# hostBins[2715] =  34
# CPU and GPU results are  equal.
# resultRef[2716] = 29
# hostBins[2716] =  29
# CPU and GPU results are  equal.
# resultRef[2717] = 30
# hostBins[2717] =  30
# CPU and GPU results are  equal.
# resultRef[2718] = 35
# hostBins[2718] =  35
# CPU and GPU results are  equal.
# resultRef[2719] = 33
# hostBins[2719] =  33
# CPU and GPU results are  equal.
# resultRef[2720] = 35
# hostBins[2720] =  35
# CPU and GPU results are  equal.
# resultRef[2721] = 36
# hostBins[2721] =  36
# CPU and GPU results are  equal.
# resultRef[2722] = 33
# hostBins[2722] =  33
# CPU and GPU results are  equal.
# resultRef[2723] = 34
# hostBins[2723] =  34
# CPU and GPU results are  equal.
# resultRef[2724] = 30
# hostBins[2724] =  30
# CPU and GPU results are  equal.
# resultRef[2725] = 30
# hostBins[2725] =  30
# CPU and GPU results are  equal.
# resultRef[2726] = 31
# hostBins[2726] =  31
# CPU and GPU results are  equal.
# resultRef[2727] = 28
# hostBins[2727] =  28
# CPU and GPU results are  equal.
# resultRef[2728] = 36
# hostBins[2728] =  36
# CPU and GPU results are  equal.
# resultRef[2729] = 20
# hostBins[2729] =  20
# CPU and GPU results are  equal.
# resultRef[2730] = 35
# hostBins[2730] =  35
# CPU and GPU results are  equal.
# resultRef[2731] = 39
# hostBins[2731] =  39
# CPU and GPU results are  equal.
# resultRef[2732] = 27
# hostBins[2732] =  27
# CPU and GPU results are  equal.
# resultRef[2733] = 27
# hostBins[2733] =  27
# CPU and GPU results are  equal.
# resultRef[2734] = 36
# hostBins[2734] =  36
# CPU and GPU results are  equal.
# resultRef[2735] = 33
# hostBins[2735] =  33
# CPU and GPU results are  equal.
# resultRef[2736] = 34
# hostBins[2736] =  34
# CPU and GPU results are  equal.
# resultRef[2737] = 26
# hostBins[2737] =  26
# CPU and GPU results are  equal.
# resultRef[2738] = 35
# hostBins[2738] =  35
# CPU and GPU results are  equal.
# resultRef[2739] = 33
# hostBins[2739] =  33
# CPU and GPU results are  equal.
# resultRef[2740] = 34
# hostBins[2740] =  34
# CPU and GPU results are  equal.
# resultRef[2741] = 30
# hostBins[2741] =  30
# CPU and GPU results are  equal.
# resultRef[2742] = 29
# hostBins[2742] =  29
# CPU and GPU results are  equal.
# resultRef[2743] = 31
# hostBins[2743] =  31
# CPU and GPU results are  equal.
# resultRef[2744] = 35
# hostBins[2744] =  35
# CPU and GPU results are  equal.
# resultRef[2745] = 30
# hostBins[2745] =  30
# CPU and GPU results are  equal.
# resultRef[2746] = 36
# hostBins[2746] =  36
# CPU and GPU results are  equal.
# resultRef[2747] = 28
# hostBins[2747] =  28
# CPU and GPU results are  equal.
# resultRef[2748] = 38
# hostBins[2748] =  38
# CPU and GPU results are  equal.
# resultRef[2749] = 33
# hostBins[2749] =  33
# CPU and GPU results are  equal.
# resultRef[2750] = 31
# hostBins[2750] =  31
# CPU and GPU results are  equal.
# resultRef[2751] = 29
# hostBins[2751] =  29
# CPU and GPU results are  equal.
# resultRef[2752] = 31
# hostBins[2752] =  31
# CPU and GPU results are  equal.
# resultRef[2753] = 40
# hostBins[2753] =  40
# CPU and GPU results are  equal.
# resultRef[2754] = 19
# hostBins[2754] =  19
# CPU and GPU results are  equal.
# resultRef[2755] = 30
# hostBins[2755] =  30
# CPU and GPU results are  equal.
# resultRef[2756] = 34
# hostBins[2756] =  34
# CPU and GPU results are  equal.
# resultRef[2757] = 31
# hostBins[2757] =  31
# CPU and GPU results are  equal.
# resultRef[2758] = 30
# hostBins[2758] =  30
# CPU and GPU results are  equal.
# resultRef[2759] = 32
# hostBins[2759] =  32
# CPU and GPU results are  equal.
# resultRef[2760] = 29
# hostBins[2760] =  29
# CPU and GPU results are  equal.
# resultRef[2761] = 33
# hostBins[2761] =  33
# CPU and GPU results are  equal.
# resultRef[2762] = 36
# hostBins[2762] =  36
# CPU and GPU results are  equal.
# resultRef[2763] = 24
# hostBins[2763] =  24
# CPU and GPU results are  equal.
# resultRef[2764] = 35
# hostBins[2764] =  35
# CPU and GPU results are  equal.
# resultRef[2765] = 36
# hostBins[2765] =  36
# CPU and GPU results are  equal.
# resultRef[2766] = 41
# hostBins[2766] =  41
# CPU and GPU results are  equal.
# resultRef[2767] = 26
# hostBins[2767] =  26
# CPU and GPU results are  equal.
# resultRef[2768] = 42
# hostBins[2768] =  42
# CPU and GPU results are  equal.
# resultRef[2769] = 24
# hostBins[2769] =  24
# CPU and GPU results are  equal.
# resultRef[2770] = 30
# hostBins[2770] =  30
# CPU and GPU results are  equal.
# resultRef[2771] = 35
# hostBins[2771] =  35
# CPU and GPU results are  equal.
# resultRef[2772] = 26
# hostBins[2772] =  26
# CPU and GPU results are  equal.
# resultRef[2773] = 26
# hostBins[2773] =  26
# CPU and GPU results are  equal.
# resultRef[2774] = 30
# hostBins[2774] =  30
# CPU and GPU results are  equal.
# resultRef[2775] = 38
# hostBins[2775] =  38
# CPU and GPU results are  equal.
# resultRef[2776] = 40
# hostBins[2776] =  40
# CPU and GPU results are  equal.
# resultRef[2777] = 28
# hostBins[2777] =  28
# CPU and GPU results are  equal.
# resultRef[2778] = 30
# hostBins[2778] =  30
# CPU and GPU results are  equal.
# resultRef[2779] = 33
# hostBins[2779] =  33
# CPU and GPU results are  equal.
# resultRef[2780] = 22
# hostBins[2780] =  22
# CPU and GPU results are  equal.
# resultRef[2781] = 25
# hostBins[2781] =  25
# CPU and GPU results are  equal.
# resultRef[2782] = 28
# hostBins[2782] =  28
# CPU and GPU results are  equal.
# resultRef[2783] = 44
# hostBins[2783] =  44
# CPU and GPU results are  equal.
# resultRef[2784] = 36
# hostBins[2784] =  36
# CPU and GPU results are  equal.
# resultRef[2785] = 26
# hostBins[2785] =  26
# CPU and GPU results are  equal.
# resultRef[2786] = 28
# hostBins[2786] =  28
# CPU and GPU results are  equal.
# resultRef[2787] = 29
# hostBins[2787] =  29
# CPU and GPU results are  equal.
# resultRef[2788] = 23
# hostBins[2788] =  23
# CPU and GPU results are  equal.
# resultRef[2789] = 25
# hostBins[2789] =  25
# CPU and GPU results are  equal.
# resultRef[2790] = 30
# hostBins[2790] =  30
# CPU and GPU results are  equal.
# resultRef[2791] = 31
# hostBins[2791] =  31
# CPU and GPU results are  equal.
# resultRef[2792] = 31
# hostBins[2792] =  31
# CPU and GPU results are  equal.
# resultRef[2793] = 25
# hostBins[2793] =  25
# CPU and GPU results are  equal.
# resultRef[2794] = 35
# hostBins[2794] =  35
# CPU and GPU results are  equal.
# resultRef[2795] = 33
# hostBins[2795] =  33
# CPU and GPU results are  equal.
# resultRef[2796] = 38
# hostBins[2796] =  38
# CPU and GPU results are  equal.
# resultRef[2797] = 36
# hostBins[2797] =  36
# CPU and GPU results are  equal.
# resultRef[2798] = 26
# hostBins[2798] =  26
# CPU and GPU results are  equal.
# resultRef[2799] = 21
# hostBins[2799] =  21
# CPU and GPU results are  equal.
# resultRef[2800] = 26
# hostBins[2800] =  26
# CPU and GPU results are  equal.
# resultRef[2801] = 27
# hostBins[2801] =  27
# CPU and GPU results are  equal.
# resultRef[2802] = 37
# hostBins[2802] =  37
# CPU and GPU results are  equal.
# resultRef[2803] = 25
# hostBins[2803] =  25
# CPU and GPU results are  equal.
# resultRef[2804] = 32
# hostBins[2804] =  32
# CPU and GPU results are  equal.
# resultRef[2805] = 41
# hostBins[2805] =  41
# CPU and GPU results are  equal.
# resultRef[2806] = 36
# hostBins[2806] =  36
# CPU and GPU results are  equal.
# resultRef[2807] = 39
# hostBins[2807] =  39
# CPU and GPU results are  equal.
# resultRef[2808] = 31
# hostBins[2808] =  31
# CPU and GPU results are  equal.
# resultRef[2809] = 33
# hostBins[2809] =  33
# CPU and GPU results are  equal.
# resultRef[2810] = 30
# hostBins[2810] =  30
# CPU and GPU results are  equal.
# resultRef[2811] = 26
# hostBins[2811] =  26
# CPU and GPU results are  equal.
# resultRef[2812] = 33
# hostBins[2812] =  33
# CPU and GPU results are  equal.
# resultRef[2813] = 30
# hostBins[2813] =  30
# CPU and GPU results are  equal.
# resultRef[2814] = 29
# hostBins[2814] =  29
# CPU and GPU results are  equal.
# resultRef[2815] = 22
# hostBins[2815] =  22
# CPU and GPU results are  equal.
# resultRef[2816] = 36
# hostBins[2816] =  36
# CPU and GPU results are  equal.
# resultRef[2817] = 45
# hostBins[2817] =  45
# CPU and GPU results are  equal.
# resultRef[2818] = 30
# hostBins[2818] =  30
# CPU and GPU results are  equal.
# resultRef[2819] = 28
# hostBins[2819] =  28
# CPU and GPU results are  equal.
# resultRef[2820] = 45
# hostBins[2820] =  45
# CPU and GPU results are  equal.
# resultRef[2821] = 30
# hostBins[2821] =  30
# CPU and GPU results are  equal.
# resultRef[2822] = 28
# hostBins[2822] =  28
# CPU and GPU results are  equal.
# resultRef[2823] = 30
# hostBins[2823] =  30
# CPU and GPU results are  equal.
# resultRef[2824] = 37
# hostBins[2824] =  37
# CPU and GPU results are  equal.
# resultRef[2825] = 30
# hostBins[2825] =  30
# CPU and GPU results are  equal.
# resultRef[2826] = 31
# hostBins[2826] =  31
# CPU and GPU results are  equal.
# resultRef[2827] = 30
# hostBins[2827] =  30
# CPU and GPU results are  equal.
# resultRef[2828] = 33
# hostBins[2828] =  33
# CPU and GPU results are  equal.
# resultRef[2829] = 26
# hostBins[2829] =  26
# CPU and GPU results are  equal.
# resultRef[2830] = 32
# hostBins[2830] =  32
# CPU and GPU results are  equal.
# resultRef[2831] = 37
# hostBins[2831] =  37
# CPU and GPU results are  equal.
# resultRef[2832] = 32
# hostBins[2832] =  32
# CPU and GPU results are  equal.
# resultRef[2833] = 27
# hostBins[2833] =  27
# CPU and GPU results are  equal.
# resultRef[2834] = 35
# hostBins[2834] =  35
# CPU and GPU results are  equal.
# resultRef[2835] = 22
# hostBins[2835] =  22
# CPU and GPU results are  equal.
# resultRef[2836] = 39
# hostBins[2836] =  39
# CPU and GPU results are  equal.
# resultRef[2837] = 30
# hostBins[2837] =  30
# CPU and GPU results are  equal.
# resultRef[2838] = 31
# hostBins[2838] =  31
# CPU and GPU results are  equal.
# resultRef[2839] = 34
# hostBins[2839] =  34
# CPU and GPU results are  equal.
# resultRef[2840] = 34
# hostBins[2840] =  34
# CPU and GPU results are  equal.
# resultRef[2841] = 18
# hostBins[2841] =  18
# CPU and GPU results are  equal.
# resultRef[2842] = 29
# hostBins[2842] =  29
# CPU and GPU results are  equal.
# resultRef[2843] = 38
# hostBins[2843] =  38
# CPU and GPU results are  equal.
# resultRef[2844] = 29
# hostBins[2844] =  29
# CPU and GPU results are  equal.
# resultRef[2845] = 40
# hostBins[2845] =  40
# CPU and GPU results are  equal.
# resultRef[2846] = 29
# hostBins[2846] =  29
# CPU and GPU results are  equal.
# resultRef[2847] = 35
# hostBins[2847] =  35
# CPU and GPU results are  equal.
# resultRef[2848] = 23
# hostBins[2848] =  23
# CPU and GPU results are  equal.
# resultRef[2849] = 32
# hostBins[2849] =  32
# CPU and GPU results are  equal.
# resultRef[2850] = 35
# hostBins[2850] =  35
# CPU and GPU results are  equal.
# resultRef[2851] = 32
# hostBins[2851] =  32
# CPU and GPU results are  equal.
# resultRef[2852] = 35
# hostBins[2852] =  35
# CPU and GPU results are  equal.
# resultRef[2853] = 45
# hostBins[2853] =  45
# CPU and GPU results are  equal.
# resultRef[2854] = 36
# hostBins[2854] =  36
# CPU and GPU results are  equal.
# resultRef[2855] = 36
# hostBins[2855] =  36
# CPU and GPU results are  equal.
# resultRef[2856] = 36
# hostBins[2856] =  36
# CPU and GPU results are  equal.
# resultRef[2857] = 40
# hostBins[2857] =  40
# CPU and GPU results are  equal.
# resultRef[2858] = 32
# hostBins[2858] =  32
# CPU and GPU results are  equal.
# resultRef[2859] = 29
# hostBins[2859] =  29
# CPU and GPU results are  equal.
# resultRef[2860] = 33
# hostBins[2860] =  33
# CPU and GPU results are  equal.
# resultRef[2861] = 27
# hostBins[2861] =  27
# CPU and GPU results are  equal.
# resultRef[2862] = 30
# hostBins[2862] =  30
# CPU and GPU results are  equal.
# resultRef[2863] = 30
# hostBins[2863] =  30
# CPU and GPU results are  equal.
# resultRef[2864] = 28
# hostBins[2864] =  28
# CPU and GPU results are  equal.
# resultRef[2865] = 39
# hostBins[2865] =  39
# CPU and GPU results are  equal.
# resultRef[2866] = 37
# hostBins[2866] =  37
# CPU and GPU results are  equal.
# resultRef[2867] = 37
# hostBins[2867] =  37
# CPU and GPU results are  equal.
# resultRef[2868] = 27
# hostBins[2868] =  27
# CPU and GPU results are  equal.
# resultRef[2869] = 36
# hostBins[2869] =  36
# CPU and GPU results are  equal.
# resultRef[2870] = 33
# hostBins[2870] =  33
# CPU and GPU results are  equal.
# resultRef[2871] = 32
# hostBins[2871] =  32
# CPU and GPU results are  equal.
# resultRef[2872] = 31
# hostBins[2872] =  31
# CPU and GPU results are  equal.
# resultRef[2873] = 31
# hostBins[2873] =  31
# CPU and GPU results are  equal.
# resultRef[2874] = 35
# hostBins[2874] =  35
# CPU and GPU results are  equal.
# resultRef[2875] = 32
# hostBins[2875] =  32
# CPU and GPU results are  equal.
# resultRef[2876] = 28
# hostBins[2876] =  28
# CPU and GPU results are  equal.
# resultRef[2877] = 31
# hostBins[2877] =  31
# CPU and GPU results are  equal.
# resultRef[2878] = 30
# hostBins[2878] =  30
# CPU and GPU results are  equal.
# resultRef[2879] = 22
# hostBins[2879] =  22
# CPU and GPU results are  equal.
# resultRef[2880] = 38
# hostBins[2880] =  38
# CPU and GPU results are  equal.
# resultRef[2881] = 37
# hostBins[2881] =  37
# CPU and GPU results are  equal.
# resultRef[2882] = 36
# hostBins[2882] =  36
# CPU and GPU results are  equal.
# resultRef[2883] = 43
# hostBins[2883] =  43
# CPU and GPU results are  equal.
# resultRef[2884] = 34
# hostBins[2884] =  34
# CPU and GPU results are  equal.
# resultRef[2885] = 28
# hostBins[2885] =  28
# CPU and GPU results are  equal.
# resultRef[2886] = 28
# hostBins[2886] =  28
# CPU and GPU results are  equal.
# resultRef[2887] = 28
# hostBins[2887] =  28
# CPU and GPU results are  equal.
# resultRef[2888] = 29
# hostBins[2888] =  29
# CPU and GPU results are  equal.
# resultRef[2889] = 31
# hostBins[2889] =  31
# CPU and GPU results are  equal.
# resultRef[2890] = 29
# hostBins[2890] =  29
# CPU and GPU results are  equal.
# resultRef[2891] = 29
# hostBins[2891] =  29
# CPU and GPU results are  equal.
# resultRef[2892] = 29
# hostBins[2892] =  29
# CPU and GPU results are  equal.
# resultRef[2893] = 29
# hostBins[2893] =  29
# CPU and GPU results are  equal.
# resultRef[2894] = 30
# hostBins[2894] =  30
# CPU and GPU results are  equal.
# resultRef[2895] = 33
# hostBins[2895] =  33
# CPU and GPU results are  equal.
# resultRef[2896] = 39
# hostBins[2896] =  39
# CPU and GPU results are  equal.
# resultRef[2897] = 46
# hostBins[2897] =  46
# CPU and GPU results are  equal.
# resultRef[2898] = 27
# hostBins[2898] =  27
# CPU and GPU results are  equal.
# resultRef[2899] = 34
# hostBins[2899] =  34
# CPU and GPU results are  equal.
# resultRef[2900] = 27
# hostBins[2900] =  27
# CPU and GPU results are  equal.
# resultRef[2901] = 26
# hostBins[2901] =  26
# CPU and GPU results are  equal.
# resultRef[2902] = 22
# hostBins[2902] =  22
# CPU and GPU results are  equal.
# resultRef[2903] = 40
# hostBins[2903] =  40
# CPU and GPU results are  equal.
# resultRef[2904] = 34
# hostBins[2904] =  34
# CPU and GPU results are  equal.
# resultRef[2905] = 36
# hostBins[2905] =  36
# CPU and GPU results are  equal.
# resultRef[2906] = 35
# hostBins[2906] =  35
# CPU and GPU results are  equal.
# resultRef[2907] = 30
# hostBins[2907] =  30
# CPU and GPU results are  equal.
# resultRef[2908] = 35
# hostBins[2908] =  35
# CPU and GPU results are  equal.
# resultRef[2909] = 21
# hostBins[2909] =  21
# CPU and GPU results are  equal.
# resultRef[2910] = 31
# hostBins[2910] =  31
# CPU and GPU results are  equal.
# resultRef[2911] = 32
# hostBins[2911] =  32
# CPU and GPU results are  equal.
# resultRef[2912] = 23
# hostBins[2912] =  23
# CPU and GPU results are  equal.
# resultRef[2913] = 30
# hostBins[2913] =  30
# CPU and GPU results are  equal.
# resultRef[2914] = 21
# hostBins[2914] =  21
# CPU and GPU results are  equal.
# resultRef[2915] = 29
# hostBins[2915] =  29
# CPU and GPU results are  equal.
# resultRef[2916] = 34
# hostBins[2916] =  34
# CPU and GPU results are  equal.
# resultRef[2917] = 33
# hostBins[2917] =  33
# CPU and GPU results are  equal.
# resultRef[2918] = 31
# hostBins[2918] =  31
# CPU and GPU results are  equal.
# resultRef[2919] = 33
# hostBins[2919] =  33
# CPU and GPU results are  equal.
# resultRef[2920] = 29
# hostBins[2920] =  29
# CPU and GPU results are  equal.
# resultRef[2921] = 30
# hostBins[2921] =  30
# CPU and GPU results are  equal.
# resultRef[2922] = 35
# hostBins[2922] =  35
# CPU and GPU results are  equal.
# resultRef[2923] = 32
# hostBins[2923] =  32
# CPU and GPU results are  equal.
# resultRef[2924] = 33
# hostBins[2924] =  33
# CPU and GPU results are  equal.
# resultRef[2925] = 28
# hostBins[2925] =  28
# CPU and GPU results are  equal.
# resultRef[2926] = 27
# hostBins[2926] =  27
# CPU and GPU results are  equal.
# resultRef[2927] = 33
# hostBins[2927] =  33
# CPU and GPU results are  equal.
# resultRef[2928] = 21
# hostBins[2928] =  21
# CPU and GPU results are  equal.
# resultRef[2929] = 23
# hostBins[2929] =  23
# CPU and GPU results are  equal.
# resultRef[2930] = 29
# hostBins[2930] =  29
# CPU and GPU results are  equal.
# resultRef[2931] = 24
# hostBins[2931] =  24
# CPU and GPU results are  equal.
# resultRef[2932] = 42
# hostBins[2932] =  42
# CPU and GPU results are  equal.
# resultRef[2933] = 27
# hostBins[2933] =  27
# CPU and GPU results are  equal.
# resultRef[2934] = 23
# hostBins[2934] =  23
# CPU and GPU results are  equal.
# resultRef[2935] = 28
# hostBins[2935] =  28
# CPU and GPU results are  equal.
# resultRef[2936] = 26
# hostBins[2936] =  26
# CPU and GPU results are  equal.
# resultRef[2937] = 37
# hostBins[2937] =  37
# CPU and GPU results are  equal.
# resultRef[2938] = 29
# hostBins[2938] =  29
# CPU and GPU results are  equal.
# resultRef[2939] = 32
# hostBins[2939] =  32
# CPU and GPU results are  equal.
# resultRef[2940] = 25
# hostBins[2940] =  25
# CPU and GPU results are  equal.
# resultRef[2941] = 37
# hostBins[2941] =  37
# CPU and GPU results are  equal.
# resultRef[2942] = 35
# hostBins[2942] =  35
# CPU and GPU results are  equal.
# resultRef[2943] = 42
# hostBins[2943] =  42
# CPU and GPU results are  equal.
# resultRef[2944] = 28
# hostBins[2944] =  28
# CPU and GPU results are  equal.
# resultRef[2945] = 35
# hostBins[2945] =  35
# CPU and GPU results are  equal.
# resultRef[2946] = 42
# hostBins[2946] =  42
# CPU and GPU results are  equal.
# resultRef[2947] = 29
# hostBins[2947] =  29
# CPU and GPU results are  equal.
# resultRef[2948] = 27
# hostBins[2948] =  27
# CPU and GPU results are  equal.
# resultRef[2949] = 45
# hostBins[2949] =  45
# CPU and GPU results are  equal.
# resultRef[2950] = 28
# hostBins[2950] =  28
# CPU and GPU results are  equal.
# resultRef[2951] = 35
# hostBins[2951] =  35
# CPU and GPU results are  equal.
# resultRef[2952] = 48
# hostBins[2952] =  48
# CPU and GPU results are  equal.
# resultRef[2953] = 39
# hostBins[2953] =  39
# CPU and GPU results are  equal.
# resultRef[2954] = 38
# hostBins[2954] =  38
# CPU and GPU results are  equal.
# resultRef[2955] = 32
# hostBins[2955] =  32
# CPU and GPU results are  equal.
# resultRef[2956] = 34
# hostBins[2956] =  34
# CPU and GPU results are  equal.
# resultRef[2957] = 35
# hostBins[2957] =  35
# CPU and GPU results are  equal.
# resultRef[2958] = 33
# hostBins[2958] =  33
# CPU and GPU results are  equal.
# resultRef[2959] = 34
# hostBins[2959] =  34
# CPU and GPU results are  equal.
# resultRef[2960] = 35
# hostBins[2960] =  35
# CPU and GPU results are  equal.
# resultRef[2961] = 24
# hostBins[2961] =  24
# CPU and GPU results are  equal.
# resultRef[2962] = 31
# hostBins[2962] =  31
# CPU and GPU results are  equal.
# resultRef[2963] = 35
# hostBins[2963] =  35
# CPU and GPU results are  equal.
# resultRef[2964] = 25
# hostBins[2964] =  25
# CPU and GPU results are  equal.
# resultRef[2965] = 47
# hostBins[2965] =  47
# CPU and GPU results are  equal.
# resultRef[2966] = 38
# hostBins[2966] =  38
# CPU and GPU results are  equal.
# resultRef[2967] = 40
# hostBins[2967] =  40
# CPU and GPU results are  equal.
# resultRef[2968] = 31
# hostBins[2968] =  31
# CPU and GPU results are  equal.
# resultRef[2969] = 28
# hostBins[2969] =  28
# CPU and GPU results are  equal.
# resultRef[2970] = 35
# hostBins[2970] =  35
# CPU and GPU results are  equal.
# resultRef[2971] = 29
# hostBins[2971] =  29
# CPU and GPU results are  equal.
# resultRef[2972] = 26
# hostBins[2972] =  26
# CPU and GPU results are  equal.
# resultRef[2973] = 40
# hostBins[2973] =  40
# CPU and GPU results are  equal.
# resultRef[2974] = 22
# hostBins[2974] =  22
# CPU and GPU results are  equal.
# resultRef[2975] = 31
# hostBins[2975] =  31
# CPU and GPU results are  equal.
# resultRef[2976] = 25
# hostBins[2976] =  25
# CPU and GPU results are  equal.
# resultRef[2977] = 27
# hostBins[2977] =  27
# CPU and GPU results are  equal.
# resultRef[2978] = 32
# hostBins[2978] =  32
# CPU and GPU results are  equal.
# resultRef[2979] = 23
# hostBins[2979] =  23
# CPU and GPU results are  equal.
# resultRef[2980] = 27
# hostBins[2980] =  27
# CPU and GPU results are  equal.
# resultRef[2981] = 33
# hostBins[2981] =  33
# CPU and GPU results are  equal.
# resultRef[2982] = 30
# hostBins[2982] =  30
# CPU and GPU results are  equal.
# resultRef[2983] = 32
# hostBins[2983] =  32
# CPU and GPU results are  equal.
# resultRef[2984] = 29
# hostBins[2984] =  29
# CPU and GPU results are  equal.
# resultRef[2985] = 30
# hostBins[2985] =  30
# CPU and GPU results are  equal.
# resultRef[2986] = 36
# hostBins[2986] =  36
# CPU and GPU results are  equal.
# resultRef[2987] = 27
# hostBins[2987] =  27
# CPU and GPU results are  equal.
# resultRef[2988] = 33
# hostBins[2988] =  33
# CPU and GPU results are  equal.
# resultRef[2989] = 25
# hostBins[2989] =  25
# CPU and GPU results are  equal.
# resultRef[2990] = 29
# hostBins[2990] =  29
# CPU and GPU results are  equal.
# resultRef[2991] = 46
# hostBins[2991] =  46
# CPU and GPU results are  equal.
# resultRef[2992] = 30
# hostBins[2992] =  30
# CPU and GPU results are  equal.
# resultRef[2993] = 28
# hostBins[2993] =  28
# CPU and GPU results are  equal.
# resultRef[2994] = 32
# hostBins[2994] =  32
# CPU and GPU results are  equal.
# resultRef[2995] = 32
# hostBins[2995] =  32
# CPU and GPU results are  equal.
# resultRef[2996] = 28
# hostBins[2996] =  28
# CPU and GPU results are  equal.
# resultRef[2997] = 27
# hostBins[2997] =  27
# CPU and GPU results are  equal.
# resultRef[2998] = 38
# hostBins[2998] =  38
# CPU and GPU results are  equal.
# resultRef[2999] = 34
# hostBins[2999] =  34
# CPU and GPU results are  equal.
# resultRef[3000] = 26
# hostBins[3000] =  26
# CPU and GPU results are  equal.
# resultRef[3001] = 27
# hostBins[3001] =  27
# CPU and GPU results are  equal.
# resultRef[3002] = 33
# hostBins[3002] =  33
# CPU and GPU results are  equal.
# resultRef[3003] = 37
# hostBins[3003] =  37
# CPU and GPU results are  equal.
# resultRef[3004] = 32
# hostBins[3004] =  32
# CPU and GPU results are  equal.
# resultRef[3005] = 31
# hostBins[3005] =  31
# CPU and GPU results are  equal.
# resultRef[3006] = 32
# hostBins[3006] =  32
# CPU and GPU results are  equal.
# resultRef[3007] = 32
# hostBins[3007] =  32
# CPU and GPU results are  equal.
# resultRef[3008] = 31
# hostBins[3008] =  31
# CPU and GPU results are  equal.
# resultRef[3009] = 41
# hostBins[3009] =  41
# CPU and GPU results are  equal.
# resultRef[3010] = 22
# hostBins[3010] =  22
# CPU and GPU results are  equal.
# resultRef[3011] = 37
# hostBins[3011] =  37
# CPU and GPU results are  equal.
# resultRef[3012] = 26
# hostBins[3012] =  26
# CPU and GPU results are  equal.
# resultRef[3013] = 38
# hostBins[3013] =  38
# CPU and GPU results are  equal.
# resultRef[3014] = 33
# hostBins[3014] =  33
# CPU and GPU results are  equal.
# resultRef[3015] = 31
# hostBins[3015] =  31
# CPU and GPU results are  equal.
# resultRef[3016] = 32
# hostBins[3016] =  32
# CPU and GPU results are  equal.
# resultRef[3017] = 34
# hostBins[3017] =  34
# CPU and GPU results are  equal.
# resultRef[3018] = 32
# hostBins[3018] =  32
# CPU and GPU results are  equal.
# resultRef[3019] = 35
# hostBins[3019] =  35
# CPU and GPU results are  equal.
# resultRef[3020] = 28
# hostBins[3020] =  28
# CPU and GPU results are  equal.
# resultRef[3021] = 30
# hostBins[3021] =  30
# CPU and GPU results are  equal.
# resultRef[3022] = 35
# hostBins[3022] =  35
# CPU and GPU results are  equal.
# resultRef[3023] = 34
# hostBins[3023] =  34
# CPU and GPU results are  equal.
# resultRef[3024] = 37
# hostBins[3024] =  37
# CPU and GPU results are  equal.
# resultRef[3025] = 37
# hostBins[3025] =  37
# CPU and GPU results are  equal.
# resultRef[3026] = 36
# hostBins[3026] =  36
# CPU and GPU results are  equal.
# resultRef[3027] = 30
# hostBins[3027] =  30
# CPU and GPU results are  equal.
# resultRef[3028] = 41
# hostBins[3028] =  41
# CPU and GPU results are  equal.
# resultRef[3029] = 39
# hostBins[3029] =  39
# CPU and GPU results are  equal.
# resultRef[3030] = 29
# hostBins[3030] =  29
# CPU and GPU results are  equal.
# resultRef[3031] = 25
# hostBins[3031] =  25
# CPU and GPU results are  equal.
# resultRef[3032] = 34
# hostBins[3032] =  34
# CPU and GPU results are  equal.
# resultRef[3033] = 36
# hostBins[3033] =  36
# CPU and GPU results are  equal.
# resultRef[3034] = 30
# hostBins[3034] =  30
# CPU and GPU results are  equal.
# resultRef[3035] = 26
# hostBins[3035] =  26
# CPU and GPU results are  equal.
# resultRef[3036] = 31
# hostBins[3036] =  31
# CPU and GPU results are  equal.
# resultRef[3037] = 27
# hostBins[3037] =  27
# CPU and GPU results are  equal.
# resultRef[3038] = 34
# hostBins[3038] =  34
# CPU and GPU results are  equal.
# resultRef[3039] = 36
# hostBins[3039] =  36
# CPU and GPU results are  equal.
# resultRef[3040] = 30
# hostBins[3040] =  30
# CPU and GPU results are  equal.
# resultRef[3041] = 33
# hostBins[3041] =  33
# CPU and GPU results are  equal.
# resultRef[3042] = 26
# hostBins[3042] =  26
# CPU and GPU results are  equal.
# resultRef[3043] = 33
# hostBins[3043] =  33
# CPU and GPU results are  equal.
# resultRef[3044] = 26
# hostBins[3044] =  26
# CPU and GPU results are  equal.
# resultRef[3045] = 29
# hostBins[3045] =  29
# CPU and GPU results are  equal.
# resultRef[3046] = 30
# hostBins[3046] =  30
# CPU and GPU results are  equal.
# resultRef[3047] = 36
# hostBins[3047] =  36
# CPU and GPU results are  equal.
# resultRef[3048] = 33
# hostBins[3048] =  33
# CPU and GPU results are  equal.
# resultRef[3049] = 32
# hostBins[3049] =  32
# CPU and GPU results are  equal.
# resultRef[3050] = 45
# hostBins[3050] =  45
# CPU and GPU results are  equal.
# resultRef[3051] = 42
# hostBins[3051] =  42
# CPU and GPU results are  equal.
# resultRef[3052] = 16
# hostBins[3052] =  16
# CPU and GPU results are  equal.
# resultRef[3053] = 27
# hostBins[3053] =  27
# CPU and GPU results are  equal.
# resultRef[3054] = 37
# hostBins[3054] =  37
# CPU and GPU results are  equal.
# resultRef[3055] = 27
# hostBins[3055] =  27
# CPU and GPU results are  equal.
# resultRef[3056] = 42
# hostBins[3056] =  42
# CPU and GPU results are  equal.
# resultRef[3057] = 43
# hostBins[3057] =  43
# CPU and GPU results are  equal.
# resultRef[3058] = 24
# hostBins[3058] =  24
# CPU and GPU results are  equal.
# resultRef[3059] = 32
# hostBins[3059] =  32
# CPU and GPU results are  equal.
# resultRef[3060] = 38
# hostBins[3060] =  38
# CPU and GPU results are  equal.
# resultRef[3061] = 16
# hostBins[3061] =  16
# CPU and GPU results are  equal.
# resultRef[3062] = 35
# hostBins[3062] =  35
# CPU and GPU results are  equal.
# resultRef[3063] = 28
# hostBins[3063] =  28
# CPU and GPU results are  equal.
# resultRef[3064] = 25
# hostBins[3064] =  25
# CPU and GPU results are  equal.
# resultRef[3065] = 27
# hostBins[3065] =  27
# CPU and GPU results are  equal.
# resultRef[3066] = 26
# hostBins[3066] =  26
# CPU and GPU results are  equal.
# resultRef[3067] = 29
# hostBins[3067] =  29
# CPU and GPU results are  equal.
# resultRef[3068] = 37
# hostBins[3068] =  37
# CPU and GPU results are  equal.
# resultRef[3069] = 39
# hostBins[3069] =  39
# CPU and GPU results are  equal.
# resultRef[3070] = 33
# hostBins[3070] =  33
# CPU and GPU results are  equal.
# resultRef[3071] = 30
# hostBins[3071] =  30
# CPU and GPU results are  equal.
# resultRef[3072] = 37
# hostBins[3072] =  37
# CPU and GPU results are  equal.
# resultRef[3073] = 24
# hostBins[3073] =  24
# CPU and GPU results are  equal.
# resultRef[3074] = 39
# hostBins[3074] =  39
# CPU and GPU results are  equal.
# resultRef[3075] = 34
# hostBins[3075] =  34
# CPU and GPU results are  equal.
# resultRef[3076] = 34
# hostBins[3076] =  34
# CPU and GPU results are  equal.
# resultRef[3077] = 26
# hostBins[3077] =  26
# CPU and GPU results are  equal.
# resultRef[3078] = 41
# hostBins[3078] =  41
# CPU and GPU results are  equal.
# resultRef[3079] = 25
# hostBins[3079] =  25
# CPU and GPU results are  equal.
# resultRef[3080] = 30
# hostBins[3080] =  30
# CPU and GPU results are  equal.
# resultRef[3081] = 32
# hostBins[3081] =  32
# CPU and GPU results are  equal.
# resultRef[3082] = 35
# hostBins[3082] =  35
# CPU and GPU results are  equal.
# resultRef[3083] = 36
# hostBins[3083] =  36
# CPU and GPU results are  equal.
# resultRef[3084] = 28
# ...
# hostBins[3904] =  30
# CPU and GPU results are  equal.
# resultRef[3905] = 29
# hostBins[3905] =  29
# CPU and GPU results are  equal.
# resultRef[3906] = 29
# hostBins[3906] =  29
# CPU and GPU results are  equal.
# resultRef[3907] = 30
# hostBins[3907] =  30
# CPU and GPU results are  equal.
# resultRef[3908] = 33
# hostBins[3908] =  33
# CPU and GPU results are  equal.
# resultRef[3909] = 39
# hostBins[3909] =  39
# CPU and GPU results are  equal.
# resultRef[3910] = 26
# hostBins[3910] =  26
# CPU and GPU results are  equal.
# resultRef[3911] = 33
# hostBins[3911] =  33
# CPU and GPU results are  equal.
# resultRef[3912] = 32
# hostBins[3912] =  32
# CPU and GPU results are  equal.
# resultRef[3913] = 23
# hostBins[3913] =  23
# CPU and GPU results are  equal.
# resultRef[3914] = 36
# hostBins[3914] =  36
# CPU and GPU results are  equal.
# resultRef[3915] = 27
# hostBins[3915] =  27
# CPU and GPU results are  equal.
# resultRef[3916] = 26
# hostBins[3916] =  26
# CPU and GPU results are  equal.
# resultRef[3917] = 24
# hostBins[3917] =  24
# CPU and GPU results are  equal.
# resultRef[3918] = 32
# hostBins[3918] =  32
# CPU and GPU results are  equal.
# resultRef[3919] = 33
# hostBins[3919] =  33
# CPU and GPU results are  equal.
# resultRef[3920] = 37
# hostBins[3920] =  37
# CPU and GPU results are  equal.
# resultRef[3921] = 32
# hostBins[3921] =  32
# CPU and GPU results are  equal.
# resultRef[3922] = 35
# hostBins[3922] =  35
# CPU and GPU results are  equal.
# resultRef[3923] = 35
# hostBins[3923] =  35
# CPU and GPU results are  equal.
# resultRef[3924] = 29
# hostBins[3924] =  29
# CPU and GPU results are  equal.
# resultRef[3925] = 31
# hostBins[3925] =  31
# CPU and GPU results are  equal.
# resultRef[3926] = 35
# hostBins[3926] =  35
# CPU and GPU results are  equal.
# resultRef[3927] = 25
# hostBins[3927] =  25
# CPU and GPU results are  equal.
# resultRef[3928] = 32
# hostBins[3928] =  32
# CPU and GPU results are  equal.
# resultRef[3929] = 43
# hostBins[3929] =  43
# CPU and GPU results are  equal.
# resultRef[3930] = 33
# hostBins[3930] =  33
# CPU and GPU results are  equal.
# resultRef[3931] = 44
# hostBins[3931] =  44
# CPU and GPU results are  equal.
# resultRef[3932] = 31
# hostBins[3932] =  31
# CPU and GPU results are  equal.
# resultRef[3933] = 30
# hostBins[3933] =  30
# CPU and GPU results are  equal.
# resultRef[3934] = 27
# hostBins[3934] =  27
# CPU and GPU results are  equal.
# resultRef[3935] = 35
# hostBins[3935] =  35
# CPU and GPU results are  equal.
# resultRef[3936] = 27
# hostBins[3936] =  27
# CPU and GPU results are  equal.
# resultRef[3937] = 35
# hostBins[3937] =  35
# CPU and GPU results are  equal.
# resultRef[3938] = 29
# hostBins[3938] =  29
# CPU and GPU results are  equal.
# resultRef[3939] = 32
# hostBins[3939] =  32
# CPU and GPU results are  equal.
# resultRef[3940] = 36
# hostBins[3940] =  36
# CPU and GPU results are  equal.
# resultRef[3941] = 35
# hostBins[3941] =  35
# CPU and GPU results are  equal.
# resultRef[3942] = 35
# hostBins[3942] =  35
# CPU and GPU results are  equal.
# resultRef[3943] = 33
# hostBins[3943] =  33
# CPU and GPU results are  equal.
# resultRef[3944] = 41
# hostBins[3944] =  41
# CPU and GPU results are  equal.
# resultRef[3945] = 31
# hostBins[3945] =  31
# CPU and GPU results are  equal.
# resultRef[3946] = 35
# hostBins[3946] =  35
# CPU and GPU results are  equal.
# resultRef[3947] = 30
# hostBins[3947] =  30
# CPU and GPU results are  equal.
# resultRef[3948] = 24
# hostBins[3948] =  24
# CPU and GPU results are  equal.
# resultRef[3949] = 40
# hostBins[3949] =  40
# CPU and GPU results are  equal.
# resultRef[3950] = 27
# hostBins[3950] =  27
# CPU and GPU results are  equal.
# resultRef[3951] = 34
# hostBins[3951] =  34
# CPU and GPU results are  equal.
# resultRef[3952] = 24
# hostBins[3952] =  24
# CPU and GPU results are  equal.
# resultRef[3953] = 25
# hostBins[3953] =  25
# CPU and GPU results are  equal.
# resultRef[3954] = 34
# hostBins[3954] =  34
# CPU and GPU results are  equal.
# resultRef[3955] = 29
# hostBins[3955] =  29
# CPU and GPU results are  equal.
# resultRef[3956] = 32
# hostBins[3956] =  32
# CPU and GPU results are  equal.
# resultRef[3957] = 28
# hostBins[3957] =  28
# CPU and GPU results are  equal.
# resultRef[3958] = 34
# hostBins[3958] =  34
# CPU and GPU results are  equal.
# resultRef[3959] = 45
# hostBins[3959] =  45
# CPU and GPU results are  equal.
# resultRef[3960] = 31
# hostBins[3960] =  31
# CPU and GPU results are  equal.
# resultRef[3961] = 32
# hostBins[3961] =  32
# CPU and GPU results are  equal.
# resultRef[3962] = 35
# hostBins[3962] =  35
# CPU and GPU results are  equal.
# resultRef[3963] = 26
# hostBins[3963] =  26
# CPU and GPU results are  equal.
# resultRef[3964] = 42
# hostBins[3964] =  42
# CPU and GPU results are  equal.
# resultRef[3965] = 29
# hostBins[3965] =  29
# CPU and GPU results are  equal.
# resultRef[3966] = 28
# hostBins[3966] =  28
# CPU and GPU results are  equal.
# resultRef[3967] = 33
# hostBins[3967] =  33
# CPU and GPU results are  equal.
# resultRef[3968] = 41
# hostBins[3968] =  41
# CPU and GPU results are  equal.
# resultRef[3969] = 25
# hostBins[3969] =  25
# CPU and GPU results are  equal.
# resultRef[3970] = 25
# hostBins[3970] =  25
# CPU and GPU results are  equal.
# resultRef[3971] = 32
# hostBins[3971] =  32
# CPU and GPU results are  equal.
# resultRef[3972] = 29
# hostBins[3972] =  29
# CPU and GPU results are  equal.
# resultRef[3973] = 25
# hostBins[3973] =  25
# CPU and GPU results are  equal.
# resultRef[3974] = 24
# hostBins[3974] =  24
# CPU and GPU results are  equal.
# resultRef[3975] = 35
# hostBins[3975] =  35
# CPU and GPU results are  equal.
# resultRef[3976] = 27
# hostBins[3976] =  27
# CPU and GPU results are  equal.
# resultRef[3977] = 25
# hostBins[3977] =  25
# CPU and GPU results are  equal.
# resultRef[3978] = 41
# hostBins[3978] =  41
# CPU and GPU results are  equal.
# resultRef[3979] = 23
# hostBins[3979] =  23
# CPU and GPU results are  equal.
# resultRef[3980] = 40
# hostBins[3980] =  40
# CPU and GPU results are  equal.
# resultRef[3981] = 37
# hostBins[3981] =  37
# CPU and GPU results are  equal.
# resultRef[3982] = 29
# hostBins[3982] =  29
# CPU and GPU results are  equal.
# resultRef[3983] = 29
# hostBins[3983] =  29
# CPU and GPU results are  equal.
# resultRef[3984] = 36
# hostBins[3984] =  36
# CPU and GPU results are  equal.
# resultRef[3985] = 26
# hostBins[3985] =  26
# CPU and GPU results are  equal.
# resultRef[3986] = 27
# hostBins[3986] =  27
# CPU and GPU results are  equal.
# resultRef[3987] = 33
# hostBins[3987] =  33
# CPU and GPU results are  equal.
# resultRef[3988] = 33
# hostBins[3988] =  33
# CPU and GPU results are  equal.
# resultRef[3989] = 31
# hostBins[3989] =  31
# CPU and GPU results are  equal.
# resultRef[3990] = 39
# hostBins[3990] =  39
# CPU and GPU results are  equal.
# resultRef[3991] = 24
# hostBins[3991] =  24
# CPU and GPU results are  equal.
# resultRef[3992] = 34
# hostBins[3992] =  34
# CPU and GPU results are  equal.
# resultRef[3993] = 32
# hostBins[3993] =  32
# CPU and GPU results are  equal.
# resultRef[3994] = 30
# hostBins[3994] =  30
# CPU and GPU results are  equal.
# resultRef[3995] = 22
# hostBins[3995] =  22
# CPU and GPU results are  equal.
# resultRef[3996] = 35
# hostBins[3996] =  35
# CPU and GPU results are  equal.
# resultRef[3997] = 31
# hostBins[3997] =  31
# CPU and GPU results are  equal.
# resultRef[3998] = 30
# hostBins[3998] =  30
# CPU and GPU results are  equal.
# resultRef[3999] = 29
# hostBins[3999] =  29
# CPU and GPU results are  equal.
# resultRef[4000] = 34
# hostBins[4000] =  34
# CPU and GPU results are  equal.
# resultRef[4001] = 33
# hostBins[4001] =  33
# CPU and GPU results are  equal.
# resultRef[4002] = 30
# hostBins[4002] =  30
# CPU and GPU results are  equal.
# resultRef[4003] = 27
# hostBins[4003] =  27
# CPU and GPU results are  equal.
# resultRef[4004] = 29
# hostBins[4004] =  29
# CPU and GPU results are  equal.
# resultRef[4005] = 26
# hostBins[4005] =  26
# CPU and GPU results are  equal.
# resultRef[4006] = 37
# hostBins[4006] =  37
# CPU and GPU results are  equal.
# resultRef[4007] = 30
# hostBins[4007] =  30
# CPU and GPU results are  equal.
# resultRef[4008] = 30
# hostBins[4008] =  30
# CPU and GPU results are  equal.
# resultRef[4009] = 36
# hostBins[4009] =  36
# CPU and GPU results are  equal.
# resultRef[4010] = 37
# hostBins[4010] =  37
# CPU and GPU results are  equal.
# resultRef[4011] = 29
# hostBins[4011] =  29
# CPU and GPU results are  equal.
# resultRef[4012] = 23
# hostBins[4012] =  23
# CPU and GPU results are  equal.
# resultRef[4013] = 46
# hostBins[4013] =  46
# CPU and GPU results are  equal.
# resultRef[4014] = 26
# hostBins[4014] =  26
# CPU and GPU results are  equal.
# resultRef[4015] = 30
# hostBins[4015] =  30
# CPU and GPU results are  equal.
# resultRef[4016] = 36
# hostBins[4016] =  36
# CPU and GPU results are  equal.
# resultRef[4017] = 35
# hostBins[4017] =  35
# CPU and GPU results are  equal.
# resultRef[4018] = 29
# hostBins[4018] =  29
# CPU and GPU results are  equal.
# resultRef[4019] = 23
# hostBins[4019] =  23
# CPU and GPU results are  equal.
# resultRef[4020] = 33
# hostBins[4020] =  33
# CPU and GPU results are  equal.
# resultRef[4021] = 33
# hostBins[4021] =  33
# CPU and GPU results are  equal.
# resultRef[4022] = 42
# hostBins[4022] =  42
# CPU and GPU results are  equal.
# resultRef[4023] = 28
# hostBins[4023] =  28
# CPU and GPU results are  equal.
# resultRef[4024] = 27
# hostBins[4024] =  27
# CPU and GPU results are  equal.
# resultRef[4025] = 33
# hostBins[4025] =  33
# CPU and GPU results are  equal.
# resultRef[4026] = 32
# hostBins[4026] =  32
# CPU and GPU results are  equal.
# resultRef[4027] = 37
# hostBins[4027] =  37
# CPU and GPU results are  equal.
# resultRef[4028] = 26
# hostBins[4028] =  26
# CPU and GPU results are  equal.
# resultRef[4029] = 25
# hostBins[4029] =  25
# CPU and GPU results are  equal.
# resultRef[4030] = 41
# hostBins[4030] =  41
# CPU and GPU results are  equal.
# resultRef[4031] = 31
# hostBins[4031] =  31
# CPU and GPU results are  equal.
# resultRef[4032] = 32
# hostBins[4032] =  32
# CPU and GPU results are  equal.
# resultRef[4033] = 39
# hostBins[4033] =  39
# CPU and GPU results are  equal.
# resultRef[4034] = 38
# hostBins[4034] =  38
# CPU and GPU results are  equal.
# resultRef[4035] = 23
# hostBins[4035] =  23
# CPU and GPU results are  equal.
# resultRef[4036] = 36
# hostBins[4036] =  36
# CPU and GPU results are  equal.
# resultRef[4037] = 40
# hostBins[4037] =  40
# CPU and GPU results are  equal.
# resultRef[4038] = 41
# hostBins[4038] =  41
# CPU and GPU results are  equal.
# resultRef[4039] = 32
# hostBins[4039] =  32
# CPU and GPU results are  equal.
# resultRef[4040] = 28
# hostBins[4040] =  28
# CPU and GPU results are  equal.
# resultRef[4041] = 30
# hostBins[4041] =  30
# CPU and GPU results are  equal.
# resultRef[4042] = 32
# hostBins[4042] =  32
# CPU and GPU results are  equal.
# resultRef[4043] = 31
# hostBins[4043] =  31
# CPU and GPU results are  equal.
# resultRef[4044] = 33
# hostBins[4044] =  33
# CPU and GPU results are  equal.
# resultRef[4045] = 28
# hostBins[4045] =  28
# CPU and GPU results are  equal.
# resultRef[4046] = 27
# hostBins[4046] =  27
# CPU and GPU results are  equal.
# resultRef[4047] = 28
# hostBins[4047] =  28
# CPU and GPU results are  equal.
# resultRef[4048] = 41
# hostBins[4048] =  41
# CPU and GPU results are  equal.
# resultRef[4049] = 30
# hostBins[4049] =  30
# CPU and GPU results are  equal.
# resultRef[4050] = 31
# hostBins[4050] =  31
# CPU and GPU results are  equal.
# resultRef[4051] = 41
# hostBins[4051] =  41
# CPU and GPU results are  equal.
# resultRef[4052] = 36
# hostBins[4052] =  36
# CPU and GPU results are  equal.
# resultRef[4053] = 38
# hostBins[4053] =  38
# CPU and GPU results are  equal.
# resultRef[4054] = 27
# hostBins[4054] =  27
# CPU and GPU results are  equal.
# resultRef[4055] = 30
# hostBins[4055] =  30
# CPU and GPU results are  equal.
# resultRef[4056] = 25
# hostBins[4056] =  25
# CPU and GPU results are  equal.
# resultRef[4057] = 43
# hostBins[4057] =  43
# CPU and GPU results are  equal.
# resultRef[4058] = 36
# hostBins[4058] =  36
# CPU and GPU results are  equal.
# resultRef[4059] = 33
# hostBins[4059] =  33
# CPU and GPU results are  equal.
# resultRef[4060] = 39
# hostBins[4060] =  39
# CPU and GPU results are  equal.
# resultRef[4061] = 29
# hostBins[4061] =  29
# CPU and GPU results are  equal.
# resultRef[4062] = 16
# hostBins[4062] =  16
# CPU and GPU results are  equal.
# resultRef[4063] = 33
# hostBins[4063] =  33
# CPU and GPU results are  equal.
# resultRef[4064] = 34
# hostBins[4064] =  34
# CPU and GPU results are  equal.
# resultRef[4065] = 40
# hostBins[4065] =  40
# CPU and GPU results are  equal.
# resultRef[4066] = 30
# hostBins[4066] =  30
# CPU and GPU results are  equal.
# resultRef[4067] = 34
# hostBins[4067] =  34
# CPU and GPU results are  equal.
# resultRef[4068] = 40
# hostBins[4068] =  40
# CPU and GPU results are  equal.
# resultRef[4069] = 35
# hostBins[4069] =  35
# CPU and GPU results are  equal.
# resultRef[4070] = 33
# hostBins[4070] =  33
# CPU and GPU results are  equal.
# resultRef[4071] = 39
# hostBins[4071] =  39
# CPU and GPU results are  equal.
# resultRef[4072] = 28
# hostBins[4072] =  28
# CPU and GPU results are  equal.
# resultRef[4073] = 31
# hostBins[4073] =  31
# CPU and GPU results are  equal.
# resultRef[4074] = 30
# hostBins[4074] =  30
# CPU and GPU results are  equal.
# resultRef[4075] = 36
# hostBins[4075] =  36
# CPU and GPU results are  equal.
# resultRef[4076] = 39
# hostBins[4076] =  39
# CPU and GPU results are  equal.
# resultRef[4077] = 27
# hostBins[4077] =  27
# CPU and GPU results are  equal.
# resultRef[4078] = 27
# hostBins[4078] =  27
# CPU and GPU results are  equal.
# resultRef[4079] = 42
# hostBins[4079] =  42
# CPU and GPU results are  equal.
# resultRef[4080] = 26
# hostBins[4080] =  26
# CPU and GPU results are  equal.
# resultRef[4081] = 33
# hostBins[4081] =  33
# CPU and GPU results are  equal.
# resultRef[4082] = 22
# hostBins[4082] =  22
# CPU and GPU results are  equal.
# resultRef[4083] = 32
# hostBins[4083] =  32
# CPU and GPU results are  equal.
# resultRef[4084] = 33
# hostBins[4084] =  33
# CPU and GPU results are  equal.
# resultRef[4085] = 34
# hostBins[4085] =  34
# CPU and GPU results are  equal.
# resultRef[4086] = 35
# hostBins[4086] =  35
# CPU and GPU results are  equal.
# resultRef[4087] = 28
# hostBins[4087] =  28
# CPU and GPU results are  equal.
# resultRef[4088] = 35
# hostBins[4088] =  35
# CPU and GPU results are  equal.
# resultRef[4089] = 33
# hostBins[4089] =  33
# CPU and GPU results are  equal.
# resultRef[4090] = 33
# hostBins[4090] =  33
# CPU and GPU results are  equal.
# resultRef[4091] = 38
# hostBins[4091] =  38
# CPU and GPU results are  equal.
# resultRef[4092] = 35
# hostBins[4092] =  35
# CPU and GPU results are  equal.
# resultRef[4093] = 35
# hostBins[4093] =  35
# CPU and GPU results are  equal.
# resultRef[4094] = 28
# hostBins[4094] =  28
# CPU and GPU results are  equal.
# resultRef[4095] = 0
# hostBins[4095] =  0
# CPU and GPU results are  equal.
# ==352== Profiling application: ./lab3_ex3 131072
# ==352== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   74.12%  167.23us         1  167.23us  167.23us  167.23us  histogram_kernel(unsigned int*, unsigned int*, unsigned int, unsigned int)
#                    20.35%  45.920us         1  45.920us  45.920us  45.920us  [CUDA memcpy HtoD]
#                     2.26%  5.0880us         1  5.0880us  5.0880us  5.0880us  [CUDA memset]
#                     1.87%  4.2240us         1  4.2240us  4.2240us  4.2240us  convert_kernel(unsigned int*, unsigned int)
#                     1.40%  3.1680us         1  3.1680us  3.1680us  3.1680us  [CUDA memcpy DtoH]
#       API calls:   99.37%  272.57ms         2  136.29ms  3.6060us  272.57ms  cudaMalloc
#                     0.26%  701.15us         2  350.58us  210.59us  490.57us  cudaFree
#                     0.15%  414.15us         1  414.15us  414.15us  414.15us  cuDeviceTotalMem
#                     0.13%  347.50us         2  173.75us  131.62us  215.88us  cudaMemcpy
#                     0.07%  180.41us       101  1.7860us     148ns  87.040us  cuDeviceGetAttribute
#                     0.01%  33.384us         1  33.384us  33.384us  33.384us  cuDeviceGetName
#                     0.01%  23.799us         1  23.799us  23.799us  23.799us  cudaMemset
#                     0.01%  19.520us         2  9.7600us  6.1300us  13.390us  cudaLaunchKernel
#                     0.00%  5.9450us         1  5.9450us  5.9450us  5.9450us  cuDeviceGetPCIBusId
#                     0.00%  2.2860us         2  1.1430us     402ns  1.8840us  cuDeviceGet
#                     0.00%  1.9100us         3     636ns     230ns  1.2560us  cuDeviceGetCount
#                     0.00%     298ns         1     298ns     298ns     298ns  cuDeviceGetUuid

# %%
import matplotlib.pyplot as plt

with open('./histogram.txt') as f:
    histogram = [int(line.rstrip()) for line in f]
fig = plt.gcf()
bins = list(range(1,len(histogram)+1))
plt.bar(bins, histogram, width=1.0)
plt.show()

# %%
# !/usr/local/cuda-11/bin/nv-nsight-cu-cli ./lab3_ex3 1024
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# resultRef[2461] = 1
# hostBins[2461] =  1
# CPU and GPU results are  equal.
# resultRef[2462] = 0
# hostBins[2462] =  0
# CPU and GPU results are  equal.
# resultRef[2463] = 0
# hostBins[2463] =  0
# CPU and GPU results are  equal.
# resultRef[2464] = 0
# hostBins[2464] =  0
# CPU and GPU results are  equal.
# resultRef[2465] = 1
# hostBins[2465] =  1
# CPU and GPU results are  equal.
# resultRef[2466] = 2
# hostBins[2466] =  2
# CPU and GPU results are  equal.
# resultRef[2467] = 0
# hostBins[2467] =  0
# CPU and GPU results are  equal.
# resultRef[2468] = 1
# hostBins[2468] =  1
# CPU and GPU results are  equal.
# resultRef[2469] = 0
# hostBins[2469] =  0
# CPU and GPU results are  equal.
# resultRef[2470] = 1
# hostBins[2470] =  1
# CPU and GPU results are  equal.
# resultRef[2471] = 0
# hostBins[2471] =  0
# CPU and GPU results are  equal.
# resultRef[2472] = 0
# hostBins[2472] =  0
# CPU and GPU results are  equal.
# resultRef[2473] = 1
# hostBins[2473] =  1
# CPU and GPU results are  equal.
# resultRef[2474] = 0
# hostBins[2474] =  0
# CPU and GPU results are  equal.
# resultRef[2475] = 0
# hostBins[2475] =  0
# CPU and GPU results are  equal.
# resultRef[2476] = 0
# hostBins[2476] =  0
# CPU and GPU results are  equal.
# resultRef[2477] = 0
# hostBins[2477] =  0
# CPU and GPU results are  equal.
# resultRef[2478] = 1
# hostBins[2478] =  1
# CPU and GPU results are  equal.
# resultRef[2479] = 0
# hostBins[2479] =  0
# CPU and GPU results are  equal.
# resultRef[2480] = 1
# hostBins[2480] =  1
# CPU and GPU results are  equal.
# resultRef[2481] = 0
# hostBins[2481] =  0
# CPU and GPU results are  equal.
# resultRef[2482] = 0
# hostBins[2482] =  0
# CPU and GPU results are  equal.
# resultRef[2483] = 0
# hostBins[2483] =  0
# CPU and GPU results are  equal.
# resultRef[2484] = 0
# hostBins[2484] =  0
# CPU and GPU results are  equal.
# resultRef[2485] = 0
# hostBins[2485] =  0
# CPU and GPU results are  equal.
# resultRef[2486] = 1
# hostBins[2486] =  1
# CPU and GPU results are  equal.
# resultRef[2487] = 1
# hostBins[2487] =  1
# CPU and GPU results are  equal.
# resultRef[2488] = 0
# hostBins[2488] =  0
# CPU and GPU results are  equal.
# resultRef[2489] = 0
# hostBins[2489] =  0
# CPU and GPU results are  equal.
# resultRef[2490] = 0
# hostBins[2490] =  0
# CPU and GPU results are  equal.
# resultRef[2491] = 0
# hostBins[2491] =  0
# CPU and GPU results are  equal.
# resultRef[2492] = 0
# hostBins[2492] =  0
# CPU and GPU results are  equal.
# resultRef[2493] = 0
# hostBins[2493] =  0
# CPU and GPU results are  equal.
# resultRef[2494] = 0
# hostBins[2494] =  0
# CPU and GPU results are  equal.
# resultRef[2495] = 0
# hostBins[2495] =  0
# CPU and GPU results are  equal.
# resultRef[2496] = 0
# hostBins[2496] =  0
# CPU and GPU results are  equal.
# resultRef[2497] = 0
# hostBins[2497] =  0
# CPU and GPU results are  equal.
# resultRef[2498] = 0
# hostBins[2498] =  0
# CPU and GPU results are  equal.
# resultRef[2499] = 0
# hostBins[2499] =  0
# CPU and GPU results are  equal.
# resultRef[2500] = 1
# hostBins[2500] =  1
# CPU and GPU results are  equal.
# resultRef[2501] = 1
# hostBins[2501] =  1
# CPU and GPU results are  equal.
# resultRef[2502] = 0
# hostBins[2502] =  0
# CPU and GPU results are  equal.
# resultRef[2503] = 1
# hostBins[2503] =  1
# CPU and GPU results are  equal.
# resultRef[2504] = 0
# hostBins[2504] =  0
# CPU and GPU results are  equal.
# resultRef[2505] = 0
# hostBins[2505] =  0
# CPU and GPU results are  equal.
# resultRef[2506] = 1
# hostBins[2506] =  1
# CPU and GPU results are  equal.
# resultRef[2507] = 0
# hostBins[2507] =  0
# CPU and GPU results are  equal.
# resultRef[2508] = 0
# hostBins[2508] =  0
# CPU and GPU results are  equal.
# resultRef[2509] = 1
# hostBins[2509] =  1
# CPU and GPU results are  equal.
# resultRef[2510] = 1
# hostBins[2510] =  1
# CPU and GPU results are  equal.
# resultRef[2511] = 0
# hostBins[2511] =  0
# CPU and GPU results are  equal.
# resultRef[2512] = 1
# hostBins[2512] =  1
# CPU and GPU results are  equal.
# resultRef[2513] = 0
# hostBins[2513] =  0
# CPU and GPU results are  equal.
# resultRef[2514] = 2
# hostBins[2514] =  2
# CPU and GPU results are  equal.
# resultRef[2515] = 0
# hostBins[2515] =  0
# CPU and GPU results are  equal.
# resultRef[2516] = 0
# hostBins[2516] =  0
# CPU and GPU results are  equal.
# resultRef[2517] = 1
# hostBins[2517] =  1
# CPU and GPU results are  equal.
# resultRef[2518] = 0
# hostBins[2518] =  0
# CPU and GPU results are  equal.
# resultRef[2519] = 0
# hostBins[2519] =  0
# CPU and GPU results are  equal.
# resultRef[2520] = 0
# hostBins[2520] =  0
# CPU and GPU results are  equal.
# resultRef[2521] = 0
# hostBins[2521] =  0
# CPU and GPU results are  equal.
# resultRef[2522] = 0
# hostBins[2522] =  0
# CPU and GPU results are  equal.
# resultRef[2523] = 1
# hostBins[2523] =  1
# CPU and GPU results are  equal.
# resultRef[2524] = 0
# hostBins[2524] =  0
# CPU and GPU results are  equal.
# resultRef[2525] = 0
# hostBins[2525] =  0
# CPU and GPU results are  equal.
# resultRef[2526] = 0
# hostBins[2526] =  0
# CPU and GPU results are  equal.
# resultRef[2527] = 0
# hostBins[2527] =  0
# CPU and GPU results are  equal.
# resultRef[2528] = 1
# hostBins[2528] =  1
# CPU and GPU results are  equal.
# resultRef[2529] = 0
# hostBins[2529] =  0
# CPU and GPU results are  equal.
# resultRef[2530] = 0
# hostBins[2530] =  0
# CPU and GPU results are  equal.
# resultRef[2531] = 1
# hostBins[2531] =  1
# CPU and GPU results are  equal.
# resultRef[2532] = 0
# hostBins[2532] =  0
# CPU and GPU results are  equal.
# resultRef[2533] = 0
# hostBins[2533] =  0
# CPU and GPU results are  equal.
# resultRef[2534] = 0
# hostBins[2534] =  0
# CPU and GPU results are  equal.
# resultRef[2535] = 0
# hostBins[2535] =  0
# CPU and GPU results are  equal.
# resultRef[2536] = 0
# hostBins[2536] =  0
# CPU and GPU results are  equal.
# resultRef[2537] = 0
# hostBins[2537] =  0
# CPU and GPU results are  equal.
# resultRef[2538] = 1
# hostBins[2538] =  1
# CPU and GPU results are  equal.
# resultRef[2539] = 1
# hostBins[2539] =  1
# CPU and GPU results are  equal.
# resultRef[2540] = 0
# hostBins[2540] =  0
# CPU and GPU results are  equal.
# resultRef[2541] = 0
# hostBins[2541] =  0
# CPU and GPU results are  equal.
# resultRef[2542] = 1
# hostBins[2542] =  1
# CPU and GPU results are  equal.
# resultRef[2543] = 0
# hostBins[2543] =  0
# CPU and GPU results are  equal.
# resultRef[2544] = 0
# hostBins[2544] =  0
# CPU and GPU results are  equal.
# resultRef[2545] = 0
# hostBins[2545] =  0
# CPU and GPU results are  equal.
# resultRef[2546] = 0
# hostBins[2546] =  0
# CPU and GPU results are  equal.
# resultRef[2547] = 0
# hostBins[2547] =  0
# CPU and GPU results are  equal.
# resultRef[2548] = 0
# hostBins[2548] =  0
# CPU and GPU results are  equal.
# resultRef[2549] = 1
# hostBins[2549] =  1
# CPU and GPU results are  equal.
# resultRef[2550] = 1
# hostBins[2550] =  1
# CPU and GPU results are  equal.
# resultRef[2551] = 0
# hostBins[2551] =  0
# CPU and GPU results are  equal.
# resultRef[2552] = 0
# hostBins[2552] =  0
# CPU and GPU results are  equal.
# resultRef[2553] = 1
# hostBins[2553] =  1
# CPU and GPU results are  equal.
# resultRef[2554] = 1
# hostBins[2554] =  1
# CPU and GPU results are  equal.
# resultRef[2555] = 0
# hostBins[2555] =  0
# CPU and GPU results are  equal.
# resultRef[2556] = 0
# hostBins[2556] =  0
# CPU and GPU results are  equal.
# resultRef[2557] = 1
# hostBins[2557] =  1
# CPU and GPU results are  equal.
# resultRef[2558] = 0
# hostBins[2558] =  0
# CPU and GPU results are  equal.
# resultRef[2559] = 0
# hostBins[2559] =  0
# CPU and GPU results are  equal.
# resultRef[2560] = 0
# hostBins[2560] =  0
# CPU and GPU results are  equal.
# resultRef[2561] = 0
# hostBins[2561] =  0
# CPU and GPU results are  equal.
# resultRef[2562] = 0
# hostBins[2562] =  0
# CPU and GPU results are  equal.
# resultRef[2563] = 0
# hostBins[2563] =  0
# CPU and GPU results are  equal.
# resultRef[2564] = 0
# hostBins[2564] =  0
# CPU and GPU results are  equal.
# resultRef[2565] = 1
# hostBins[2565] =  1
# CPU and GPU results are  equal.
# resultRef[2566] = 1
# hostBins[2566] =  1
# CPU and GPU results are  equal.
# resultRef[2567] = 0
# hostBins[2567] =  0
# CPU and GPU results are  equal.
# resultRef[2568] = 0
# hostBins[2568] =  0
# CPU and GPU results are  equal.
# resultRef[2569] = 0
# hostBins[2569] =  0
# CPU and GPU results are  equal.
# resultRef[2570] = 0
# hostBins[2570] =  0
# CPU and GPU results are  equal.
# resultRef[2571] = 0
# hostBins[2571] =  0
# CPU and GPU results are  equal.
# resultRef[2572] = 1
# hostBins[2572] =  1
# CPU and GPU results are  equal.
# resultRef[2573] = 0
# hostBins[2573] =  0
# CPU and GPU results are  equal.
# resultRef[2574] = 0
# hostBins[2574] =  0
# CPU and GPU results are  equal.
# resultRef[2575] = 1
# hostBins[2575] =  1
# CPU and GPU results are  equal.
# resultRef[2576] = 0
# hostBins[2576] =  0
# CPU and GPU results are  equal.
# resultRef[2577] = 0
# hostBins[2577] =  0
# CPU and GPU results are  equal.
# resultRef[2578] = 0
# hostBins[2578] =  0
# CPU and GPU results are  equal.
# resultRef[2579] = 0
# hostBins[2579] =  0
# CPU and GPU results are  equal.
# resultRef[2580] = 0
# hostBins[2580] =  0
# CPU and GPU results are  equal.
# resultRef[2581] = 1
# hostBins[2581] =  1
# CPU and GPU results are  equal.
# resultRef[2582] = 0
# hostBins[2582] =  0
# CPU and GPU results are  equal.
# resultRef[2583] = 0
# hostBins[2583] =  0
# CPU and GPU results are  equal.
# resultRef[2584] = 0
# hostBins[2584] =  0
# CPU and GPU results are  equal.
# resultRef[2585] = 0
# hostBins[2585] =  0
# CPU and GPU results are  equal.
# resultRef[2586] = 0
# hostBins[2586] =  0
# CPU and GPU results are  equal.
# resultRef[2587] = 0
# hostBins[2587] =  0
# CPU and GPU results are  equal.
# resultRef[2588] = 0
# hostBins[2588] =  0
# CPU and GPU results are  equal.
# resultRef[2589] = 0
# hostBins[2589] =  0
# CPU and GPU results are  equal.
# resultRef[2590] = 0
# hostBins[2590] =  0
# CPU and GPU results are  equal.
# resultRef[2591] = 1
# hostBins[2591] =  1
# CPU and GPU results are  equal.
# resultRef[2592] = 0
# hostBins[2592] =  0
# CPU and GPU results are  equal.
# resultRef[2593] = 0
# hostBins[2593] =  0
# CPU and GPU results are  equal.
# resultRef[2594] = 1
# hostBins[2594] =  1
# CPU and GPU results are  equal.
# resultRef[2595] = 0
# hostBins[2595] =  0
# CPU and GPU results are  equal.
# resultRef[2596] = 0
# hostBins[2596] =  0
# CPU and GPU results are  equal.
# resultRef[2597] = 0
# hostBins[2597] =  0
# CPU and GPU results are  equal.
# resultRef[2598] = 0
# hostBins[2598] =  0
# CPU and GPU results are  equal.
# resultRef[2599] = 0
# hostBins[2599] =  0
# CPU and GPU results are  equal.
# resultRef[2600] = 0
# hostBins[2600] =  0
# CPU and GPU results are  equal.
# resultRef[2601] = 0
# hostBins[2601] =  0
# CPU and GPU results are  equal.
# resultRef[2602] = 1
# hostBins[2602] =  1
# CPU and GPU results are  equal.
# resultRef[2603] = 0
# hostBins[2603] =  0
# CPU and GPU results are  equal.
# resultRef[2604] = 0
# hostBins[2604] =  0
# CPU and GPU results are  equal.
# resultRef[2605] = 0
# hostBins[2605] =  0
# CPU and GPU results are  equal.
# resultRef[2606] = 0
# hostBins[2606] =  0
# CPU and GPU results are  equal.
# resultRef[2607] = 0
# hostBins[2607] =  0
# CPU and GPU results are  equal.
# resultRef[2608] = 0
# hostBins[2608] =  0
# CPU and GPU results are  equal.
# resultRef[2609] = 0
# hostBins[2609] =  0
# CPU and GPU results are  equal.
# resultRef[2610] = 1
# hostBins[2610] =  1
# CPU and GPU results are  equal.
# resultRef[2611] = 0
# hostBins[2611] =  0
# CPU and GPU results are  equal.
# resultRef[2612] = 0
# hostBins[2612] =  0
# CPU and GPU results are  equal.
# resultRef[2613] = 0
# hostBins[2613] =  0
# CPU and GPU results are  equal.
# resultRef[2614] = 0
# hostBins[2614] =  0
# CPU and GPU results are  equal.
# resultRef[2615] = 0
# hostBins[2615] =  0
# CPU and GPU results are  equal.
# resultRef[2616] = 0
# hostBins[2616] =  0
# CPU and GPU results are  equal.
# resultRef[2617] = 1
# hostBins[2617] =  1
# CPU and GPU results are  equal.
# resultRef[2618] = 0
# hostBins[2618] =  0
# CPU and GPU results are  equal.
# resultRef[2619] = 0
# hostBins[2619] =  0
# CPU and GPU results are  equal.
# resultRef[2620] = 0
# hostBins[2620] =  0
# CPU and GPU results are  equal.
# resultRef[2621] = 0
# hostBins[2621] =  0
# CPU and GPU results are  equal.
# resultRef[2622] = 1
# hostBins[2622] =  1
# CPU and GPU results are  equal.
# resultRef[2623] = 1
# hostBins[2623] =  1
# CPU and GPU results are  equal.
# resultRef[2624] = 2
# hostBins[2624] =  2
# CPU and GPU results are  equal.
# resultRef[2625] = 0
# hostBins[2625] =  0
# CPU and GPU results are  equal.
# resultRef[2626] = 0
# hostBins[2626] =  0
# CPU and GPU results are  equal.
# resultRef[2627] = 0
# hostBins[2627] =  0
# CPU and GPU results are  equal.
# resultRef[2628] = 0
# hostBins[2628] =  0
# CPU and GPU results are  equal.
# resultRef[2629] = 0
# hostBins[2629] =  0
# CPU and GPU results are  equal.
# resultRef[2630] = 0
# hostBins[2630] =  0
# CPU and GPU results are  equal.
# resultRef[2631] = 1
# hostBins[2631] =  1
# CPU and GPU results are  equal.
# resultRef[2632] = 0
# hostBins[2632] =  0
# CPU and GPU results are  equal.
# resultRef[2633] = 0
# hostBins[2633] =  0
# CPU and GPU results are  equal.
# resultRef[2634] = 0
# hostBins[2634] =  0
# CPU and GPU results are  equal.
# resultRef[2635] = 0
# hostBins[2635] =  0
# CPU and GPU results are  equal.
# resultRef[2636] = 0
# hostBins[2636] =  0
# CPU and GPU results are  equal.
# resultRef[2637] = 0
# hostBins[2637] =  0
# CPU and GPU results are  equal.
# resultRef[2638] = 0
# hostBins[2638] =  0
# CPU and GPU results are  equal.
# resultRef[2639] = 0
# hostBins[2639] =  0
# CPU and GPU results are  equal.
# resultRef[2640] = 0
# hostBins[2640] =  0
# CPU and GPU results are  equal.
# resultRef[2641] = 0
# hostBins[2641] =  0
# CPU and GPU results are  equal.
# resultRef[2642] = 0
# hostBins[2642] =  0
# CPU and GPU results are  equal.
# resultRef[2643] = 0
# hostBins[2643] =  0
# CPU and GPU results are  equal.
# resultRef[2644] = 0
# hostBins[2644] =  0
# CPU and GPU results are  equal.
# resultRef[2645] = 0
# hostBins[2645] =  0
# CPU and GPU results are  equal.
# resultRef[2646] = 0
# hostBins[2646] =  0
# CPU and GPU results are  equal.
# resultRef[2647] = 0
# hostBins[2647] =  0
# CPU and GPU results are  equal.
# resultRef[2648] = 3
# hostBins[2648] =  3
# CPU and GPU results are  equal.
# resultRef[2649] = 1
# hostBins[2649] =  1
# CPU and GPU results are  equal.
# resultRef[2650] = 0
# hostBins[2650] =  0
# CPU and GPU results are  equal.
# resultRef[2651] = 0
# hostBins[2651] =  0
# CPU and GPU results are  equal.
# resultRef[2652] = 0
# hostBins[2652] =  0
# CPU and GPU results are  equal.
# resultRef[2653] = 0
# hostBins[2653] =  0
# CPU and GPU results are  equal.
# resultRef[2654] = 0
# hostBins[2654] =  0
# CPU and GPU results are  equal.
# resultRef[2655] = 0
# hostBins[2655] =  0
# CPU and GPU results are  equal.
# resultRef[2656] = 0
# hostBins[2656] =  0
# CPU and GPU results are  equal.
# resultRef[2657] = 1
# hostBins[2657] =  1
# CPU and GPU results are  equal.
# resultRef[2658] = 0
# hostBins[2658] =  0
# CPU and GPU results are  equal.
# resultRef[2659] = 0
# hostBins[2659] =  0
# CPU and GPU results are  equal.
# resultRef[2660] = 0
# hostBins[2660] =  0
# CPU and GPU results are  equal.
# resultRef[2661] = 1
# hostBins[2661] =  1
# CPU and GPU results are  equal.
# resultRef[2662] = 0
# hostBins[2662] =  0
# CPU and GPU results are  equal.
# resultRef[2663] = 1
# hostBins[2663] =  1
# CPU and GPU results are  equal.
# resultRef[2664] = 1
# hostBins[2664] =  1
# CPU and GPU results are  equal.
# resultRef[2665] = 0
# hostBins[2665] =  0
# CPU and GPU results are  equal.
# resultRef[2666] = 1
# hostBins[2666] =  1
# CPU and GPU results are  equal.
# resultRef[2667] = 0
# hostBins[2667] =  0
# CPU and GPU results are  equal.
# resultRef[2668] = 0
# hostBins[2668] =  0
# CPU and GPU results are  equal.
# resultRef[2669] = 0
# hostBins[2669] =  0
# CPU and GPU results are  equal.
# resultRef[2670] = 0
# hostBins[2670] =  0
# CPU and GPU results are  equal.
# resultRef[2671] = 0
# hostBins[2671] =  0
# CPU and GPU results are  equal.
# resultRef[2672] = 0
# hostBins[2672] =  0
# CPU and GPU results are  equal.
# resultRef[2673] = 0
# hostBins[2673] =  0
# CPU and GPU results are  equal.
# resultRef[2674] = 0
# hostBins[2674] =  0
# CPU and GPU results are  equal.
# resultRef[2675] = 0
# hostBins[2675] =  0
# CPU and GPU results are  equal.
# resultRef[2676] = 0
# hostBins[2676] =  0
# CPU and GPU results are  equal.
# resultRef[2677] = 1
# hostBins[2677] =  1
# CPU and GPU results are  equal.
# resultRef[2678] = 1
# hostBins[2678] =  1
# CPU and GPU results are  equal.
# resultRef[2679] = 0
# hostBins[2679] =  0
# CPU and GPU results are  equal.
# resultRef[2680] = 0
# hostBins[2680] =  0
# CPU and GPU results are  equal.
# resultRef[2681] = 0
# hostBins[2681] =  0
# CPU and GPU results are  equal.
# resultRef[2682] = 0
# hostBins[2682] =  0
# CPU and GPU results are  equal.
# resultRef[2683] = 0
# hostBins[2683] =  0
# CPU and GPU results are  equal.
# resultRef[2684] = 0
# hostBins[2684] =  0
# CPU and GPU results are  equal.
# resultRef[2685] = 0
# hostBins[2685] =  0
# CPU and GPU results are  equal.
# resultRef[2686] = 0
# hostBins[2686] =  0
# CPU and GPU results are  equal.
# resultRef[2687] = 0
# hostBins[2687] =  0
# CPU and GPU results are  equal.
# resultRef[2688] = 0
# hostBins[2688] =  0
# CPU and GPU results are  equal.
# resultRef[2689] = 0
# hostBins[2689] =  0
# CPU and GPU results are  equal.
# resultRef[2690] = 0
# hostBins[2690] =  0
# CPU and GPU results are  equal.
# resultRef[2691] = 0
# hostBins[2691] =  0
# CPU and GPU results are  equal.
# resultRef[2692] = 0
# hostBins[2692] =  0
# CPU and GPU results are  equal.
# resultRef[2693] = 2
# hostBins[2693] =  2
# CPU and GPU results are  equal.
# resultRef[2694] = 0
# hostBins[2694] =  0
# CPU and GPU results are  equal.
# resultRef[2695] = 0
# hostBins[2695] =  0
# CPU and GPU results are  equal.
# resultRef[2696] = 0
# hostBins[2696] =  0
# CPU and GPU results are  equal.
# resultRef[2697] = 1
# hostBins[2697] =  1
# CPU and GPU results are  equal.
# resultRef[2698] = 1
# hostBins[2698] =  1
# CPU and GPU results are  equal.
# resultRef[2699] = 0
# hostBins[2699] =  0
# CPU and GPU results are  equal.
# resultRef[2700] = 0
# hostBins[2700] =  0
# CPU and GPU results are  equal.
# resultRef[2701] = 0
# hostBins[2701] =  0
# CPU and GPU results are  equal.
# resultRef[2702] = 1
# hostBins[2702] =  1
# CPU and GPU results are  equal.
# resultRef[2703] = 0
# hostBins[2703] =  0
# CPU and GPU results are  equal.
# resultRef[2704] = 0
# hostBins[2704] =  0
# CPU and GPU results are  equal.
# resultRef[2705] = 0
# hostBins[2705] =  0
# CPU and GPU results are  equal.
# resultRef[2706] = 0
# hostBins[2706] =  0
# CPU and GPU results are  equal.
# resultRef[2707] = 1
# hostBins[2707] =  1
# CPU and GPU results are  equal.
# resultRef[2708] = 1
# hostBins[2708] =  1
# CPU and GPU results are  equal.
# resultRef[2709] = 0
# hostBins[2709] =  0
# CPU and GPU results are  equal.
# resultRef[2710] = 0
# hostBins[2710] =  0
# CPU and GPU results are  equal.
# resultRef[2711] = 1
# hostBins[2711] =  1
# CPU and GPU results are  equal.
# resultRef[2712] = 0
# hostBins[2712] =  0
# CPU and GPU results are  equal.
# resultRef[2713] = 0
# hostBins[2713] =  0
# CPU and GPU results are  equal.
# resultRef[2714] = 0
# hostBins[2714] =  0
# CPU and GPU results are  equal.
# resultRef[2715] = 0
# hostBins[2715] =  0
# CPU and GPU results are  equal.
# resultRef[2716] = 1
# hostBins[2716] =  1
# CPU and GPU results are  equal.
# resultRef[2717] = 0
# hostBins[2717] =  0
# CPU and GPU results are  equal.
# resultRef[2718] = 2
# hostBins[2718] =  2
# CPU and GPU results are  equal.
# resultRef[2719] = 0
# hostBins[2719] =  0
# CPU and GPU results are  equal.
# resultRef[2720] = 0
# hostBins[2720] =  0
# CPU and GPU results are  equal.
# resultRef[2721] = 0
# hostBins[2721] =  0
# CPU and GPU results are  equal.
# resultRef[2722] = 0
# hostBins[2722] =  0
# CPU and GPU results are  equal.
# resultRef[2723] = 0
# hostBins[2723] =  0
# CPU and GPU results are  equal.
# resultRef[2724] = 0
# hostBins[2724] =  0
# CPU and GPU results are  equal.
# resultRef[2725] = 0
# hostBins[2725] =  0
# CPU and GPU results are  equal.
# resultRef[2726] = 0
# hostBins[2726] =  0
# CPU and GPU results are  equal.
# resultRef[2727] = 0
# hostBins[2727] =  0
# CPU and GPU results are  equal.
# resultRef[2728] = 0
# hostBins[2728] =  0
# CPU and GPU results are  equal.
# resultRef[2729] = 0
# hostBins[2729] =  0
# CPU and GPU results are  equal.
# resultRef[2730] = 0
# hostBins[2730] =  0
# CPU and GPU results are  equal.
# resultRef[2731] = 0
# hostBins[2731] =  0
# CPU and GPU results are  equal.
# resultRef[2732] = 0
# hostBins[2732] =  0
# CPU and GPU results are  equal.
# resultRef[2733] = 0
# hostBins[2733] =  0
# CPU and GPU results are  equal.
# resultRef[2734] = 1
# hostBins[2734] =  1
# CPU and GPU results are  equal.
# resultRef[2735] = 0
# hostBins[2735] =  0
# CPU and GPU results are  equal.
# resultRef[2736] = 0
# hostBins[2736] =  0
# CPU and GPU results are  equal.
# resultRef[2737] = 0
# hostBins[2737] =  0
# CPU and GPU results are  equal.
# resultRef[2738] = 0
# hostBins[2738] =  0
# CPU and GPU results are  equal.
# resultRef[2739] = 0
# hostBins[2739] =  0
# CPU and GPU results are  equal.
# resultRef[2740] = 0
# hostBins[2740] =  0
# CPU and GPU results are  equal.
# resultRef[2741] = 1
# hostBins[2741] =  1
# CPU and GPU results are  equal.
# resultRef[2742] = 0
# hostBins[2742] =  0
# CPU and GPU results are  equal.
# resultRef[2743] = 2
# hostBins[2743] =  2
# CPU and GPU results are  equal.
# resultRef[2744] = 0
# hostBins[2744] =  0
# CPU and GPU results are  equal.
# resultRef[2745] = 0
# hostBins[2745] =  0
# CPU and GPU results are  equal.
# resultRef[2746] = 0
# hostBins[2746] =  0
# CPU and GPU results are  equal.
# resultRef[2747] = 0
# hostBins[2747] =  0
# CPU and GPU results are  equal.
# resultRef[2748] = 1
# hostBins[2748] =  1
# CPU and GPU results are  equal.
# resultRef[2749] = 0
# hostBins[2749] =  0
# CPU and GPU results are  equal.
# resultRef[2750] = 0
# hostBins[2750] =  0
# CPU and GPU results are  equal.
# resultRef[2751] = 0
# hostBins[2751] =  0
# CPU and GPU results are  equal.
# resultRef[2752] = 0
# hostBins[2752] =  0
# CPU and GPU results are  equal.
# resultRef[2753] = 0
# hostBins[2753] =  0
# CPU and GPU results are  equal.
# resultRef[2754] = 0
# hostBins[2754] =  0
# CPU and GPU results are  equal.
# resultRef[2755] = 0
# hostBins[2755] =  0
# CPU and GPU results are  equal.
# resultRef[2756] = 0
# hostBins[2756] =  0
# CPU and GPU results are  equal.
# resultRef[2757] = 0
# hostBins[2757] =  0
# CPU and GPU results are  equal.
# resultRef[2758] = 0
# hostBins[2758] =  0
# CPU and GPU results are  equal.
# resultRef[2759] = 0
# hostBins[2759] =  0
# CPU and GPU results are  equal.
# resultRef[2760] = 0
# hostBins[2760] =  0
# CPU and GPU results are  equal.
# resultRef[2761] = 0
# hostBins[2761] =  0
# CPU and GPU results are  equal.
# resultRef[2762] = 0
# hostBins[2762] =  0
# CPU and GPU results are  equal.
# resultRef[2763] = 0
# hostBins[2763] =  0
# CPU and GPU results are  equal.
# resultRef[2764] = 0
# hostBins[2764] =  0
# CPU and GPU results are  equal.
# resultRef[2765] = 0
# hostBins[2765] =  0
# CPU and GPU results are  equal.
# resultRef[2766] = 2
# hostBins[2766] =  2
# CPU and GPU results are  equal.
# resultRef[2767] = 0
# hostBins[2767] =  0
# CPU and GPU results are  equal.
# resultRef[2768] = 0
# hostBins[2768] =  0
# CPU and GPU results are  equal.
# resultRef[2769] = 0
# hostBins[2769] =  0
# CPU and GPU results are  equal.
# resultRef[2770] = 0
# hostBins[2770] =  0
# CPU and GPU results are  equal.
# resultRef[2771] = 0
# hostBins[2771] =  0
# CPU and GPU results are  equal.
# resultRef[2772] = 0
# hostBins[2772] =  0
# CPU and GPU results are  equal.
# resultRef[2773] = 0
# hostBins[2773] =  0
# CPU and GPU results are  equal.
# resultRef[2774] = 1
# hostBins[2774] =  1
# CPU and GPU results are  equal.
# resultRef[2775] = 0
# hostBins[2775] =  0
# CPU and GPU results are  equal.
# resultRef[2776] = 0
# hostBins[2776] =  0
# CPU and GPU results are  equal.
# resultRef[2777] = 0
# hostBins[2777] =  0
# CPU and GPU results are  equal.
# resultRef[2778] = 0
# hostBins[2778] =  0
# CPU and GPU results are  equal.
# resultRef[2779] = 2
# hostBins[2779] =  2
# CPU and GPU results are  equal.
# resultRef[2780] = 0
# hostBins[2780] =  0
# CPU and GPU results are  equal.
# resultRef[2781] = 0
# hostBins[2781] =  0
# CPU and GPU results are  equal.
# resultRef[2782] = 0
# hostBins[2782] =  0
# CPU and GPU results are  equal.
# resultRef[2783] = 0
# hostBins[2783] =  0
# CPU and GPU results are  equal.
# resultRef[2784] = 0
# hostBins[2784] =  0
# CPU and GPU results are  equal.
# resultRef[2785] = 0
# hostBins[2785] =  0
# CPU and GPU results are  equal.
# resultRef[2786] = 0
# hostBins[2786] =  0
# CPU and GPU results are  equal.
# resultRef[2787] = 0
# hostBins[2787] =  0
# CPU and GPU results are  equal.
# resultRef[2788] = 0
# hostBins[2788] =  0
# CPU and GPU results are  equal.
# resultRef[2789] = 0
# hostBins[2789] =  0
# CPU and GPU results are  equal.
# resultRef[2790] = 1
# hostBins[2790] =  1
# CPU and GPU results are  equal.
# resultRef[2791] = 0
# hostBins[2791] =  0
# CPU and GPU results are  equal.
# resultRef[2792] = 0
# hostBins[2792] =  0
# CPU and GPU results are  equal.
# resultRef[2793] = 0
# hostBins[2793] =  0
# CPU and GPU results are  equal.
# resultRef[2794] = 0
# hostBins[2794] =  0
# CPU and GPU results are  equal.
# resultRef[2795] = 0
# hostBins[2795] =  0
# CPU and GPU results are  equal.
# resultRef[2796] = 0
# hostBins[2796] =  0
# CPU and GPU results are  equal.
# resultRef[2797] = 0
# hostBins[2797] =  0
# CPU and GPU results are  equal.
# resultRef[2798] = 0
# hostBins[2798] =  0
# CPU and GPU results are  equal.
# resultRef[2799] = 0
# hostBins[2799] =  0
# CPU and GPU results are  equal.
# resultRef[2800] = 0
# hostBins[2800] =  0
# CPU and GPU results are  equal.
# resultRef[2801] = 0
# hostBins[2801] =  0
# CPU and GPU results are  equal.
# resultRef[2802] = 1
# hostBins[2802] =  1
# CPU and GPU results are  equal.
# resultRef[2803] = 1
# hostBins[2803] =  1
# CPU and GPU results are  equal.
# resultRef[2804] = 0
# hostBins[2804] =  0
# CPU and GPU results are  equal.
# resultRef[2805] = 0
# hostBins[2805] =  0
# CPU and GPU results are  equal.
# resultRef[2806] = 1
# hostBins[2806] =  1
# CPU and GPU results are  equal.
# resultRef[2807] = 1
# hostBins[2807] =  1
# CPU and GPU results are  equal.
# resultRef[2808] = 0
# hostBins[2808] =  0
# CPU and GPU results are  equal.
# resultRef[2809] = 0
# hostBins[2809] =  0
# CPU and GPU results are  equal.
# resultRef[2810] = 0
# hostBins[2810] =  0
# CPU and GPU results are  equal.
# resultRef[2811] = 1
# hostBins[2811] =  1
# CPU and GPU results are  equal.
# resultRef[2812] = 0
# hostBins[2812] =  0
# CPU and GPU results are  equal.
# resultRef[2813] = 1
# hostBins[2813] =  1
# CPU and GPU results are  equal.
# resultRef[2814] = 0
# hostBins[2814] =  0
# CPU and GPU results are  equal.
# resultRef[2815] = 0
# hostBins[2815] =  0
# CPU and GPU results are  equal.
# resultRef[2816] = 0
# hostBins[2816] =  0
# CPU and GPU results are  equal.
# resultRef[2817] = 0
# hostBins[2817] =  0
# CPU and GPU results are  equal.
# resultRef[2818] = 0
# hostBins[2818] =  0
# CPU and GPU results are  equal.
# resultRef[2819] = 0
# hostBins[2819] =  0
# CPU and GPU results are  equal.
# resultRef[2820] = 0
# hostBins[2820] =  0
# CPU and GPU results are  equal.
# resultRef[2821] = 1
# hostBins[2821] =  1
# CPU and GPU results are  equal.
# resultRef[2822] = 0
# hostBins[2822] =  0
# CPU and GPU results are  equal.
# resultRef[2823] = 0
# hostBins[2823] =  0
# CPU and GPU results are  equal.
# resultRef[2824] = 0
# hostBins[2824] =  0
# CPU and GPU results are  equal.
# resultRef[2825] = 0
# hostBins[2825] =  0
# CPU and GPU results are  equal.
# resultRef[2826] = 0
# hostBins[2826] =  0
# CPU and GPU results are  equal.
# resultRef[2827] = 0
# hostBins[2827] =  0
# CPU and GPU results are  equal.
# resultRef[2828] = 0
# hostBins[2828] =  0
# CPU and GPU results are  equal.
# resultRef[2829] = 1
# hostBins[2829] =  1
# CPU and GPU results are  equal.
# resultRef[2830] = 0
# hostBins[2830] =  0
# CPU and GPU results are  equal.
# resultRef[2831] = 0
# hostBins[2831] =  0
# CPU and GPU results are  equal.
# resultRef[2832] = 0
# hostBins[2832] =  0
# CPU and GPU results are  equal.
# resultRef[2833] = 0
# hostBins[2833] =  0
# CPU and GPU results are  equal.
# resultRef[2834] = 0
# hostBins[2834] =  0
# CPU and GPU results are  equal.
# resultRef[2835] = 0
# hostBins[2835] =  0
# CPU and GPU results are  equal.
# resultRef[2836] = 0
# hostBins[2836] =  0
# CPU and GPU results are  equal.
# resultRef[2837] = 0
# hostBins[2837] =  0
# CPU and GPU results are  equal.
# resultRef[2838] = 0
# hostBins[2838] =  0
# CPU and GPU results are  equal.
# resultRef[2839] = 0
# hostBins[2839] =  0
# CPU and GPU results are  equal.
# resultRef[2840] = 0
# hostBins[2840] =  0
# CPU and GPU results are  equal.
# resultRef[2841] = 0
# hostBins[2841] =  0
# CPU and GPU results are  equal.
# resultRef[2842] = 0
# hostBins[2842] =  0
# CPU and GPU results are  equal.
# resultRef[2843] = 0
# hostBins[2843] =  0
# CPU and GPU results are  equal.
# resultRef[2844] = 0
# hostBins[2844] =  0
# CPU and GPU results are  equal.
# resultRef[2845] = 0
# hostBins[2845] =  0
# CPU and GPU results are  equal.
# resultRef[2846] = 0
# hostBins[2846] =  0
# CPU and GPU results are  equal.
# resultRef[2847] = 0
# hostBins[2847] =  0
# CPU and GPU results are  equal.
# resultRef[2848] = 0
# hostBins[2848] =  0
# CPU and GPU results are  equal.
# resultRef[2849] = 0
# hostBins[2849] =  0
# CPU and GPU results are  equal.
# resultRef[2850] = 0
# hostBins[2850] =  0
# CPU and GPU results are  equal.
# resultRef[2851] = 0
# hostBins[2851] =  0
# CPU and GPU results are  equal.
# resultRef[2852] = 0
# hostBins[2852] =  0
# CPU and GPU results are  equal.
# resultRef[2853] = 1
# hostBins[2853] =  1
# CPU and GPU results are  equal.
# resultRef[2854] = 1
# hostBins[2854] =  1
# CPU and GPU results are  equal.
# resultRef[2855] = 0
# hostBins[2855] =  0
# CPU and GPU results are  equal.
# resultRef[2856] = 2
# hostBins[2856] =  2
# CPU and GPU results are  equal.
# resultRef[2857] = 1
# hostBins[2857] =  1
# CPU and GPU results are  equal.
# resultRef[2858] = 0
# hostBins[2858] =  0
# CPU and GPU results are  equal.
# resultRef[2859] = 1
# hostBins[2859] =  1
# CPU and GPU results are  equal.
# resultRef[2860] = 0
# hostBins[2860] =  0
# CPU and GPU results are  equal.
# resultRef[2861] = 0
# hostBins[2861] =  0
# CPU and GPU results are  equal.
# resultRef[2862] = 0
# hostBins[2862] =  0
# CPU and GPU results are  equal.
# resultRef[2863] = 0
# hostBins[2863] =  0
# CPU and GPU results are  equal.
# resultRef[2864] = 0
# hostBins[2864] =  0
# CPU and GPU results are  equal.
# resultRef[2865] = 0
# hostBins[2865] =  0
# CPU and GPU results are  equal.
# resultRef[2866] = 0
# hostBins[2866] =  0
# CPU and GPU results are  equal.
# resultRef[2867] = 1
# hostBins[2867] =  1
# CPU and GPU results are  equal.
# resultRef[2868] = 0
# hostBins[2868] =  0
# CPU and GPU results are  equal.
# resultRef[2869] = 1
# hostBins[2869] =  1
# CPU and GPU results are  equal.
# resultRef[2870] = 1
# hostBins[2870] =  1
# CPU and GPU results are  equal.
# resultRef[2871] = 1
# hostBins[2871] =  1
# CPU and GPU results are  equal.
# resultRef[2872] = 0
# hostBins[2872] =  0
# CPU and GPU results are  equal.
# resultRef[2873] = 0
# hostBins[2873] =  0
# CPU and GPU results are  equal.
# resultRef[2874] = 0
# hostBins[2874] =  0
# CPU and GPU results are  equal.
# resultRef[2875] = 0
# hostBins[2875] =  0
# CPU and GPU results are  equal.
# resultRef[2876] = 0
# hostBins[2876] =  0
# CPU and GPU results are  equal.
# resultRef[2877] = 0
# hostBins[2877] =  0
# CPU and GPU results are  equal.
# resultRef[2878] = 0
# hostBins[2878] =  0
# CPU and GPU results are  equal.
# resultRef[2879] = 0
# hostBins[2879] =  0
# CPU and GPU results are  equal.
# resultRef[2880] = 0
# hostBins[2880] =  0
# CPU and GPU results are  equal.
# resultRef[2881] = 1
# hostBins[2881] =  1
# CPU and GPU results are  equal.
# resultRef[2882] = 1
# hostBins[2882] =  1
# CPU and GPU results are  equal.
# resultRef[2883] = 0
# hostBins[2883] =  0
# CPU and GPU results are  equal.
# resultRef[2884] = 0
# hostBins[2884] =  0
# CPU and GPU results are  equal.
# resultRef[2885] = 0
# hostBins[2885] =  0
# CPU and GPU results are  equal.
# resultRef[2886] = 0
# hostBins[2886] =  0
# CPU and GPU results are  equal.
# resultRef[2887] = 0
# hostBins[2887] =  0
# CPU and GPU results are  equal.
# resultRef[2888] = 0
# hostBins[2888] =  0
# CPU and GPU results are  equal.
# resultRef[2889] = 0
# hostBins[2889] =  0
# CPU and GPU results are  equal.
# resultRef[2890] = 0
# hostBins[2890] =  0
# CPU and GPU results are  equal.
# resultRef[2891] = 0
# hostBins[2891] =  0
# CPU and GPU results are  equal.
# resultRef[2892] = 1
# hostBins[2892] =  1
# CPU and GPU results are  equal.
# resultRef[2893] = 0
# hostBins[2893] =  0
# CPU and GPU results are  equal.
# resultRef[2894] = 0
# hostBins[2894] =  0
# CPU and GPU results are  equal.
# resultRef[2895] = 0
# hostBins[2895] =  0
# CPU and GPU results are  equal.
# resultRef[2896] = 1
# hostBins[2896] =  1
# CPU and GPU results are  equal.
# resultRef[2897] = 1
# hostBins[2897] =  1
# CPU and GPU results are  equal.
# resultRef[2898] = 0
# hostBins[2898] =  0
# CPU and GPU results are  equal.
# resultRef[2899] = 1
# hostBins[2899] =  1
# CPU and GPU results are  equal.
# resultRef[2900] = 1
# hostBins[2900] =  1
# CPU and GPU results are  equal.
# resultRef[2901] = 0
# hostBins[2901] =  0
# CPU and GPU results are  equal.
# resultRef[2902] = 0
# hostBins[2902] =  0
# CPU and GPU results are  equal.
# resultRef[2903] = 0
# hostBins[2903] =  0
# CPU and GPU results are  equal.
# resultRef[2904] = 0
# hostBins[2904] =  0
# CPU and GPU results are  equal.
# resultRef[2905] = 0
# hostBins[2905] =  0
# CPU and GPU results are  equal.
# resultRef[2906] = 0
# hostBins[2906] =  0
# CPU and GPU results are  equal.
# resultRef[2907] = 0
# hostBins[2907] =  0
# CPU and GPU results are  equal.
# resultRef[2908] = 1
# hostBins[2908] =  1
# CPU and GPU results are  equal.
# resultRef[2909] = 0
# hostBins[2909] =  0
# CPU and GPU results are  equal.
# resultRef[2910] = 0
# hostBins[2910] =  0
# CPU and GPU results are  equal.
# resultRef[2911] = 0
# hostBins[2911] =  0
# CPU and GPU results are  equal.
# resultRef[2912] = 0
# hostBins[2912] =  0
# CPU and GPU results are  equal.
# resultRef[2913] = 0
# hostBins[2913] =  0
# CPU and GPU results are  equal.
# resultRef[2914] = 0
# hostBins[2914] =  0
# CPU and GPU results are  equal.
# resultRef[2915] = 0
# hostBins[2915] =  0
# CPU and GPU results are  equal.
# resultRef[2916] = 0
# hostBins[2916] =  0
# CPU and GPU results are  equal.
# resultRef[2917] = 0
# hostBins[2917] =  0
# CPU and GPU results are  equal.
# resultRef[2918] = 0
# hostBins[2918] =  0
# CPU and GPU results are  equal.
# resultRef[2919] = 0
# hostBins[2919] =  0
# CPU and GPU results are  equal.
# resultRef[2920] = 0
# hostBins[2920] =  0
# CPU and GPU results are  equal.
# resultRef[2921] = 0
# hostBins[2921] =  0
# CPU and GPU results are  equal.
# resultRef[2922] = 0
# hostBins[2922] =  0
# CPU and GPU results are  equal.
# resultRef[2923] = 0
# hostBins[2923] =  0
# CPU and GPU results are  equal.
# resultRef[2924] = 0
# hostBins[2924] =  0
# CPU and GPU results are  equal.
# resultRef[2925] = 0
# hostBins[2925] =  0
# CPU and GPU results are  equal.
# resultRef[2926] = 1
# hostBins[2926] =  1
# CPU and GPU results are  equal.
# resultRef[2927] = 1
# hostBins[2927] =  1
# CPU and GPU results are  equal.
# resultRef[2928] = 1
# hostBins[2928] =  1
# CPU and GPU results are  equal.
# resultRef[2929] = 0
# hostBins[2929] =  0
# CPU and GPU results are  equal.
# resultRef[2930] = 1
# hostBins[2930] =  1
# CPU and GPU results are  equal.
# resultRef[2931] = 0
# hostBins[2931] =  0
# CPU and GPU results are  equal.
# resultRef[2932] = 0
# hostBins[2932] =  0
# CPU and GPU results are  equal.
# resultRef[2933] = 0
# hostBins[2933] =  0
# CPU and GPU results are  equal.
# resultRef[2934] = 0
# hostBins[2934] =  0
# CPU and GPU results are  equal.
# resultRef[2935] = 1
# hostBins[2935] =  1
# CPU and GPU results are  equal.
# resultRef[2936] = 0
# hostBins[2936] =  0
# CPU and GPU results are  equal.
# resultRef[2937] = 1
# hostBins[2937] =  1
# CPU and GPU results are  equal.
# resultRef[2938] = 0
# hostBins[2938] =  0
# CPU and GPU results are  equal.
# resultRef[2939] = 0
# hostBins[2939] =  0
# CPU and GPU results are  equal.
# resultRef[2940] = 0
# hostBins[2940] =  0
# CPU and GPU results are  equal.
# resultRef[2941] = 1
# hostBins[2941] =  1
# CPU and GPU results are  equal.
# resultRef[2942] = 0
# hostBins[2942] =  0
# CPU and GPU results are  equal.
# resultRef[2943] = 2
# hostBins[2943] =  2
# CPU and GPU results are  equal.
# resultRef[2944] = 0
# hostBins[2944] =  0
# CPU and GPU results are  equal.
# resultRef[2945] = 0
# hostBins[2945] =  0
# CPU and GPU results are  equal.
# resultRef[2946] = 0
# hostBins[2946] =  0
# CPU and GPU results are  equal.
# resultRef[2947] = 0
# hostBins[2947] =  0
# CPU and GPU results are  equal.
# resultRef[2948] = 0
# hostBins[2948] =  0
# CPU and GPU results are  equal.
# resultRef[2949] = 0
# hostBins[2949] =  0
# CPU and GPU results are  equal.
# resultRef[2950] = 0
# hostBins[2950] =  0
# CPU and GPU results are  equal.
# resultRef[2951] = 0
# hostBins[2951] =  0
# CPU and GPU results are  equal.
# resultRef[2952] = 0
# hostBins[2952] =  0
# CPU and GPU results are  equal.
# resultRef[2953] = 1
# hostBins[2953] =  1
# CPU and GPU results are  equal.
# resultRef[2954] = 1
# hostBins[2954] =  1
# CPU and GPU results are  equal.
# resultRef[2955] = 2
# hostBins[2955] =  2
# CPU and GPU results are  equal.
# resultRef[2956] = 1
# hostBins[2956] =  1
# CPU and GPU results are  equal.
# resultRef[2957] = 0
# hostBins[2957] =  0
# CPU and GPU results are  equal.
# resultRef[2958] = 0
# hostBins[2958] =  0
# CPU and GPU results are  equal.
# resultRef[2959] = 0
# hostBins[2959] =  0
# CPU and GPU results are  equal.
# resultRef[2960] = 0
# hostBins[2960] =  0
# CPU and GPU results are  equal.
# resultRef[2961] = 0
# hostBins[2961] =  0
# CPU and GPU results are  equal.
# resultRef[2962] = 0
# hostBins[2962] =  0
# CPU and GPU results are  equal.
# resultRef[2963] = 1
# hostBins[2963] =  1
# CPU and GPU results are  equal.
# resultRef[2964] = 0
# hostBins[2964] =  0
# CPU and GPU results are  equal.
# resultRef[2965] = 1
# hostBins[2965] =  1
# CPU and GPU results are  equal.
# resultRef[2966] = 0
# hostBins[2966] =  0
# CPU and GPU results are  equal.
# resultRef[2967] = 1
# hostBins[2967] =  1
# CPU and GPU results are  equal.
# resultRef[2968] = 0
# hostBins[2968] =  0
# CPU and GPU results are  equal.
# resultRef[2969] = 0
# hostBins[2969] =  0
# CPU and GPU results are  equal.
# resultRef[2970] = 0
# hostBins[2970] =  0
# CPU and GPU results are  equal.
# resultRef[2971] = 0
# hostBins[2971] =  0
# CPU and GPU results are  equal.
# resultRef[2972] = 0
# hostBins[2972] =  0
# CPU and GPU results are  equal.
# resultRef[2973] = 0
# hostBins[2973] =  0
# CPU and GPU results are  equal.
# resultRef[2974] = 0
# hostBins[2974] =  0
# CPU and GPU results are  equal.
# resultRef[2975] = 0
# hostBins[2975] =  0
# CPU and GPU results are  equal.
# resultRef[2976] = 0
# hostBins[2976] =  0
# CPU and GPU results are  equal.
# resultRef[2977] = 0
# hostBins[2977] =  0
# CPU and GPU results are  equal.
# resultRef[2978] = 0
# hostBins[2978] =  0
# CPU and GPU results are  equal.
# resultRef[2979] = 0
# hostBins[2979] =  0
# CPU and GPU results are  equal.
# resultRef[2980] = 0
# hostBins[2980] =  0
# CPU and GPU results are  equal.
# resultRef[2981] = 0
# hostBins[2981] =  0
# CPU and GPU results are  equal.
# resultRef[2982] = 0
# hostBins[2982] =  0
# CPU and GPU results are  equal.
# resultRef[2983] = 1
# hostBins[2983] =  1
# CPU and GPU results are  equal.
# resultRef[2984] = 0
# hostBins[2984] =  0
# CPU and GPU results are  equal.
# resultRef[2985] = 0
# hostBins[2985] =  0
# CPU and GPU results are  equal.
# resultRef[2986] = 0
# hostBins[2986] =  0
# CPU and GPU results are  equal.
# resultRef[2987] = 0
# hostBins[2987] =  0
# CPU and GPU results are  equal.
# resultRef[2988] = 0
# hostBins[2988] =  0
# CPU and GPU results are  equal.
# resultRef[2989] = 0
# hostBins[2989] =  0
# CPU and GPU results are  equal.
# resultRef[2990] = 0
# hostBins[2990] =  0
# CPU and GPU results are  equal.
# resultRef[2991] = 0
# hostBins[2991] =  0
# CPU and GPU results are  equal.
# resultRef[2992] = 0
# hostBins[2992] =  0
# CPU and GPU results are  equal.
# resultRef[2993] = 0
# hostBins[2993] =  0
# CPU and GPU results are  equal.
# resultRef[2994] = 0
# hostBins[2994] =  0
# CPU and GPU results are  equal.
# resultRef[2995] = 0
# hostBins[2995] =  0
# CPU and GPU results are  equal.
# resultRef[2996] = 1
# hostBins[2996] =  1
# CPU and GPU results are  equal.
# resultRef[2997] = 0
# hostBins[2997] =  0
# CPU and GPU results are  equal.
# resultRef[2998] = 2
# hostBins[2998] =  2
# CPU and GPU results are  equal.
# resultRef[2999] = 0
# hostBins[2999] =  0
# CPU and GPU results are  equal.
# resultRef[3000] = 0
# hostBins[3000] =  0
# CPU and GPU results are  equal.
# resultRef[3001] = 0
# hostBins[3001] =  0
# CPU and GPU results are  equal.
# resultRef[3002] = 1
# hostBins[3002] =  1
# CPU and GPU results are  equal.
# resultRef[3003] = 1
# hostBins[3003] =  1
# CPU and GPU results are  equal.
# resultRef[3004] = 1
# hostBins[3004] =  1
# CPU and GPU results are  equal.
# resultRef[3005] = 0
# hostBins[3005] =  0
# CPU and GPU results are  equal.
# resultRef[3006] = 0
# hostBins[3006] =  0
# CPU and GPU results are  equal.
# resultRef[3007] = 0
# hostBins[3007] =  0
# CPU and GPU results are  equal.
# resultRef[3008] = 0
# hostBins[3008] =  0
# CPU and GPU results are  equal.
# resultRef[3009] = 0
# hostBins[3009] =  0
# CPU and GPU results are  equal.
# resultRef[3010] = 0
# hostBins[3010] =  0
# CPU and GPU results are  equal.
# resultRef[3011] = 0
# hostBins[3011] =  0
# CPU and GPU results are  equal.
# resultRef[3012] = 1
# hostBins[3012] =  1
# CPU and GPU results are  equal.
# resultRef[3013] = 1
# hostBins[3013] =  1
# CPU and GPU results are  equal.
# resultRef[3014] = 0
# hostBins[3014] =  0
# CPU and GPU results are  equal.
# resultRef[3015] = 1
# hostBins[3015] =  1
# CPU and GPU results are  equal.
# resultRef[3016] = 0
# hostBins[3016] =  0
# CPU and GPU results are  equal.
# resultRef[3017] = 0
# hostBins[3017] =  0
# CPU and GPU results are  equal.
# resultRef[3018] = 2
# hostBins[3018] =  2
# CPU and GPU results are  equal.
# resultRef[3019] = 0
# hostBins[3019] =  0
# CPU and GPU results are  equal.
# resultRef[3020] = 0
# hostBins[3020] =  0
# CPU and GPU results are  equal.
# resultRef[3021] = 0
# hostBins[3021] =  0
# CPU and GPU results are  equal.
# resultRef[3022] = 0
# hostBins[3022] =  0
# CPU and GPU results are  equal.
# resultRef[3023] = 0
# hostBins[3023] =  0
# CPU and GPU results are  equal.
# resultRef[3024] = 1
# hostBins[3024] =  1
# CPU and GPU results are  equal.
# resultRef[3025] = 1
# hostBins[3025] =  1
# CPU and GPU results are  equal.
# resultRef[3026] = 0
# hostBins[3026] =  0
# CPU and GPU results are  equal.
# resultRef[3027] = 0
# hostBins[3027] =  0
# CPU and GPU results are  equal.
# resultRef[3028] = 0
# hostBins[3028] =  0
# CPU and GPU results are  equal.
# resultRef[3029] = 0
# hostBins[3029] =  0
# CPU and GPU results are  equal.
# resultRef[3030] = 0
# hostBins[3030] =  0
# CPU and GPU results are  equal.
# resultRef[3031] = 0
# hostBins[3031] =  0
# CPU and GPU results are  equal.
# resultRef[3032] = 0
# hostBins[3032] =  0
# CPU and GPU results are  equal.
# resultRef[3033] = 0
# hostBins[3033] =  0
# CPU and GPU results are  equal.
# resultRef[3034] = 1
# hostBins[3034] =  1
# CPU and GPU results are  equal.
# resultRef[3035] = 1
# hostBins[3035] =  1
# CPU and GPU results are  equal.
# resultRef[3036] = 0
# hostBins[3036] =  0
# CPU and GPU results are  equal.
# resultRef[3037] = 0
# hostBins[3037] =  0
# CPU and GPU results are  equal.
# resultRef[3038] = 1
# hostBins[3038] =  1
# CPU and GPU results are  equal.
# resultRef[3039] = 0
# hostBins[3039] =  0
# CPU and GPU results are  equal.
# resultRef[3040] = 0
# hostBins[3040] =  0
# CPU and GPU results are  equal.
# resultRef[3041] = 0
# hostBins[3041] =  0
# CPU and GPU results are  equal.
# resultRef[3042] = 0
# hostBins[3042] =  0
# CPU and GPU results are  equal.
# resultRef[3043] = 0
# hostBins[3043] =  0
# CPU and GPU results are  equal.
# resultRef[3044] = 2
# hostBins[3044] =  2
# CPU and GPU results are  equal.
# resultRef[3045] = 0
# hostBins[3045] =  0
# CPU and GPU results are  equal.
# resultRef[3046] = 0
# hostBins[3046] =  0
# CPU and GPU results are  equal.
# resultRef[3047] = 0
# hostBins[3047] =  0
# CPU and GPU results are  equal.
# resultRef[3048] = 0
# hostBins[3048] =  0
# CPU and GPU results are  equal.
# resultRef[3049] = 0
# hostBins[3049] =  0
# CPU and GPU results are  equal.
# resultRef[3050] = 0
# hostBins[3050] =  0
# CPU and GPU results are  equal.
# resultRef[3051] = 0
# hostBins[3051] =  0
# CPU and GPU results are  equal.
# resultRef[3052] = 0
# hostBins[3052] =  0
# CPU and GPU results are  equal.
# resultRef[3053] = 0
# hostBins[3053] =  0
# CPU and GPU results are  equal.
# resultRef[3054] = 0
# hostBins[3054] =  0
# CPU and GPU results are  equal.
# resultRef[3055] = 0
# hostBins[3055] =  0
# CPU and GPU results are  equal.
# resultRef[3056] = 0
# hostBins[3056] =  0
# CPU and GPU results are  equal.
# resultRef[3057] = 0
# hostBins[3057] =  0
# CPU and GPU results are  equal.
# resultRef[3058] = 0
# hostBins[3058] =  0
# CPU and GPU results are  equal.
# resultRef[3059] = 1
# hostBins[3059] =  1
# CPU and GPU results are  equal.
# resultRef[3060] = 0
# hostBins[3060] =  0
# CPU and GPU results are  equal.
# resultRef[3061] = 0
# hostBins[3061] =  0
# CPU and GPU results are  equal.
# resultRef[3062] = 1
# hostBins[3062] =  1
# CPU and GPU results are  equal.
# resultRef[3063] = 0
# hostBins[3063] =  0
# CPU and GPU results are  equal.
# resultRef[3064] = 0
# hostBins[3064] =  0
# CPU and GPU results are  equal.
# resultRef[3065] = 0
# hostBins[3065] =  0
# CPU and GPU results are  equal.
# resultRef[3066] = 0
# hostBins[3066] =  0
# CPU and GPU results are  equal.
# resultRef[3067] = 0
# hostBins[3067] =  0
# CPU and GPU results are  equal.
# resultRef[3068] = 1
# hostBins[3068] =  1
# CPU and GPU results are  equal.
# resultRef[3069] = 0
# hostBins[3069] =  0
# CPU and GPU results are  equal.
# resultRef[3070] = 0
# hostBins[3070] =  0
# CPU and GPU results are  equal.
# resultRef[3071] = 0
# hostBins[3071] =  0
# CPU and GPU results are  equal.
# resultRef[3072] = 0
# hostBins[3072] =  0
# CPU and GPU results are  equal.
# resultRef[3073] = 0
# hostBins[3073] =  0
# CPU and GPU results are  equal.
# resultRef[3074] = 0
# hostBins[3074] =  0
# CPU and GPU results are  equal.
# resultRef[3075] = 0
# hostBins[3075] =  0
# CPU and GPU results are  equal.
# resultRef[3076] = 0
# hostBins[3076] =  0
# CPU and GPU results are  equal.
# resultRef[3077] = 1
# hostBins[3077] =  1
# CPU and GPU results are  equal.
# resultRef[3078] = 0
# hostBins[3078] =  0
# CPU and GPU results are  equal.
# resultRef[3079] = 0
# hostBins[3079] =  0
# CPU and GPU results are  equal.
# resultRef[3080] = 0
# hostBins[3080] =  0
# CPU and GPU results are  equal.
# resultRef[3081] = 0
# hostBins[3081] =  0
# CPU and GPU results are  equal.
# resultRef[3082] = 0
# hostBins[3082] =  0
# CPU and GPU results are  equal.
# resultRef[3083] = 0
# hostBins[3083] =  0
# CPU and GPU results are  equal.
# resultRef[3084] = 0
# hostBins[3084] =  0
# CPU and GPU results are  equal.
# resultRef[3085] = 0
# hostBins[3085] =  0
# CPU and GPU results are  equal.
# resultRef[3086] = 0
# hostBins[3086] =  0
# CPU and GPU results are  equal.
# resultRef[3087] = 0
# hostBins[3087] =  0
# CPU and GPU results are  equal.
# resultRef[3088] = 1
# hostBins[3088] =  1
# CPU and GPU results are  equal.
# resultRef[3089] = 0
# hostBins[3089] =  0
# CPU and GPU results are  equal.
# resultRef[3090] = 0
# hostBins[3090] =  0
# CPU and GPU results are  equal.
# resultRef[3091] = 0
# hostBins[3091] =  0
# CPU and GPU results are  equal.
# resultRef[3092] = 1
# hostBins[3092] =  1
# CPU and GPU results are  equal.
# resultRef[3093] = 0
# hostBins[3093] =  0
# CPU and GPU results are  equal.
# resultRef[3094] = 0
# hostBins[3094] =  0
# CPU and GPU results are  equal.
# resultRef[3095] = 0
# hostBins[3095] =  0
# CPU and GPU results are  equal.
# resultRef[3096] = 2
# hostBins[3096] =  2
# CPU and GPU results are  equal.
# resultRef[3097] = 0
# hostBins[3097] =  0
# CPU and GPU results are  equal.
# resultRef[3098] = 0
# hostBins[3098] =  0
# CPU and GPU results are  equal.
# resultRef[3099] = 1
# hostBins[3099] =  1
# CPU and GPU results are  equal.
# resultRef[3100] = 0
# hostBins[3100] =  0
# CPU and GPU results are  equal.
# resultRef[3101] = 0
# hostBins[3101] =  0
# CPU and GPU results are  equal.
# resultRef[3102] = 0
# hostBins[3102] =  0
# CPU and GPU results are  equal.
# resultRef[3103] = 0
# hostBins[3103] =  0
# CPU and GPU results are  equal.
# resultRef[3104] = 0
# hostBins[3104] =  0
# CPU and GPU results are  equal.
# resultRef[3105] = 0
# hostBins[3105] =  0
# CPU and GPU results are  equal.
# resultRef[3106] = 1
# hostBins[3106] =  1
# CPU and GPU results are  equal.
# resultRef[3107] = 1
# hostBins[3107] =  1
# CPU and GPU results are  equal.
# resultRef[3108] = 0
# hostBins[3108] =  0
# CPU and GPU results are  equal.
# resultRef[3109] = 0
# hostBins[3109] =  0
# CPU and GPU results are  equal.
# resultRef[3110] = 0
# hostBins[3110] =  0
# CPU and GPU results are  equal.
# resultRef[3111] = 1
# hostBins[3111] =  1
# CPU and GPU results are  equal.
# resultRef[3112] = 0
# hostBins[3112] =  0
# CPU and GPU results are  equal.
# resultRef[3113] = 0
# hostBins[3113] =  0
# CPU and GPU results are  equal.
# resultRef[3114] = 0
# hostBins[3114] =  0
# CPU and GPU results are  equal.
# resultRef[3115] = 1
# hostBins[3115] =  1
# CPU and GPU results are  equal.
# resultRef[3116] = 0
# hostBins[3116] =  0
# CPU and GPU results are  equal.
# resultRef[3117] = 1
# hostBins[3117] =  1
# CPU and GPU results are  equal.
# resultRef[3118] = 0
# hostBins[3118] =  0
# CPU and GPU results are  equal.
# resultRef[3119] = 0
# hostBins[3119] =  0
# CPU and GPU results are  equal.
# resultRef[3120] = 1
# hostBins[3120] =  1
# CPU and GPU results are  equal.
# resultRef[3121] = 0
# hostBins[3121] =  0
# CPU and GPU results are  equal.
# resultRef[3122] = 0
# hostBins[3122] =  0
# CPU and GPU results are  equal.
# resultRef[3123] = 1
# hostBins[3123] =  1
# CPU and GPU results are  equal.
# resultRef[3124] = 0
# hostBins[3124] =  0
# CPU and GPU results are  equal.
# resultRef[3125] = 0
# hostBins[3125] =  0
# CPU and GPU results are  equal.
# resultRef[3126] = 0
# hostBins[3126] =  0
# CPU and GPU results are  equal.
# resultRef[3127] = 0
# ...
# resultRef[4014] = 0
# hostBins[4014] =  0
# CPU and GPU results are  equal.
# resultRef[4015] = 0
# hostBins[4015] =  0
# CPU and GPU results are  equal.
# resultRef[4016] = 1
# hostBins[4016] =  1
# CPU and GPU results are  equal.
# resultRef[4017] = 1
# hostBins[4017] =  1
# CPU and GPU results are  equal.
# resultRef[4018] = 0
# hostBins[4018] =  0
# CPU and GPU results are  equal.
# resultRef[4019] = 0
# hostBins[4019] =  0
# CPU and GPU results are  equal.
# resultRef[4020] = 0
# hostBins[4020] =  0
# CPU and GPU results are  equal.
# resultRef[4021] = 0
# hostBins[4021] =  0
# CPU and GPU results are  equal.
# resultRef[4022] = 0
# hostBins[4022] =  0
# CPU and GPU results are  equal.
# resultRef[4023] = 1
# hostBins[4023] =  1
# CPU and GPU results are  equal.
# resultRef[4024] = 0
# hostBins[4024] =  0
# CPU and GPU results are  equal.
# resultRef[4025] = 1
# hostBins[4025] =  1
# CPU and GPU results are  equal.
# resultRef[4026] = 0
# hostBins[4026] =  0
# CPU and GPU results are  equal.
# resultRef[4027] = 0
# hostBins[4027] =  0
# CPU and GPU results are  equal.
# resultRef[4028] = 1
# hostBins[4028] =  1
# CPU and GPU results are  equal.
# resultRef[4029] = 0
# hostBins[4029] =  0
# CPU and GPU results are  equal.
# resultRef[4030] = 1
# hostBins[4030] =  1
# CPU and GPU results are  equal.
# resultRef[4031] = 0
# hostBins[4031] =  0
# CPU and GPU results are  equal.
# resultRef[4032] = 0
# hostBins[4032] =  0
# CPU and GPU results are  equal.
# resultRef[4033] = 0
# hostBins[4033] =  0
# CPU and GPU results are  equal.
# resultRef[4034] = 0
# hostBins[4034] =  0
# CPU and GPU results are  equal.
# resultRef[4035] = 1
# hostBins[4035] =  1
# CPU and GPU results are  equal.
# resultRef[4036] = 0
# hostBins[4036] =  0
# CPU and GPU results are  equal.
# resultRef[4037] = 0
# hostBins[4037] =  0
# CPU and GPU results are  equal.
# resultRef[4038] = 0
# hostBins[4038] =  0
# CPU and GPU results are  equal.
# resultRef[4039] = 0
# hostBins[4039] =  0
# CPU and GPU results are  equal.
# resultRef[4040] = 0
# hostBins[4040] =  0
# CPU and GPU results are  equal.
# resultRef[4041] = 2
# hostBins[4041] =  2
# CPU and GPU results are  equal.
# resultRef[4042] = 0
# hostBins[4042] =  0
# CPU and GPU results are  equal.
# resultRef[4043] = 0
# hostBins[4043] =  0
# CPU and GPU results are  equal.
# resultRef[4044] = 0
# hostBins[4044] =  0
# CPU and GPU results are  equal.
# resultRef[4045] = 0
# hostBins[4045] =  0
# CPU and GPU results are  equal.
# resultRef[4046] = 1
# hostBins[4046] =  1
# CPU and GPU results are  equal.
# resultRef[4047] = 0
# hostBins[4047] =  0
# CPU and GPU results are  equal.
# resultRef[4048] = 0
# hostBins[4048] =  0
# CPU and GPU results are  equal.
# resultRef[4049] = 0
# hostBins[4049] =  0
# CPU and GPU results are  equal.
# resultRef[4050] = 1
# hostBins[4050] =  1
# CPU and GPU results are  equal.
# resultRef[4051] = 0
# hostBins[4051] =  0
# CPU and GPU results are  equal.
# resultRef[4052] = 2
# hostBins[4052] =  2
# CPU and GPU results are  equal.
# resultRef[4053] = 0
# hostBins[4053] =  0
# CPU and GPU results are  equal.
# resultRef[4054] = 0
# hostBins[4054] =  0
# CPU and GPU results are  equal.
# resultRef[4055] = 0
# hostBins[4055] =  0
# CPU and GPU results are  equal.
# resultRef[4056] = 0
# hostBins[4056] =  0
# CPU and GPU results are  equal.
# resultRef[4057] = 0
# hostBins[4057] =  0
# CPU and GPU results are  equal.
# resultRef[4058] = 0
# hostBins[4058] =  0
# CPU and GPU results are  equal.
# resultRef[4059] = 0
# hostBins[4059] =  0
# CPU and GPU results are  equal.
# resultRef[4060] = 0
# hostBins[4060] =  0
# CPU and GPU results are  equal.
# resultRef[4061] = 0
# hostBins[4061] =  0
# CPU and GPU results are  equal.
# resultRef[4062] = 0
# hostBins[4062] =  0
# CPU and GPU results are  equal.
# resultRef[4063] = 1
# hostBins[4063] =  1
# CPU and GPU results are  equal.
# resultRef[4064] = 0
# hostBins[4064] =  0
# CPU and GPU results are  equal.
# resultRef[4065] = 0
# hostBins[4065] =  0
# CPU and GPU results are  equal.
# resultRef[4066] = 0
# hostBins[4066] =  0
# CPU and GPU results are  equal.
# resultRef[4067] = 1
# hostBins[4067] =  1
# CPU and GPU results are  equal.
# resultRef[4068] = 0
# hostBins[4068] =  0
# CPU and GPU results are  equal.
# resultRef[4069] = 0
# hostBins[4069] =  0
# CPU and GPU results are  equal.
# resultRef[4070] = 0
# hostBins[4070] =  0
# CPU and GPU results are  equal.
# resultRef[4071] = 0
# hostBins[4071] =  0
# CPU and GPU results are  equal.
# resultRef[4072] = 0
# hostBins[4072] =  0
# CPU and GPU results are  equal.
# resultRef[4073] = 0
# hostBins[4073] =  0
# CPU and GPU results are  equal.
# resultRef[4074] = 0
# hostBins[4074] =  0
# CPU and GPU results are  equal.
# resultRef[4075] = 1
# hostBins[4075] =  1
# CPU and GPU results are  equal.
# resultRef[4076] = 0
# hostBins[4076] =  0
# CPU and GPU results are  equal.
# resultRef[4077] = 0
# hostBins[4077] =  0
# CPU and GPU results are  equal.
# resultRef[4078] = 0
# hostBins[4078] =  0
# CPU and GPU results are  equal.
# resultRef[4079] = 0
# hostBins[4079] =  0
# CPU and GPU results are  equal.
# resultRef[4080] = 0
# hostBins[4080] =  0
# CPU and GPU results are  equal.
# resultRef[4081] = 0
# hostBins[4081] =  0
# CPU and GPU results are  equal.
# resultRef[4082] = 0
# hostBins[4082] =  0
# CPU and GPU results are  equal.
# resultRef[4083] = 0
# hostBins[4083] =  0
# CPU and GPU results are  equal.
# resultRef[4084] = 0
# hostBins[4084] =  0
# CPU and GPU results are  equal.
# resultRef[4085] = 0
# hostBins[4085] =  0
# CPU and GPU results are  equal.
# resultRef[4086] = 0
# hostBins[4086] =  0
# CPU and GPU results are  equal.
# resultRef[4087] = 1
# hostBins[4087] =  1
# CPU and GPU results are  equal.
# resultRef[4088] = 1
# hostBins[4088] =  1
# CPU and GPU results are  equal.
# resultRef[4089] = 0
# hostBins[4089] =  0
# CPU and GPU results are  equal.
# resultRef[4090] = 0
# hostBins[4090] =  0
# CPU and GPU results are  equal.
# resultRef[4091] = 0
# hostBins[4091] =  0
# CPU and GPU results are  equal.
# resultRef[4092] = 0
# hostBins[4092] =  0
# CPU and GPU results are  equal.
# resultRef[4093] = 1
# hostBins[4093] =  1
# CPU and GPU results are  equal.
# resultRef[4094] = 0
# hostBins[4094] =  0
# CPU and GPU results are  equal.
# resultRef[4095] = 0
# hostBins[4095] =  0
# CPU and GPU results are  equal.
# ==PROF== Disconnected from process 379
# [379] lab3_ex3@127.0.0.1
#   histogram_kernel(unsigned int*, unsigned int*, unsigned int, unsigned int), 2022-Dec-15 22:51:10, Context 1, Stream 7
#     Section: GPU Speed Of Light
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     DRAM Frequency                                                           cycle/nsecond                           4.96
#     SM Frequency                                                             cycle/usecond                         580.50
#     Elapsed Cycles                                                                   cycle                          6,838
#     Memory [%]                                                                           %                           4.56
#     SOL DRAM                                                                             %                           0.78
#     Duration                                                                       usecond                          11.78
#     SOL L1/TEX Cache                                                                     %                          14.03
#     SOL L2 Cache                                                                         %                           3.45
#     SM Active Cycles                                                                 cycle                       2,224.55
#     SM [%]                                                                               %                           4.56
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     WRN   This kernel grid is too small to fill the available resources on this device, resulting in only 0.1 full
#           waves across all SMs. Look at Launch Statistics for more details.
#
#     Section: Launch Statistics
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Block Size                                                                                                         64
#     Function Cache Configuration                                                                  cudaFuncCachePreferNone
#     Grid Size                                                                                                          16
#     Registers Per Thread                                                   register/thread                             16
#     Shared Memory Configuration Size                                                 Kbyte                          65.54
#     Driver Shared Memory Per Block                                              byte/block                              0
#     Dynamic Shared Memory Per Block                                             byte/block                              0
#     Static Shared Memory Per Block                                             Kbyte/block                          16.38
#     Threads                                                                         thread                          1,024
#     Waves Per SM                                                                                                     0.10
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     WRN   The grid for this launch is configured to execute only 16 blocks, which is less than the GPU's 40
#           multiprocessors. This can underutilize some multiprocessors. If you do not intend to execute this kernel
#           concurrently with other workloads, consider reducing the block size to have at least one block per
#           multiprocessor or increase the size of the grid to fully utilize the available hardware resources.
#
#     Section: Occupancy
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Block Limit SM                                                                   block                             16
#     Block Limit Registers                                                            block                             64
#     Block Limit Shared Mem                                                           block                              4
#     Block Limit Warps                                                                block                             16
#     Theoretical Active Warps per SM                                                   warp                              8
#     Theoretical Occupancy                                                                %                             25
#     Achieved Occupancy                                                                   %                           6.25
#     Achieved Active Warps Per SM                                                      warp                           2.00
#     ---------------------------------------------------------------------- --------------- ------------------------------
#
#   convert_kernel(unsigned int*, unsigned int), 2022-Dec-15 22:51:10, Context 1, Stream 7
#     Section: GPU Speed Of Light
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     DRAM Frequency                                                           cycle/nsecond                           4.77
#     SM Frequency                                                             cycle/usecond                         562.03
#     Elapsed Cycles                                                                   cycle                          2,141
#     Memory [%]                                                                           %                           1.74
#     SOL DRAM                                                                             %                           1.74
#     Duration                                                                       usecond                           3.81
#     SOL L1/TEX Cache                                                                     %                           1.46
#     SOL L2 Cache                                                                         %                           1.14
#     SM Active Cycles                                                                 cycle                         874.95
#     SM [%]                                                                               %                           0.60
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     WRN   This kernel grid is too small to fill the available resources on this device, resulting in only 0.1 full
#           waves across all SMs. Look at Launch Statistics for more details.
#
#     Section: Launch Statistics
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Block Size                                                                                                         64
#     Function Cache Configuration                                                                  cudaFuncCachePreferNone
#     Grid Size                                                                                                          64
#     Registers Per Thread                                                   register/thread                             16
#     Shared Memory Configuration Size                                                 Kbyte                          32.77
#     Driver Shared Memory Per Block                                              byte/block                              0
#     Dynamic Shared Memory Per Block                                             byte/block                              0
#     Static Shared Memory Per Block                                              byte/block                              0
#     Threads                                                                         thread                          4,096
#     Waves Per SM                                                                                                     0.10
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     WRN   If you execute __syncthreads() to synchronize the threads of a block, it is recommended to have more than the
#           achieved 1 blocks per multiprocessor. This way, blocks that aren't waiting for __syncthreads() can keep the
#           hardware busy.
#
#     Section: Occupancy
#     ---------------------------------------------------------------------- --------------- ------------------------------
#     Block Limit SM                                                                   block                             16
#     Block Limit Registers                                                            block                             64
#     Block Limit Shared Mem                                                           block                             16
#     Block Limit Warps                                                                block                             16
#     Theoretical Active Warps per SM                                                   warp                             32
#     Theoretical Occupancy                                                                %                            100
#     Achieved Occupancy                                                                   %                           9.76
#     Achieved Active Warps Per SM                                                      warp                           3.12
#     ---------------------------------------------------------------------- --------------- ------------------------------
