# %% [markdown]
# <a href="https://colab.research.google.com/github/zhang99111/DD2360HT22/blob/main/hw_4/hw4_ex4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd '/content/drive/MyDrive'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive

# %%
# !nvcc hw4_ex4.cu -lcusparse -lcublas -o hw4_ex4

# %%
# !./hw4_ex4 312 1
# Out:
# The X dimension of the grid is 312
# The number of time steps to perform is 1
# Timing - Allocating device memory. 		Elasped 85624 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 86 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 6 microseconds
# Timing - Initializing memory on the host. 		Elasped 26 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 207 microseconds
# time spent in SpMV: 222.000000
# The relative error of the approximation is 11.385603

# %%
# !./hw4_ex4 2048 1
# Out:
# The X dimension of the grid is 2048
# The number of time steps to perform is 1
# Timing - Allocating device memory. 		Elasped 83514 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 85 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 33 microseconds
# Timing - Initializing memory on the host. 		Elasped 27 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 295 microseconds
# time spent in SpMV: 261.000000
# The relative error of the approximation is 29.303943

# %%
# !./hw4_ex4 4 2
# Out:
# The X dimension of the grid is 4
# The number of time steps to perform is 2
# Timing - Allocating device memory. 		Elasped 86929 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 43 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 1 microseconds
# Timing - Initializing memory on the host. 		Elasped 0 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 323 microseconds
# time spent in SpMV: 82.000000
# The relative error of the approximation is 0.298592

# %%
# !./hw4_ex4 8 2
# Out:
# The X dimension of the grid is 8
# The number of time steps to perform is 2
# Timing - Allocating device memory. 		Elasped 87370 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 80 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 0 microseconds
# Timing - Initializing memory on the host. 		Elasped 0 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 231 microseconds
# time spent in SpMV: 81.000000
# The relative error of the approximation is 1.231768

# %%
# !./hw4_ex4 16 2
# Out:
# The X dimension of the grid is 16
# The number of time steps to perform is 2
# Timing - Allocating device memory. 		Elasped 88444 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 61 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 0 microseconds
# Timing - Initializing memory on the host. 		Elasped 0 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 275 microseconds
# time spent in SpMV: 84.000000
# The relative error of the approximation is 2.147572

# %%
# !./hw4_ex4 32 2
# Out:
# The X dimension of the grid is 32
# The number of time steps to perform is 2
# Timing - Allocating device memory. 		Elasped 82775 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 75 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 1 microseconds
# Timing - Initializing memory on the host. 		Elasped 1 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 292 microseconds
# time spent in SpMV: 88.000000
# The relative error of the approximation is 3.288533

# %%
# !./hw4_ex4 64 2
# Out:
# The X dimension of the grid is 64
# The number of time steps to perform is 2
# Timing - Allocating device memory. 		Elasped 82816 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 43 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 1 microseconds
# Timing - Initializing memory on the host. 		Elasped 0 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 185 microseconds
# time spent in SpMV: 85.000000
# The relative error of the approximation is 4.819221

# %%
# !./hw4_ex4 128 2
# Out:
# The X dimension of the grid is 128
# The number of time steps to perform is 2
# Timing - Allocating device memory. 		Elasped 88798 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 67 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 3 microseconds
# Timing - Initializing memory on the host. 		Elasped 0 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 329 microseconds
# time spent in SpMV: 95.000000
# The relative error of the approximation is 6.931700

# %%
# !./hw4_ex4 256 2
# Out:
# The X dimension of the grid is 256
# The number of time steps to perform is 2
# Timing - Allocating device memory. 		Elasped 89890 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 61 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 5 microseconds
# Timing - Initializing memory on the host. 		Elasped 29 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 287 microseconds
# time spent in SpMV: 302.000000
# The relative error of the approximation is 9.884174

# %%
# !./hw4_ex4 128 10
# Out:
# The X dimension of the grid is 128
# The number of time steps to perform is 10
# Timing - Allocating device memory. 		Elasped 88270 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 66 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 2 microseconds
# Timing - Initializing memory on the host. 		Elasped 0 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 292 microseconds
# time spent in SpMV: 314.000000
# The relative error of the approximation is 5.551650

# %%
# !./hw4_ex4 128 1010
# Out:
# The X dimension of the grid is 128
# The number of time steps to perform is 1010
# Timing - Allocating device memory. 		Elasped 86524 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 70 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 2 microseconds
# Timing - Initializing memory on the host. 		Elasped 0 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 258 microseconds
# time spent in SpMV: 28788.000000
# The relative error of the approximation is 1.480747

# %%
# !./hw4_ex4 128 2010
# Out:
# The X dimension of the grid is 128
# The number of time steps to perform is 2010
# Timing - Allocating device memory. 		Elasped 85429 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 41 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 2 microseconds
# Timing - Initializing memory on the host. 		Elasped 0 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 203 microseconds
# time spent in SpMV: 51105.000000
# The relative error of the approximation is 0.959595

# %%
# !./hw4_ex4 128 3010
# Out:
# The X dimension of the grid is 128
# The number of time steps to perform is 3010
# Timing - Allocating device memory. 		Elasped 82095 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 62 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 2 microseconds
# Timing - Initializing memory on the host. 		Elasped 1 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 213 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 33 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# ...

# %%
# !./hw4_ex4 128 4010
# Out:
# The X dimension of the grid is 128
# The number of time steps to perform is 4010
# Timing - Allocating device memory. 		Elasped 82870 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 44 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 2 microseconds
# Timing - Initializing memory on the host. 		Elasped 0 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 447 microseconds
# time spent in SpMV: 88536.000000
# The relative error of the approximation is 0.464450

# %%
# !./hw4_ex4 128 5010
# Out:
# The X dimension of the grid is 128
# The number of time steps to perform is 5010
# Timing - Allocating device memory. 		Elasped 88673 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 46 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 2 microseconds
# Timing - Initializing memory on the host. 		Elasped 0 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 302 microseconds
# time spent in SpMV: 103914.000000
# The relative error of the approximation is 0.336597

# %%
# !./hw4_ex4 128 6010
# Out:
# The X dimension of the grid is 128
# The number of time steps to perform is 6010
# Timing - Allocating device memory. 		Elasped 83459 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 63 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 2 microseconds
# Timing - Initializing memory on the host. 		Elasped 0 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 281 microseconds
# time spent in SpMV: 121211.000000
# The relative error of the approximation is 0.248554

# %%
# !./hw4_ex4 128 7010
# Out:
# The X dimension of the grid is 128
# The number of time steps to perform is 7010
# Timing - Allocating device memory. 		Elasped 87983 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 42 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 2 microseconds
# Timing - Initializing memory on the host. 		Elasped 1 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 185 microseconds
# time spent in SpMV: 133960.000000
# The relative error of the approximation is 0.186129

# %%
# !./hw4_ex4 128 8010
# Out:
# The X dimension of the grid is 128
# The number of time steps to perform is 8010
# Timing - Allocating device memory. 		Elasped 86631 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 50 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 2 microseconds
# Timing - Initializing memory on the host. 		Elasped 0 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 262 microseconds
# time spent in SpMV: 151857.000000
# The relative error of the approximation is 0.140850

# %%
# !./hw4_ex4 128 9010
# Out:
# The X dimension of the grid is 128
# The number of time steps to perform is 9010
# Timing - Allocating device memory. 		Elasped 90608 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 71 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 3 microseconds
# Timing - Initializing memory on the host. 		Elasped 0 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 2399 microseconds
# time spent in SpMV: 166497.000000
# The relative error of the approximation is 0.107430

# %%
# !./hw4_ex4 128 10010
# Out:
# The X dimension of the grid is 128
# The number of time steps to perform is 10010
# Timing - Allocating device memory. 		Elasped 83884 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 43 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 2 microseconds
# Timing - Initializing memory on the host. 		Elasped 0 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 308 microseconds
# time spent in SpMV: 184969.000000
# The relative error of the approximation is 0.082431

# %% [markdown]
# prefetch

# %%
# !nvcc hw4_ex4_pre.cu -lcusparse -lcublas -o hw4_ex4_pre

# %% [markdown]
# performance with out pretech

# %%
# !nvprof ./hw4_ex4_pre 64 500
# Out:
# The X dimension of the grid is 64
# The number of time steps to perform is 500
# ==8699== NVPROF is profiling process 8699, command: ./hw4_ex4_pre 64 500
# Timing - Allocating device memory. 		Elasped 288683 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 0 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 73 microseconds
# Timing - Initializing memory on the host. 		Elasped 0 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 0 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 59 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 23 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 21 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# ...

# %% [markdown]
# performance with prefetch

# %%
# !nvprof ./hw4_ex4 64 500
# Out:
# The X dimension of the grid is 64
# The number of time steps to perform is 500
# ==7909== NVPROF is profiling process 7909, command: ./hw4_ex4 64 500
# Timing - Allocating device memory. 		Elasped 224939 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 57 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 1 microseconds
# Timing - Initializing memory on the host. 		Elasped 0 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 221 microseconds
# time spent in SpMV: 17874.000000
# The relative error of the approximation is 0.938907
# ==7909== Profiling application: ./hw4_ex4 64 500
# ==7909== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   74.39%  44.712ms      1004  44.534us  43.871us  52.511us  void nrm2_kernel<double, double, double, int=0, int=0, int=128>(cublasNrm2Params<double, double>)
# ...
