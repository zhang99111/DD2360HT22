# %% [markdown]
# <a href="https://colab.research.google.com/github/zhang99111/DD2360HT22/blob/main/hw_4/hw4_ex4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd '/content/drive/MyDrive'
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive

# %%
# !nvcc hw4_ex4.cu -lcusparse -lcublas -o hw4_ex4

# %%
# !./hw4_ex4 128 1
# Out:
# The X dimension of the grid is 128
# The number of time steps to perform is 1
# Timing - Allocating device memory. 		Elasped 227312 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 1343 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 2 microseconds
# Timing - Initializing memory on the host. 		Elasped 0 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 301 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 354 microseconds
# The relative error of the approximation is 7.235710

# %%
# !./hw4_ex4 2048 1
# Out:
# The X dimension of the grid is 2048
# The number of time steps to perform is 1
# Timing - Allocating device memory. 		Elasped 231862 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 1232 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 32 microseconds
# Timing - Initializing memory on the host. 		Elasped 28 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 257 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 414 microseconds
# The relative error of the approximation is 29.303943

# %%
# !./hw4_ex4 4 2
# Out:
# The X dimension of the grid is 4
# The number of time steps to perform is 2
# Timing - Allocating device memory. 		Elasped 329976 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 785 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 0 microseconds
# Timing - Initializing memory on the host. 		Elasped 0 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 187 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 223 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# The relative error of the approximation is 0.298592

# %%
# !./hw4_ex4 8 2
# Out:
# The X dimension of the grid is 8
# The number of time steps to perform is 2
# Timing - Allocating device memory. 		Elasped 204892 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 111 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 1 microseconds
# Timing - Initializing memory on the host. 		Elasped 0 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 203 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 70 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 27 microseconds
# The relative error of the approximation is 1.231768

# %%
# !./hw4_ex4 16 2
# Out:
# The X dimension of the grid is 16
# The number of time steps to perform is 2
# Timing - Allocating device memory. 		Elasped 176669 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 42 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 0 microseconds
# Timing - Initializing memory on the host. 		Elasped 0 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 278 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 35 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# The relative error of the approximation is 2.147572

# %%
# !./hw4_ex4 32 2
# Out:
# The X dimension of the grid is 32
# The number of time steps to perform is 2
# Timing - Allocating device memory. 		Elasped 178924 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 43 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 1 microseconds
# Timing - Initializing memory on the host. 		Elasped 0 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 278 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 40 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# The relative error of the approximation is 3.288533

# %%
# !./hw4_ex4 64 2
# Out:
# The X dimension of the grid is 64
# The number of time steps to perform is 2
# Timing - Allocating device memory. 		Elasped 175068 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 49 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 2 microseconds
# Timing - Initializing memory on the host. 		Elasped 0 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 329 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 32 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# The relative error of the approximation is 4.819221

# %%
# !./hw4_ex4 128 2
# Out:
# The X dimension of the grid is 128
# The number of time steps to perform is 2
# Timing - Allocating device memory. 		Elasped 185836 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 42 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 3 microseconds
# Timing - Initializing memory on the host. 		Elasped 1 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 208 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 36 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# The relative error of the approximation is 6.931700

# %%
# !./hw4_ex4 256 2

# %%
# !./hw4_ex4 128 10
# Out:
# The X dimension of the grid is 128
# The number of time steps to perform is 10
# Timing - Allocating device memory. 		Elasped 84712 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 49 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 2 microseconds
# Timing - Initializing memory on the host. 		Elasped 0 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 361 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 37 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# The relative error of the approximation is 5.551650

# %%
# !./hw4_ex4 128 1010
# Out:
# The X dimension of the grid is 128
# The number of time steps to perform is 1010
# Timing - Allocating device memory. 		Elasped 81824 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 43 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 3 microseconds
# Timing - Initializing memory on the host. 		Elasped 1 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 283 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 37 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 23 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 33 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 31 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 22 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 21 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 22 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 22 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 24 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# ...
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 24 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# The relative error of the approximation is 1.480747

# %%
# !./hw4_ex4 128 2010
# Out:
# The X dimension of the grid is 128
# The number of time steps to perform is 2010
# Timing - Allocating device memory. 		Elasped 81406 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 45 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 2 microseconds
# Timing - Initializing memory on the host. 		Elasped 0 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 291 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 33 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 32 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 27 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 24 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 20 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 20 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# ...
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 20 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 40 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 21 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# The relative error of the approximation is 0.959595

# %%
# !./hw4_ex4 128 3010
# Out:
# The X dimension of the grid is 128
# The number of time steps to perform is 3010
# Timing - Allocating device memory. 		Elasped 82095 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 62 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 2 microseconds
# Timing - Initializing memory on the host. 		Elasped 1 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 213 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 33 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 28 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 30 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 27 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 26 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 50 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 33 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 35 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 23 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# ...
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# The relative error of the approximation is 0.656959

# %%
# !./hw4_ex4 128 4010
# Out:
# The X dimension of the grid is 128
# The number of time steps to perform is 4010
# Timing - Allocating device memory. 		Elasped 82782 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 38 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 2 microseconds
# Timing - Initializing memory on the host. 		Elasped 0 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 276 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 48 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 24 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 23 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 23 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 23 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 53 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 44 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 37 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# ...
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 25 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# The relative error of the approximation is 0.464450

# %%
# !./hw4_ex4 128 5010
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 20 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 44 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 30 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 32 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 26 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 34 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 24 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 27 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 33 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 22 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 26 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 38 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 21 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 21 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 36 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 26 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 37 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 30 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 50 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 23 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# ...
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 22 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 20 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 29 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 21 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# The relative error of the approximation is 0.336597

# %%
# !./hw4_ex4 128 6010
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 30 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 47 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 29 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 20 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 25 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 21 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 21 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 25 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 26 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 28 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 27 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 27 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 25 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 22 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 26 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 20 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 25 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# ...
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# The relative error of the approximation is 0.248554

# %%
# !./hw4_ex4 128 7010
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 25 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 28 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 23 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 22 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# ...
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 21 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 23 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 21 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# The relative error of the approximation is 0.186129

# %%
# !./hw4_ex4 128 8010
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 30 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 25 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 29 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 21 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 21 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 20 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 25 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 20 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 25 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 21 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 21 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# ...
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 31 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 21 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 24 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 21 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# The relative error of the approximation is 0.140850

# %%
# !./hw4_ex4 128 9010
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 21 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 24 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 26 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 23 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 27 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 36 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 21 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 21 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 23 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 140 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 20 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 23 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 20 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 36 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 261 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 263 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 284 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 291 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 258 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 20 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 26 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# ...
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 25 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 23 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# The relative error of the approximation is 0.107430

# %%
# !./hw4_ex4 128 10010
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 21 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 26 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 26 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 26 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 21 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 21 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 23 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 24 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 29 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 29 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 32 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 25 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 28 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 36 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 23 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 26 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 22 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 28 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 5 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# ...
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 23 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 9 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 8 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 7 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 6 microseconds
# The relative error of the approximation is 0.082431

# %% [markdown]
# prefetch

# %%
# !nvcc hw4_ex4_pre.cu -lcusparse -lcublas -o hw4_ex4_pre

# %% [markdown]
# performance with out pretech

# %%
# !nvprof ./hw4_ex4_pre 64 500
# Out:
# The X dimension of the grid is 64
# The number of time steps to perform is 500
# ==701== NVPROF is profiling process 701, command: ./hw4_ex4_pre 64 500
# Timing - Allocating device memory. 		Elasped 389558 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 0 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 83 microseconds
# Timing - Initializing memory on the host. 		Elasped 1 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 0 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 52 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 22 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 20 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 23 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 23 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 28 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 25 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 29 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 24 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 23 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 20 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 29 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 28 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 40 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 35 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 39 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 20 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 21 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 23 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 23 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 23 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 26 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 22 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 21 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 26 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 94 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 23 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 28 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 24 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 24 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 30 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 23 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 23 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 20 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 20 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 20 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 20 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 28 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 24 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# The relative error of the approximation is 0.938907
# ==701== Profiling application: ./hw4_ex4_pre 64 500
# ==701== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   74.09%  44.603ms      1004  44.425us  43.647us  46.335us  void nrm2_kernel<double, double, double, int=0, int=0, int=128>(cublasNrm2Params<double, double>)
#                    13.34%  8.0314ms       500  16.062us  15.999us  16.640us  _ZN8cusparse21load_balancing_kernelILj512ELj4ELm16384EiiNS_7CsrmvOpILi512EdLb0EEEJKiKdS4_didEEEvPKT3_T2_S5_S5_iPKS8_T4_DpPT5_
#                     6.04%  3.6355ms       500  7.2700us  6.3680us  419.32us  _ZN8cusparse30binary_search_partition_kernelILi128ELi2048EiiNS_6ScaleYINS_20MatrixWiseMulPolicy1ILb0EdEEidEEJdEEEvPKT2_T1_S5_iPS8_T3_DpPT4_
#                     3.99%  2.4038ms       501  4.7970us  4.7030us  9.9190us  void axpy_kernel_val<double, double>(cublasAxpyParamsVal<double, double, double>)
#                     1.36%  816.50us       502  1.6260us  1.5990us  2.0800us  [CUDA memcpy DtoH]
#                     1.18%  707.98us       502  1.4100us  1.3750us  1.8240us  [CUDA memcpy HtoD]
#                     0.01%  4.4480us         1  4.4480us  4.4480us  4.4480us  void thrust::cuda_cub::core::_kernel_agent<thrust::cuda_cub::__parallel_for::ParallelForAgent<thrust::cuda_cub::__tabulate::functor<thrust::device_ptr<double>, thrust::detail::functional::actor<thrust::detail::functional::composite<thrust::detail::functional::transparent_binary_operator<thrust::plus<void>>, thrust::detail::functional::value<double>, thrust::detail::functional::actor<thrust::detail::functional::composite<thrust::detail::functional::transparent_binary_operator<thrust::multiplies<void>>, thrust::detail::functional::value<double>, thrust::detail::functional::actor<thrust::detail::functional::argument<unsigned int=0>>, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type>>, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type>>, long>, long>, thrust::cuda_cub::__tabulate::functor<thrust::device_ptr<double>, thrust::detail::functional::actor<thrust::detail::functional::composite<thrust::detail::functional::transparent_binary_operator<thrust::plus<void>>, thrust::detail::functional::value<double>, thrust::detail::functional::actor<thrust::detail::functional::composite<thrust::detail::functional::transparent_binary_operator<thrust::multiplies<void>>, thrust::detail::functional::value<double>, thrust::detail::functional::actor<thrust::detail::functional::argument<unsigned int=0>>, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type>>, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type>>, long>, long>(thrust::device_ptr<double>, void)
#       API calls:   69.21%  1.04934s        12  87.445ms  4.1630us  458.23ms  cudaFree
#                    25.69%  389.55ms         5  77.910ms  6.2120us  389.50ms  cudaMallocManaged
#                     3.42%  51.797ms      1004  51.590us  3.0760us  339.06us  cudaMemcpyAsync
#                     1.05%  15.976ms      2506  6.3750us  3.6160us  76.260us  cudaLaunchKernel
#                     0.13%  1.9869ms       503  3.9500us  1.9280us  20.245us  cudaFuncGetAttributes
#                     0.11%  1.7105ms         4  427.62us  341.90us  621.42us  cuDeviceTotalMem
#                     0.08%  1.1777ms       502  2.3450us  1.3720us  11.416us  cudaEventQuery
#                     0.07%  1.0533ms       503  2.0930us  1.6640us  5.6170us  cudaStreamSynchronize
#                     0.07%  1.0209ms      3021     337ns     129ns  12.215us  cudaGetLastError
#                     0.05%  807.95us      1506     536ns     305ns  17.052us  cudaStreamGetCaptureInfo
#                     0.04%  659.92us       395  1.6700us     130ns  84.384us  cuDeviceGetAttribute
#                     0.03%  507.43us       502  1.0100us     679ns  9.1420us  cudaEventRecord
#                     0.02%  267.70us         4  66.925us  4.4700us  150.96us  cudaMalloc
#                     0.01%  181.49us         1  181.49us  181.49us  181.49us  cudaGetDeviceProperties
#                     0.01%  140.23us         4  35.057us  18.582us  58.378us  cuDeviceGetName
#                     0.00%  16.821us        18     934ns     365ns  6.6460us  cudaEventCreateWithFlags
#                     0.00%  10.530us        18     585ns     340ns  1.9870us  cudaEventDestroy
#                     0.00%  9.9730us         4  2.4930us     861ns  4.8170us  cudaDeviceSynchronize
#                     0.00%  9.3430us         7  1.3340us     400ns  2.3010us  cudaGetDevice
#                     0.00%  7.4810us         3  2.4930us  2.1770us  2.8810us  cuInit
#                     0.00%  7.4790us        14     534ns     270ns  1.4710us  cudaDeviceGetAttribute
#                     0.00%  6.9020us         1  6.9020us  6.9020us  6.9020us  cuDeviceGetPCIBusId
#                     0.00%  2.5230us         5     504ns     276ns  1.1040us  cuDeviceGet
#                     0.00%  2.1750us         6     362ns     150ns     918ns  cuDeviceGetCount
#                     0.00%  1.9250us         3     641ns     332ns  1.0250us  cuDriverGetVersion
#                     0.00%  1.2290us         4     307ns     282ns     317ns  cuDeviceGetUuid
#                     0.00%  1.1060us         1  1.1060us  1.1060us  1.1060us  cudaGetSymbolAddress
#                     0.00%     784ns         1     784ns     784ns     784ns  cudaGetDeviceCount
#                     0.00%     344ns         2     172ns     130ns     214ns  cudaPeekAtLastError
#
# ==701== Unified Memory profiling result:
# Device "Tesla T4 (0)"
#    Count  Avg Size  Min Size  Max Size  Total Size  Total Time  Name
#        2  32.000KB  4.0000KB  60.000KB  64.00000KB  11.20000us  Host To Device
#        1         -         -         -           -  410.2950us  Gpu page fault groups
# Total CPU Page faults: 1

# %% [markdown]
# performance with prefetch

# %%
# !nvprof ./hw4_ex4 64 500
# Out:
# The X dimension of the grid is 64
# The number of time steps to perform is 500
# ==16353== NVPROF is profiling process 16353, command: ./hw4_ex4 64 500
# Timing - Allocating device memory. 		Elasped 375697 microseconds
# Timing - Prefetching GPU memory to the host. 		Elasped 61 microseconds
# Timing - Initializing the sparse matrix on the host. 		Elasped 1 microseconds
# Timing - Initializing memory on the host. 		Elasped 0 microseconds
# Timing - Prefetching GPU memory to the device. 		Elasped 245 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 78 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 20 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 28 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 24 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 24 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 20 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 20 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 24 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 21 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 24 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 21 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 22 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 21 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 27 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 25 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 22 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 22 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 21 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 20 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 22 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 20 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 20 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 20 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 20 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 21 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 24 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 23 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 20 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 10 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 21 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 24 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 16 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 29 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 21 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 18 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 17 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 19 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 14 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 15 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 24 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 11 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 12 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 13 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 34 microseconds
# Timing - CUDA Sparse matrix multiplication. 		Elasped 29 microseconds
# The relative error of the approximation is 0.938907
# ==16353== Profiling application: ./hw4_ex4 64 500
# ==16353== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   74.49%  44.631ms      1004  44.452us  43.679us  46.112us  void nrm2_kernel<double, double, double, int=0, int=0, int=128>(cublasNrm2Params<double, double>)
#                    13.43%  8.0472ms       500  16.094us  16.031us  16.736us  _ZN8cusparse21load_balancing_kernelILj512ELj4ELm16384EiiNS_7CsrmvOpILi512EdLb0EEEJKiKdS4_didEEEvPKT3_T2_S5_S5_iPKS8_T4_DpPT5_
#                     5.39%  3.2312ms       500  6.4620us  6.3680us  9.5990us  _ZN8cusparse30binary_search_partition_kernelILi128ELi2048EiiNS_6ScaleYINS_20MatrixWiseMulPolicy1ILb0EdEEidEEJdEEEvPKT2_T1_S5_iPS8_T3_DpPT4_
#                     4.04%  2.4195ms       501  4.8290us  4.7040us  10.464us  void axpy_kernel_val<double, double>(cublasAxpyParamsVal<double, double, double>)
#                     1.41%  842.17us       502  1.6770us  1.6320us  2.1120us  [CUDA memcpy DtoH]
#                     1.23%  736.63us       502  1.4670us  1.4080us  1.8560us  [CUDA memcpy HtoD]
#                     0.01%  4.4480us         1  4.4480us  4.4480us  4.4480us  void thrust::cuda_cub::core::_kernel_agent<thrust::cuda_cub::__parallel_for::ParallelForAgent<thrust::cuda_cub::__tabulate::functor<thrust::device_ptr<double>, thrust::detail::functional::actor<thrust::detail::functional::composite<thrust::detail::functional::transparent_binary_operator<thrust::plus<void>>, thrust::detail::functional::value<double>, thrust::detail::functional::actor<thrust::detail::functional::composite<thrust::detail::functional::transparent_binary_operator<thrust::multiplies<void>>, thrust::detail::functional::value<double>, thrust::detail::functional::actor<thrust::detail::functional::argument<unsigned int=0>>, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type>>, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type>>, long>, long>, thrust::cuda_cub::__tabulate::functor<thrust::device_ptr<double>, thrust::detail::functional::actor<thrust::detail::functional::composite<thrust::detail::functional::transparent_binary_operator<thrust::plus<void>>, thrust::detail::functional::value<double>, thrust::detail::functional::actor<thrust::detail::functional::composite<thrust::detail::functional::transparent_binary_operator<thrust::multiplies<void>>, thrust::detail::functional::value<double>, thrust::detail::functional::actor<thrust::detail::functional::argument<unsigned int=0>>, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type>>, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type, thrust::null_type>>, long>, long>(thrust::device_ptr<double>, void)
#       API calls:   69.67%  1.04200s        12  86.834ms  7.4870us  458.24ms  cudaFree
#                    25.12%  375.67ms         5  75.135ms  4.5620us  375.64ms  cudaMallocManaged
#                     3.46%  51.722ms      1004  51.515us  5.0010us  109.21us  cudaMemcpyAsync
#                     1.10%  16.466ms      2506  6.5700us  3.8310us  51.022us  cudaLaunchKernel
#                     0.13%  1.9830ms       503  3.9420us  2.7780us  20.241us  cudaFuncGetAttributes
#                     0.10%  1.4664ms         4  366.61us  350.06us  407.30us  cuDeviceTotalMem
#                     0.08%  1.2036ms       502  2.3970us  1.9630us  19.596us  cudaEventQuery
#                     0.08%  1.1343ms       503  2.2550us  1.8000us  20.572us  cudaStreamSynchronize
#                     0.06%  955.90us      3021     316ns     143ns  7.8250us  cudaGetLastError
#                     0.05%  815.88us      1506     541ns     300ns  13.156us  cudaStreamGetCaptureInfo
#                     0.04%  661.35us       395  1.6740us     124ns  91.225us  cuDeviceGetAttribute
#                     0.03%  513.38us       502  1.0220us     792ns  9.6560us  cudaEventRecord
#                     0.02%  305.11us         4  76.277us  4.1340us  156.83us  cudaMalloc
#                     0.02%  295.37us         6  49.228us  2.7020us  233.09us  cudaMemPrefetchAsync
#                     0.01%  219.37us         1  219.37us  219.37us  219.37us  cudaGetDeviceProperties
#                     0.01%  114.72us         4  28.679us  18.211us  36.695us  cuDeviceGetName
#                     0.00%  32.463us        14  2.3180us     275ns  25.640us  cudaDeviceGetAttribute
#                     0.00%  18.185us        18  1.0100us     367ns  6.9700us  cudaEventCreateWithFlags
#                     0.00%  17.612us         4  4.4030us  1.7160us  7.0180us  cudaDeviceSynchronize
#                     0.00%  14.553us        18     808ns     578ns  2.1080us  cudaEventDestroy
#                     0.00%  13.267us         7  1.8950us     408ns  4.3250us  cudaGetDevice
#                     0.00%  6.9460us         3  2.3150us  1.7700us  2.8640us  cuInit
#                     0.00%  6.3710us         1  6.3710us  6.3710us  6.3710us  cuDeviceGetPCIBusId
#                     0.00%  2.5410us         6     423ns     204ns     949ns  cuDeviceGetCount
#                     0.00%  2.1010us         5     420ns     243ns     942ns  cuDeviceGet
#                     0.00%  1.1340us         3     378ns     317ns     440ns  cuDriverGetVersion
#                     0.00%  1.1050us         1  1.1050us  1.1050us  1.1050us  cudaGetSymbolAddress
#                     0.00%  1.0600us         4     265ns     212ns     292ns  cuDeviceGetUuid
#                     0.00%     399ns         2     199ns     151ns     248ns  cudaPeekAtLastError
#                     0.00%     336ns         1     336ns     336ns     336ns  cudaGetDeviceCount
#
# ==16353== Unified Memory profiling result:
# Device "Tesla T4 (0)"
#    Count  Avg Size  Min Size  Max Size  Total Size  Total Time  Name
#        1  4.0000KB  4.0000KB  4.0000KB  4.000000KB  3.040000us  Host To Device
